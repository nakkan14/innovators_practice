# %% [markdown]
# # 1スクレイピングとは(APIがない場合の手段)
#
#
# 目次https://docs.google.com/document/d/1tA8OJW3plW6nMc6tqjrjIqmov70FTC9ITL9NhN0oa3g/edit?usp=sharing

# %% [markdown]
# ### 1.1目的

# %% [markdown]
# 欲しい情報を提供するAPIが存在しない際は、スクレイピングをという技術を用いて欲しい情報を取得する。今回は、楽天トラベルから情報を取得することでスクレイピングのイロハを学ぶ

# %% [markdown]
# ### 1.2情報を取得する方法

# %% [markdown]
# 大きく２種類あります。
#
# - 情報提供を目的としたサービス：API
# - 情報が提供された目的とは違う、情報取集：スクレイピング
#
# があります。
#
# 欲しい情報を提供してくれるAPIが存在しない場合、ウェブサイトから情報を収集することが必要になります。この場合、スクレイピングを活用することになります。

# %% [markdown]
# ### 1.3スクレイピングとは

# %% [markdown]
# スクレイピングとは、ウェブサイトからデータを自動的に収集するプログラムを作成することです。
# スクレイピングを行うためには、WebページのHTMLコードを解析して、必要な情報を抽出する必要があります。
#
# 一般的に、スクレイピングは以下の手順で行われます。
# - スクレイピングする対象のWebページのURLを指定する。
# - WebページのHTMLコードをダウンロードする。
# - HTMLコードから必要な情報を抽出する。
# - 抽出した情報を保存する。
#
# 注意点として、スクレイピングはウェブサイトの利用規約に違反しないように注意する必要があります。適切なスクレイピングの方法と頻度の制御が重要です。

# %% [markdown]
# <img src="img/img021.jpg">

# %% [markdown]
# 参照：https://www.octoparse.jp/blog/web-scraping/

# %% [markdown]
# 禁止事項を確認してみましょう！
#
# - 把握のためにどういう事が禁止されているか見てみましょう！
#     - 条件が厳しいsuumoで全体像を確認してみましょう！
#         - https://suumo.jp/robots.txt
#     - 規制があまりない楽天トラベル
#         - http://travel.rakuten.co.jp/robots.txt

# %% [markdown]
# ### 1.4.APIとの違いは

# %% [markdown]
# APIによって提供される情報は、APIの設計者が決定した範囲内でのみ利用可能です。
# 例えば、楽天が情報提供するデータは楽天が所持しているデータのみで、他のデータは別のAPIで取得する必要があります。
# 一方、スクレイピングは、APIの有無に関わらず、多数のウェブサイトから情報を収集することが可能です。多様な情報を取得ができる点が大きな違いです。
#
# APIは呼び出しに料金が必要な場合や呼び出しの最大数も制限がある事があり、メリット・デメリットが存在します。

# %% [markdown]
# #### APIのメリットデメリット

# %% [markdown]
# メリット
# - 早く開発できる
# - スマホアプリなどの連携が容易
# - スクレイピングに比べて仕様変更の作業コストが安い
#
# デメリット
# - APIの提供中止
# - APIが有料化する
# - APIの料金変更

# %% [markdown]
# #### スクレイピングのメリットデメリット

# %% [markdown]
# メリット
# - 多様な情報をまとめたデータを構築できる
# - 利用料金がない
# - 自分で作ったコードなので、提供中止にならない
#
# デメリット
# - サイト側の仕様変更に対応しなければならない
# - 作成コストが高い
# - 取得が許可された範囲を確認する必要性あり

# %% [markdown]
# ## 2.スクレイピングの実践

# %% [markdown]
# ### 2.1.スクレイピングのために使うライブラリ：beautifulsoup4

# %% [markdown]
# #### beautifulsoup4とは

# %% [markdown]
# Pythonのライブラリであり、httpリクエストで得られたHTMLやXMLなどの構造化されたドキュメントから情報を抽出するために使用されます。Webスクレイピングに最適なライブラリの1つです。
#
# httpリクエストライブラリのrequestsで得られたhtmlデータの中からHTMLタグ、属性、テキストコンテンツなどを簡単に検索、抽出することができます。

# %% [markdown]
# <img src="img/img022.png">

# %% [markdown]
# 参照：https://itdepends.hateblo.jp/entry/2020/02/26/000120

# %% [markdown]
# #### beautifulsoup4をインストールしましょう

# %% [markdown]
# ターミナルでpip install beautifulsoup4でインストールできます。

# %% [markdown]
# ### 2.2使い方の具体例

# %% [markdown]
# >全体像

# %% [markdown]
# 具体例として、楽天トラベルのサイトから以下の画像にある4つの情報を取得します。
# 取得する場所はhttps://travel.rakuten.co.jp/yado/okinawa/nahashi.htmlです。
#
# 注意点として、このサイトではアクセスするたびに掲載されているホテル情報が変わる為、取得できる情報が那覇ウエスト・インでなくても構いません。
#
# 1. タイトル（那覇ウエスト・イン）
# 1. 値段の数字（[最安料金] 2,450円〜）
# 1. 評価（4.28）
# 1. 住所（〒900-0036　沖縄県那覇市西1-16-7[地図を見る]）

# %% [markdown]
# <img src="img/img023.png">

# %% [markdown]
# >解説の流れ

# %% [markdown]
# 取得する流れは以下のようになります。
#
# 1. 取得したいサイトからデータを取得する準備
#     1. requestsの機能をインポート
#     1. BeautifulSoupの機能をインポート
#     1. requestsでhtmlのデータを取得
#     1. BeautifulSoupに読み込ませて欲しい要素を検索可能状態にする
# 1. 欲しい情報を取得
#     1. htmlの構造を確認
#     1. どのcssセレクタの条件で絞り込みできるか考える
#     1. どのhtml範囲から取得するか考える
#     1. 抽出する範囲のhtmlを取得
#     1. 取得したhtmlから欲しい情報を取得
# 1. 取得した情報整理
#     1. 余分な文字データをreplaceで整理

# %% [markdown]
# >実際のコード

# %% [markdown]
# 1.取得したいサイトからデータを取得する準備

# %% [markdown]
# requestsで楽天トラベルを取得します。

# %%
# requests機能をインポートします。
import requests
#アクセス先をREQUEST_URLを代入します。
REQUEST_URL = 'https://travel.rakuten.co.jp/yado/okinawa/nahashi.html'
#リクエストしたデータをresに代入します。
res = requests.get(REQUEST_URL)
# resの文字データがISO-8859-1なので、utf-8に変換して文字化けを防止します。
res.encoding = 'utf-8'

# %% [markdown]
# 取得したデータをbeautifulsoup4が解析できるようにします。

# %%
# BeautifulSoupの機能をインポートします。
from bs4 import BeautifulSoup
# BeautifulSoup(解析したいデータ,解析する方法)を指定し、解析したデータをsoupに代入します。
soup = BeautifulSoup(res.text,"html.parser")

# %% [markdown]
# これで取得したhtmlデータから欲しい情報を取得できるようになりました。

# %% [markdown]
# 2.欲しい情報を取得

# %% [markdown]
# 欲しい情報がどのようなhtml構成をしているかを確認します。
#
# 欲しい情報があるhtml要素にpadding:20px;などのcssを適応しようとしたらどのようなcssセレクタを指定すればよいのかを意識しながら確認します。
# 理由は、BeautifulSoupも同様にそのcssセレクタに該当するhtml要素を取得するためです。
#
# 以下がcssセレクタの例です
# - h1 a
# - .htlPrice
#
# 方法はブラウザで右クリックまたは２本指タップでメニューを出し、”ページのソースを表示”を選択して、下記のような画面を出します。
# 欲しいhtml要素の特定はctrl + Fまたはcommand + Fで住所を検索すると良いでしょう！

# %% [markdown]
# <img src="img/img024.png">

# %% [markdown]
# このサイトでは、欲しい情報を以下のcssセレクタで取得できます。
# - h1 a
# - p.htlPrice span
# - p.cstmrEvl strong
# - p.htlAccess

# %% [markdown]
# ですが、問題点はこのセレクターでは該当するhtmlを１つに絞る事ができません。
# 理由は、このcssセレクタをもつhtml要素が複数存在するからです。
#
# また、どこを取得したか把握しずらいので、問題が起きた時に修正ができません。

# %% [markdown]
# 対策として、１度に欲しい情報を取得するのではなく、htmlの一部を取得してその中から欲しい情報を取得します。
#
# 例として、sectionのcssセレクタを活用して、htmlの一部を取得した場合を考えます。
# このサイトでsectionタグで限定した場合、以下の画像のような範囲のhtmlを取得できます。

# %% [markdown]
# <img src="img/img025.png">

# %% [markdown]
# 今回は3つ目のsectionに那覇ウエスト・インの情報が存在するので、変数hotel_sectionに3つ目のsectionのhtmlを代入しておきます。
# 注意点として、このサイトではアクセスするたびに掲載されているホテル情報が変わる為、取得できる情報が那覇ウエスト・インでなくても構いません。
#
# 全体のhtmlが変数soupに格納されていて、
# 今から変数soupに格納されたhtmlからcssセレクタのsectionを条件に抽出したhtmlを変数hotel_sectionに代入します。
#
# 抽出の仕方は
# htmlが格納されている変数.select("ここにcssセレクタ")になります。
#
# 注意点として.selectで取得した場合は、
# １つだけも複数のhtmlデータも配列として取得するので、必ず取得したデータは配列の何番目に格納されているか確認しましょう！
# １つだけを取得する.select_oneの場合は配列ではなく、htmlとして取得するので配列などは気にしなくて良いです。
#
# 今回は取得したhtml要素の３つ目のhtml要素を代入したいので、[2]も付けておきます。

# %%
# html全体を格納しているsoupからsectionというcssセレクタを使って抽出
hotel_section = soup.select("section")[0]

# %% [markdown]
# 一部のhtmlから以下のcssセレクタで欲しい情報を取得してみましょう。
#
# このcssセレクタをもつcssは１つしか存在しないので、select_oneも解説として使用してみます。
#
# - h1 a
# - p.htlPrice span
# - p.cstmrEvl strong
# - p.htlAccess

# %%
# sctionの３番目のhtmlを格納しているsoupからh1 aというcssセレクタを使って抽出
print(hotel_section.select_one("h1 a"))
# sctionの３番目のhtmlを格納しているsoupからp.htlPrice spanというcssセレクタを使って抽出
print(hotel_section.select_one("p.htlPrice span"))
# sctionの３番目のhtmlを格納しているsoupからp.cstmrEvl strongというcssセレクタを使って抽出
print(hotel_section.select_one("p.cstmrEvl strong"))
# sctionの３番目のhtmlを格納しているsoupからp.htlAccessというcssセレクタを使って抽出
print(hotel_section.select_one("p.htlAccess"))
# Out:
# <a href="https://travel.rakuten.co.jp/HOTEL/146927/146927.html?l-id=hotelList_ad_L000002979_1_146927">ホテルアベスト那覇国際通り</a>
# <span>3,055円〜</span>
# <strong>4.13</strong>
# <p class="htlAccess">
#            〒900-0015　沖縄県那覇市久茂地3-1-10<a class="thickbox" data-ratevent="click" data-ratid="hotelList_ad_L000002979_1_146927_mapClick" data-ratparam="all" href="//travel.rakuten.co.jp/share/gmap/map.html?f_longitude=127.6807344&amp;f_latitude=26.2140234&amp;TB_iframe=true&amp;height=450&amp;width=600" title="ホテルアベスト那覇国際通り">[地図を見る]</a>
# </p>

# %% [markdown]
# 取得できた欲しい情報のhtmlをそれぞれの変数に代入しておきます
# - hotelName （ホテル名）
# - hotelMinCharge （ホテルの料金）
# - reviewAverage （ホテル評価）
# - hotel_locate （ホテル住所）

# %%
#hotelName, hotelMinCharge, reviewAverage, hotel_locateの変数に入れる
hotelName = hotel_section.select_one("h1 a")
hotelMinCharge = hotel_section.select_one("p.htlPrice span")
reviewAverage = hotel_section.select_one("p.cstmrEvl strong")
hotel_locate = hotel_section.select_one("p.htlAccess")

# %% [markdown]
# 3.取得した情報整理

# %% [markdown]
# htmlからテキストを抽出する場合は、.textを使います。
# 今回は使用しませんがhtmlからURLを抽出する場合は、["href"]を使います。
#
# 参考としてhotel_section.select("h1 a")からテキストデータとURLを抽出してみます。

# %%
#hotel_section.select_one("h1 a").textで抽出
hotelName.text
# Out:
# 'ホテルアベスト那覇国際通り'

# %%
#select_one("h1 a")["href"]でリンクを取得
hotelName["href"]
# Out:
# 'https://travel.rakuten.co.jp/HOTEL/146927/146927.html?l-id=hotelList_ad_L000002979_1_146927'

# %% [markdown]
# 余計な文字列を削除して整理する解説として、hotel_locateに格納した住所を含むhtmlを例として挙げます。
# .textをつけて、htmlから文字を抽出します。

# %%
# .textで文字取得
hotel_locate.text
# Out:
# '\n           〒900-0015\u3000沖縄県那覇市久茂地3-1-10[地図を見る]\n'

# %% [markdown]
# \nやスペースなど必要ない文字を含んでいます。
# これらはpython標準の関数であるreplaceで整理していきます。
#
# 使い方は.replace("ここに置き換えたい文字","置き換える文字")で置換可能です。
# "置き換える文字"を空欄である""にすることで、削除のような処理になります。
#
# サンプルとして、\nを削除します。

# %%
# .replace("ここに置き換えたい文字","置き換える文字")
hotel_locate.text.replace("\n","")
# Out:
# '           〒900-0015\u3000沖縄県那覇市久茂地3-1-10[地図を見る]'

# %% [markdown]
# またreplace関数は複数回使用可能なので、スペースも全角スペース、[地図を見る]も削除して整理します。

# %%
#地図を見るという言葉もリプレイスで消しておく
hotel_locate.text.replace("\n","").replace(" ","").replace("[地図を見る]","").replace("　","")
# Out:
# '〒900-0015沖縄県那覇市久茂地3-1-10'

# %% [markdown]
# このようにreplaceを活用して、取得した４つのhtml情報を整理すると、欲しい情報だけを取得する事ができます。

# %%
print(hotelName.text)
print(hotelMinCharge.text.replace("円〜","").replace(",",""))
print(reviewAverage.text)
print(hotel_locate.text.replace("\n","").replace(" ","").replace("[地図を見る]","").replace("　",""))
# Out:
# ホテルアベスト那覇国際通り
# 3055
# 4.13
# 〒900-0015沖縄県那覇市久茂地3-1-10

# %% [markdown]
# 以上がBeautifulSoupの使い方の例です。

# %% [markdown]
# ### 2.3この講座でやる事の全体像

# %% [markdown]
# 取得する情報は以下の4つです。
# - ホテル名
# - ホテルの値段
# - ホテルの評価
# - ホテルの住所
#
# 以下の項目はスクレイピングをする時の流れになります。
# 実際にスクレイピングのコーディングしようとすると、必ず試行錯誤が必要なので、
# 試行錯誤を3回含んでいます。
#
# 1. スクレイピング可能か確認
#     1. 規約でスクレイピングするURLがDisallowの項目に入っていないかの確認
# 1. スクレイピングの準備
#     1. ライブラリのインポート
#     1. requestsでhtmlデータ取得
#     1. 文字化けしてないかのチェック
#     1. 文字化けしていた場合の対処
#     1. BeautifulSoupでhtml解析
# 1. 試行錯誤その１
#     1. h1.premium_normalですべての情報を取得できるか確認
# 1. 試行錯誤その２
#     1. section h1 aですべての情報を取得できるか確認
# 1. 試行錯誤その３
#     1. 欲しい情報にすべて書かれている[最安料金]という文字に着目してスクレイピングの構造を考える
#     1. 表示されている32件ではなく、全部で36件もデータが存在する事が判明
#     1. 36件のデータを取得するための条件を考える
#     1. sectionを条件にhtmlを分割
#     1. 分割したhtmlから欲しい情報を含むhtmlを1つずつ抽出
#     1. htmlから欲しい情報だけを抽出
# 1. pandasを活用してデータにまとめる
#     1. 抽出した配列をDataFrameへ
#     1. 重複をチェック
#     1. データ整理

# %% [markdown]
# ### 2.4実際にコーディング

# %% [markdown]
# #### 2.4.1.規約の確認

# %% [markdown]
# http://travel.rakuten.co.jp/robots.txt
# 取得して良いか確認しましょう

# %% [markdown]
# Disallow: /cgi-bin/
# Disallow: /B2B/
# Disallow: /*_trvmkt*
#
# なので、
# 1. サイトURL+/cgi-bin/
# 1. サイトURL+/B2B/
# 1. サイトURL+/*_trvmkt*
#
# この3つのURLでのスクレイピングが禁止されている事がわかります。
#
# 今回はこの規約に載っていないので問題ありません。

# %% [markdown]
# #### 2.4.2.スクレイピング可能か確認

# %% [markdown]
# >ライブラリのインポート

# %% [markdown]
# リクエストをするためのライブラリをインポートしておきましょう！

# %%
# requestsとBeautifulSoupの機能をインポートします。
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# >requestsでhtmlデータ取得

# %% [markdown]
# requestsを使って、ブラウザのようにhtmlが取得できるかどうか確認してみましょう！
# 今回はパラメータは必要ないので、シンプルにrequests.get(REQUEST_URL)だけでいいです！

# %%
#アクセス先をREQUEST_URLを代入します。
REQUEST_URL = 'https://travel.rakuten.co.jp/yado/okinawa/nahashi.html'
#リクエストしたデータをresに代入します。
res = requests.get(REQUEST_URL)

# %% [markdown]
# >文字化けしてないかのチェック

# %% [markdown]
# 通信の結果、返ってきたデータの中身はhtmlなので、res.textで確認してみましょう！

# %%
#resのtextにサイトデータが格納されているので、それをresultに代入します。
result = res.text
# printでサイトデータを確認します。
print(result)
# Out:
# <!DOCTYPE HTML>
# <html lang="ja" prefix="og: http://ogp.me/ns# fb: http://www.facebook.com/2008/fbml mixi: http://mixi-platform.com/ns# gr: http://gree.jp/ns">
# <head>
# <meta charset="utf-8">
# <title>é£è¦ã®ããã«ã»æé¤¨ å®¿æ³äºç´ ãæ¥½å¤©ãã©ãã«ã</title>
# <meta name="description" content="é£è¦ã®ããã«ã»æé¤¨ã®äºç´ã¯æ¥½å¤©ãã©ãã«ã§ï¼äººæ°ãã¸ãã¹,ã·ãã£ããã«ããæé¤¨ã¾ã§ãå®¢æ§ã®å£°ãªã©å®¿æå ±æºè¼">
# <meta name="keywords" content="å®¿æ³,åºå¼µ,äºç´,æ½è¨­,ãã¸ãã¹,ããã«,æé¤¨,æ¥½å¤©ãã©ãã«,æã®çªå£,é£è¦">
# <meta name="robots" content="index,follow">
# <meta property="og:title" content="é£è¦ã®ããã«ã»æé¤¨ å®¿æ³äºç´ ãæ¥½å¤©ãã©ãã«ã">
# <meta property="og:description" content="é£è¦ã®ããã«ã»æé¤¨ã®äºç´ã¯æ¥½å¤©ãã©ãã«ã§ï¼äººæ°ãã¸ãã¹,ã·ãã£ããã«ããæé¤¨ã¾ã§ãå®¢æ§ã®å£°ãªã©å®¿æå ±æºè¼">
# <meta property="og:type" content="article">
# <meta property="og:url" content="https://travel.rakuten.co.jp/yado/okinawa/nahashi.html">
# <meta property="og:image" content="https://trvimg.r10s.jp/share/common/images/bnr_ogp_logo.gif">
# 	<link rel="canonical" href="https://travel.rakuten.co.jp/yado/okinawa/nahashi.html">
# <meta property="og:site_name" content="æ¥½å¤©ãã©ãã«">
# <meta property="og:locale" content="ja_JP">
# <meta name="format-detection" content="telephone=no">
#
# <link rel="stylesheet" href="https://img.travel.rakuten.co.jp/share/common/css/style-pc.css?_=20221213" >
#
# <link type="text/css" rel="stylesheet" href="https://img.travel.rakuten.co.jp/share/themes/ds/css/trvl_srch_undtd_page.css?_=20230717" media="screen">
# <link type="text/css" rel="stylesheet" href="https://img.travel.rakuten.co.jp/share/themes/ds/css/trvl_srch_undtd_dp_pop.css" media="screen">
# <link type="text/css" rel="stylesheet" href="https://img.travel.rakuten.co.jp/share/rtl/css/util.calendar.css" media="screen">
# <link type="text/css" rel="stylesheet" href="https://img.travel.rakuten.co.jp/share/themes/ds/css/searchSide_B.css" media="screen">
# <link type="text/css" rel="stylesheet" href="https://img.travel.rakuten.co.jp/share/common/css/thickbox.css" media="screen">
# <link type="text/css" rel="stylesheet" href="https://img.travel.rakuten.co.jp/share/themes/ds/css/station_C.css" media="screen">
# <link type="text/css" rel="stylesheet" href="https://img.travel.rakuten.co.jp/share/themes/ds/css/preferred_sparkle.css?=_20210525" media="all">
# <link rel="next" href="https://search.travel.rakuten.co.jp/ds/yado/okinawa/nahashi-p2">
# <LINK type="text/css" rel="stylesheet" href="https://img.travel.rakuten.co.jp/share/rtl/css/widget_history_correlated-pc.css" media="all">
# <LINK type="text/css" rel="stylesheet" href="https://trv.r10s.jp/share/rtl/css/widget_history_correlated-pc_imgOpt.css" media="all">
# <!--[if lt IE 9]><script src="https://img.travel.rakuten.co.jp/share/common/js/lib/html5shiv.js"></script><![endif]-->
#
# </head>
# <body id="TOP" class="">
# <script>
#  if(!tags) var tags = {};
#  if(!tags.data) tags.data = {};
#  tags.data = {"contents":{"type":"hotel"},"page":{"type":"search","step":"","pageNo":1,"abTestName":"E20210630","patternNumber":"0"},"query":{"items":[{"from":{"date":"","country":"japan","prefecture":"okinawa","city":"nahashi","district":"","spot":""},"to":{"date":"","country":"japan","prefecture":"okinawa","city":"nahashi","district":"","spot":""},"guest":{"adult":"","child":"","infant":""},"id":"","type":"","category":"","provider":{"id":"","type":"hotel","category":""}}],"price":"","currency":"JPY","abTestHotelIdList":["hotelList_ad_L000002979_1_146927","hotelList_ad_L000002979_2_182439","hotelList_ad_L000002979_3_158644","hotelList_ad_L000002979_4_183095","hotelList_ad_L000002979_5_72693","hotelList_ad_L000002979_6_149360","hotelList_7_104526","hotelList_8_134763","hotelList_9_128440","hotelList_10_163087","hotelList_11_178447","hotelList_12_171943","hotelList_13_177761","hotelList_14_181785","hotelList_15_40768","hotelList_16_160939","hotelList_17_176757","hotelList_18_130025","hotelList_19_182884","hotelList_20_167519","hotelList_21_71990","hotelList_22_38282","hotelList_23_149369","hotelList_24_136808","hotelList_25_178292","hotelList_26_148000","hotelList_27_70884","hotelList_28_67292","hotelList_29_153504","hotelList_30_76923","hotelList_31_183095","hotelList_32_16693","hotelList_33_16443","hotelList_34_181339","hotelList_35_172986","hotelList_36_18195"]},"browse":{"items":[{"id":"","type":"room","provider":{"id":"146927","type":"hotel"}},{"id":"","type":"room","provider":{"id":"182439","type":"hotel"}},{"id":"","type":"room","provider":{"id":"158644","type":"hotel"}},{"id":"","type":"room","provider":{"id":"183095","type":"hotel"}},{"id":"","type":"room","provider":{"id":"72693","type":"hotel"}},{"id":"","type":"room","provider":{"id":"149360","type":"hotel"}},{"id":"","type":"room","provider":{"id":"104526","type":"hotel"}},{"id":"","type":"room","provider":{"id":"134763","type":"hotel"}},{"id":"","type":"room","provider":{"id":"128440","type":"hotel"}},{"id":"","type":"room","provider":{"id":"163087","type":"hotel"}},{"id":"","type":"room","provider":{"id":"178447","type":"hotel"}},{"id":"","type":"room","provider":{"id":"171943","type":"hotel"}},{"id":"","type":"room","provider":{"id":"177761","type":"hotel"}},{"id":"","type":"room","provider":{"id":"181785","type":"hotel"}},{"id":"","type":"room","provider":{"id":"40768","type":"hotel"}},{"id":"","type":"room","provider":{"id":"160939","type":"hotel"}},{"id":"","type":"room","provider":{"id":"176757","type":"hotel"}},{"id":"","type":"room","provider":{"id":"130025","type":"hotel"}},{"id":"","type":"room","provider":{"id":"182884","type":"hotel"}},{"id":"","type":"room","provider":{"id":"167519","type":"hotel"}},{"id":"","type":"room","provider":{"id":"71990","type":"hotel"}},{"id":"","type":"room","provider":{"id":"38282","type":"hotel"}},{"id":"","type":"room","provider":{"id":"149369","type":"hotel"}},{"id":"","type":"room","provider":{"id":"136808","type":"hotel"}},{"id":"","type":"room","provider":{"id":"178292","type":"hotel"}},{"id":"","type":"room","provider":{"id":"148000","type":"hotel"}},{"id":"","type":"room","provider":{"id":"70884","type":"hotel"}},{"id":"","type":"room","provider":{"id":"67292","type":"hotel"}},{"id":"","type":"room","provider":{"id":"153504","type":"hotel"}},{"id":"","type":"room","provider":{"id":"76923","type":"hotel"}},{"id":"","type":"room","provider":{"id":"183095","type":"hotel"}},{"id":"","type":"room","provider":{"id":"16693","type":"hotel"}},{"id":"","type":"room","provider":{"id":"16443","type":"hotel"}},{"id":"","type":"room","provider":{"id":"181339","type":"hotel"}},{"id":"","type":"room","provider":{"id":"172986","type":"hotel"}},{"id":"","type":"room","provider":{"id":"18195","type":"hotel"}}]}};
# </script>
# <script type="text/javascript">
# if(!rtp) var rtp = {};
# rtp.service = "dh";
#
# var abtest = {};
#
#
# 	var ds = {"actionPath":"search","areaName":"é£è¦","conditions":{"f_sort":["hotel"],"f_campaign":[""],"f_point_min":["0"],"f_page":["1"],"seo_f_chu":["okinawa"],"seo_f_shou":["nahashi"],"f_gcode":[""],"f_cd":[""],"f_dai":["japan"],"f_chu":["okinawa"],"f_shou":["nahashi"],"f_sai":[""],"f_latitude":["0.0"],"f_longitude":["0.0"],"f_km":[""],"f_squeezes":[],"f_rm_bed":[],"f_rm_type":[],"f_tab":["hotel"],"f_service":null},"displayedHotels":[146927,182439,158644,183095,72693,149360,104526,134763,128440,163087,178447,171943,177761,181785,40768,160939,176757,130025,182884,167519,71990,38282,149369,136808,178292,148000,70884,67292,153504,76923,16693,16443,181339,172986,18195],"facilityName":"","hotels":{},"isCamby":false,"isDated":false,"isHotelFixed":false,"isNearbySearch":false,"isSecret":false,"isShowCrossSearch":true,"isSqueezingCambyFlag":false,"narrowingArea":[],"rtcond":{"f_sort":["hotel"],"f_campaign":[""],"f_point_min":["0"],"f_gcode":[""],"f_cd":[""],"f_dai":["japan"],"f_chu":["okinawa"],"f_shou":["nahashi"],"f_sai":[""],"f_latitude":["0.0"],"f_longitude":["0.0"],"f_km":[""],"f_squeezes":[]},"rtcondex":{"dated":false,"f_tab":"hotel"},"totalResults":[416]};
#
# var searchHotelNo = "";
#
# if (!tags) var tags = {};
# if (!tags.data) tags.data = {};
# </script>
# <!--START_HEADER-->
# <span id="headerBannerAppDL"></span>
# <div class="rt-header">
# <ul class="rt-group-link">
# <li><a href="https://travel-smp.faq.rakuten.net/detail/000013745" target="_blank">æ°åã³ã­ãã¦ã¤ã«ã¹ã®å¯¾å¿ã«ã¤ãã¦</a></li>
# <li><a href="https://ad2.trafficgate.net/t/r/9091/1441/99636_99636/">ã«ã¼ã</a></li>
# <li><a href="https://gora.golf.rakuten.co.jp/?scid=wi_grp_gmx_trv_hetopbu_gra">GORA</a></li>
# <li><a href="https://www.rakuten.co.jp/">æ¥½å¤©å¸å ´</a></li>
# <!--/.rt-group-link--></ul>
# <div class="rt-service-bar">
# <div class="rt-site-id">
# <p class="rt-site-name"><a href="https://travel.rakuten.co.jp/">æ¥½å¤©ãã©ãã«</a></p>
# <p class="rt-outline">å®¿ã»èªç©ºå¸ã»ãã¢ã¼äºç´</p>
# <!--/.rt-site-id--></div>
# <div class="rt-promotion">
# <a id="rt-header-square-banner" href="#"><img src="https://img.travel.rakuten.co.jp/share/images/null.gif" width="170" height="53" alt="" border="0"></a>
# <!--/.rt-promotion --></div>
# <div class="rt-utility">
# <ul class="rt-help-link">
# <li><a href="https://travel.rakuten.co.jp/howto/">æ¥½å¤©ãã©ãã«ã®ä½¿ãæ¹</a></li>
# <li><a href="https://travel.rakuten.co.jp/sitemap/">ãµã¤ãããã</a></li>
# <li><a href="https://travel.faq.rakuten.net/">ãã«ã</a></li>
# <li class="rt-lang-link"><a id="rt-lang-link-a" href="javascript:void(0);">Languages</a>
#   <ul id="rt-lang-box" style="display: none;">
#   <li><a id="lnkEnglish" href="https://travel.rakuten.com/"><span>English</span></a></li>
#   <li><a id="lnkKorea" href="https://travel.rakuten.co.kr/"><span>&#xB300;&#xD55C;&#xBBFC;&#xAD6D;(&#xD55C;&#xAD6D;&#xC5B4;)</span></a></li>
#   <li><a id="lnkTaiwanese" href="https://travel.rakuten.com.tw/"><span>&#x53F0;&#x7063;(&#x7E41;&#x9AD4;&#x4E2D;&#x6587;)</span></a></li>
#   <li><a id="lnkHonkKong" href="https://travel.rakuten.com.hk/"><span>&#x9999;&#x6E2F;(&#x7E41;&#x9AD4;&#x4E2D;&#x6587;)</span></a></li>
#   <li><a id="lnkChinese" href="https://travel.rakuten.cn/"><span>&#x4E2D;&#x56FD;(&#x7B80;&#x4F53;&#x4E2D;&#x6587;)</span></a></li>
#   <li><a id="lnkThai" href="https://travel.rakuten.co.th/"><span>&#xE1B;&#xE23;&#xE30;&#xE40;&#xE17;&#xE28;&#xE44;&#xE17;&#xE22; (&#xE20;&#xE32;&#xE29;&#xE32;&#xE44;&#xE17;&#xE22;)</span></a></li>
#   </ul>
# </li>
# </ul>
#
# <div class="rt-mytrv">
# <a href="https://auth.travel.rakuten.co.jp/fwd/memberDispatcher/staticPageLogin?service_id=t01&return_url=cgi-bin/rakuten_id_reference&_guestLoginServiceKey=guestReservation&f_next_url=https://mypage.travel.rakuten.co.jp/">äºç´ã®ç¢ºèªã»ã­ã£ã³ã»ã«</a>
# <!--/.rt-mytrv--></div>
#
# <div id="rt-notification-container" class="rt-notification-btn-box" style="display:none;">
#   <button class="rt-notification-btn" id="notificationButton">
#     ãç¥ãã
#   <!--/.rt-notification--></button>
#   <span class="rt-count-badge" id="notificationBadge" style="display:none;">0</span>
# </div>
#
# <div id="pbox-container">
#   <script type="text/x-jquery-tmpl" id="pbox-member">
#   <div class="rt-member-notification">
#   <dl class="rt-member">
#   <dt class="rt-member-${body.userRank}"><span>ãããã</span><a href="https://my.travel.rakuten.co.jp/mytravel/"><b>${body.name}</b>ãã</a></dt>
#   <dd><b>${body.totalPoint}</b>ãã¤ã³ã</dd>
#   </dl>
#   </div>
#   <div id="rt-btn-info" class="rt-btn-info">
#   <a href="#">ä¼å¡æå ±</a>
#   <!--/.rt-btn-info--></div>
#
#   <!-- member detail -->
#   <div id="memberDetail">
#
#   <!-- detailMenu -->
#   <div class="detailMenu">
#   <ul id="menuTab"><!--
#   --><li class="memberMenu open">ä¼å¡æå ±</li><!--
#   --><li class="serviceMenu">é¢é£ãµã¼ãã¹</li><!--
#   --></ul><!--
#   --><div class="close">éãã</div>
#   </div>
#   <!-- /detailMenu -->
#
#   <!-- statusInfo -->
#   <div id="statusInfo">
#   <div id="loginForm" class="${body.userRank}">
#   <div class="loginStatus" id="loginStatus">
#   <p class="user-name">ããããã<a href="https://my.travel.rakuten.co.jp/mytravel/"><span>${body.name}</span>ãã</a></p>
#   <p class="member-rank">ããªãã¯<em>${body.kaiinRank}</em></p>
#
#   <div class="pointInfo">
#   {{if body.loadPrivateFile}}
#   <p class="invitation"><a href="${body.loadPrivateFile}"><img width="20" hspace="2" height="24" border="0" style="vertical-align:middle;" src="https://img.travel.rakuten.co.jp/share/themes/top/images/env_anime.gif" alt="ç¹å¥ãæå¾">ç¹å¥ãæå¾</a></p>
#   {{/if}}
#   <p class="point">ç¾å¨ã®ä¿æãã¤ã³ã<em>${body.totalPoint}ãã¤ã³ã</em>
#   {{if body.limitedTermPoint != 0}}
#   <span class="limit">ãã¡ãæééå®ãã¤ã³ã: ${body.limitedTermPoint}ãã¤ã³ã</span>
#       {{if body.pointrCash != 0 }}
#           <span class="note">æ¥½å¤©ã­ã£ãã·ã¥ ${rtl.widget.pbox.viewHelper.numSeparate3Format(body.pointrCash)} å</span>
#       {{/if}}
#   {{else  body.pointrCash != 0 }}
#   <span class="cash">ãã¡ãæ¥½å¤©ã­ã£ãã·ã¥ ${rtl.widget.pbox.viewHelper.numSeparate3Format(body.pointrCash)} å</span>
#   {{/if}}
#   </p>
#   <!-- /pointInfo --></div>
#   <!-- /loginStatus --></div>
#
#   <div class="btn-point"><a href="https://travel.rakuten.co.jp/point/">æ¥½å¤©ãã¤ã³ãã«ã¤ãã¦</a><!-- /.btn-point --></div>
#   <ul class="link">
#   <li><a href="https://coupon.rakuten.co.jp/myCoupon">ç²å¾æ¸ã¿ã®ã¯ã¼ãã³</a><img src="https://img.travel.rakuten.co.jp/share/themes/top/images/icon_new.gif"></li>
#   </ul>
#
#   <div class="btn-confirm">
#   <a href="https://auth.travel.rakuten.co.jp/fwd/memberDispatcher/staticPageLogin?service_id=t01&return_url=cgi-bin/rakuten_id_reference&_guestLoginServiceKey=guestReservation&f_next_url=https://mypage.travel.rakuten.co.jp/">äºç´ã®ç¢ºèªã»å¤æ´ã»åæ¶</a>
#   <!-- /.btn-confirm --></div>
#   <div class="btn-change">
#   <a href="https://auth.travel.rakuten.co.jp/fwd/memberDispatcher/staticPageLogin?service_id=t01&return_url=cgi-bin/rakuten_id_reference&f_next_url=https://aps1.travel.rakuten.co.jp/portal/my/rakuten_kaiin_supplement.main?f_henkou_flg=HENKOU">ç»é²åå®¹å¤æ´</a>
#   <!-- /.btn-change --></div>
#
#   <!-- /loginForm --></div>
#
#   <div class="btn-logout"><a href="https://auth.travel.rakuten.co.jp/fwd/omniLogout">ã­ã°ã¢ã¦ã</a><!-- /.btn-logout --></div>
#   </div><!-- /div#statusInfo -->
#
#   <div id="serviceInfo">
#   <p class="title">æ¥½å¤©ã°ã«ã¼ãã®ãµã¼ãã¹</p>
#   <ul class="serviceList"><!--
#   --><li><a href="https://www.rakuten.co.jp/"><span>æ¥½å¤©å¸å ´</span></a></li><!--
#   --><li><a href="https://www.rakuten-card.co.jp/smart/"><span>æ¥½å¤©ã«ã¼ã</span></a></li><!--
#   --><li><a href="https://books.rakuten.co.jp/"><span>æ¥½å¤©ããã¯ã¹</span></a></li><!--
#   --><li><a href="https://auction.rakuten.co.jp/"><span>æ¥½å¤©ãªã¼ã¯ã·ã§ã³</span></a></li><!--
#   --><li><a href="https://sp.rakuten-edy.co.jp/"><span>æ¥½å¤©Edy</span></a></li><!--
#   --><li><a href="https://www.rakuten-bank.co.jp/smartphone/index.html"><span>æ¥½å¤©éè¡</span></a></li><!--
#   --><li><a href="https://gora.golf.rakuten.co.jp/smart/iphone_top.html"><span>æ¥½å¤©GORA</span></a></li><!--
#   --><li><a href="https://www.rakuten-sec.co.jp/smartphone/"><span>æ¥½å¤©è¨¼å¸</span></a></li><!--
#   --><li><a href="https://www.rakuten.co.jp/sitemap/sp/"><span>æ¥½å¤©ãµã¼ãã¹ä¸è¦§</span></a></li><!--
#   --><li><a href="https://www.rakuten.co.jp/sitemap/spapp/"><span>æ¥½å¤©ã¢ããªä¸è¦§</span></a></li><!--
#   --></ul><!-- /.serviceLst -->
#   <!-- /div#serviceInfo --></div>
#   <!-- /member detail --></div>
#   </script>
#
#   <script type="text/x-jquery-tmpl" id="pbox-nologin">
#   <dl class="rt-nologin">
#   <dt>ãããããæ¥½å¤©ãã©ãã«ã¸</dt>
#   <dd><ul>
#       <li class="rt-btn-register"><a href="https://travel.rakuten.co.jp/kaiin.html">ä¼å¡ç»é²</a></li>
#       <li class="rt-btn-login"><a href="${body.redirect}">ã­ã°ã¤ã³</a></li>
#   </ul></dd>
#   </dl>
#   </script>
# </div>
#
# <!--/.rtUtility--></div>
# <!--/.rt-service-bar--></div>
# <dl class="rt-nav-link">
# <dt><a id="rt-nav-link-a" href="#">ã¡ãã¥ã¼</a></dt>
# <dd><ul id="rt-nav-box" class="rt-hide" >
# <li class="rt-nav-active"><a href="https://travel.rakuten.co.jp/?l-id=top_navi_dh">å½åæè¡</a></li>
# <li class=" rt-nav-down"><a href="https://travel.rakuten.co.jp/package/?l-id=top_navi_dp">å½åãã¢ã¼</a>
#   <ul class="rt-nav-secondary">
#   <li><a href="https://travel.rakuten.co.jp/package/ana/?l-id=top_navi_dp_ana">ANAæ¥½ããã¯ï¼èªç©ºå¸ï¼å®¿ï¼</a></li>
#   <li><a href="https://travel.rakuten.co.jp/package/jal/?l-id=top_navi_dp_jal">JALæ¥½ããã¯ï¼èªç©ºå¸ï¼å®¿ï¼</a></li>
#   </ul>
# </li>
# <li class=""><a href="https://travel.rakuten.co.jp/cars/?scid=wi_trv_top_navi_car">ã¬ã³ã¿ã«ã¼</a></li>
# <li class=""><a href="https://travel.rakuten.co.jp/bus/?scid=wi_trv_top_navi_bus">é«éãã¹ã»ãã¹ãã¢ã¼</a></li>
# <li class=""><a href="https://travel.rakuten.co.jp/kaigai/?scid=wi_trv_top_navi_kaigai">æµ·å¤æè¡</a></li>
# <li class=""><a href="https://experiences.travel.rakuten.co.jp/?scid=wi_txp_trv_pc-nav">éã³ã»ä½é¨</a></li>
# <li class=""><a href="https://camp.travel.rakuten.co.jp/?scid=wi_trv_top_navi_camp">ã­ã£ã³ãå ´</a></li>
# <li class=""><a href="https://travel.rakuten.co.jp/coupon/?l-id=top_navi_coupon">å²å¼ã¯ã¼ãã³</a></li>
# <li class=""><a href="https://travel.rakuten.co.jp/special/furusato/?l-id=top_navi_furusato">ãµããã¨ç´ç¨</a></li>
# <li class=""><a href="https://travel.rakuten.co.jp/mytrip/?scid=wi_trv_top_navi_guide">æè¡ã¬ã¤ã</a></li>
# </ul></dd>
# <!--/.rt-nav-link--></dl>
# <!--ds-->
# <div id="widgetPointupBannerRef"></div>
# <!--/.rt-header--></div>
# <div id="widgetPointupModalRef" data-ratid="Point_Banner" data-ratevent="appear" data-ratparam="all"></div>
#
# <input type="hidden" id="rt-service-hidden" value="domestic-travel">
# <!--END_HEADER-->
# <div id="wideEventBanner" style="display:none;">
# </div>
# <div id="srchContents" class="htlList">
# <!-- ****ãã³ããéå§**** -->
# <p id="srchBrdCrmbs">
# 		<a href="//travel.rakuten.co.jp/">æ¥½å¤©ãã©ãã«ããã</a>&nbsp;&gt;
# 				<span class="grpLocationLocus"><a href="//travel.rakuten.co.jp/yado/japan.html">å¨å½</a></span>&nbsp;&gt;&nbsp;
# 							<span class="grpLocationLocus"><a href="//travel.rakuten.co.jp/yado/okinawa/map.html">æ²ç¸ç</a></span>
#
# 								&nbsp;&gt;&nbsp;
# 								é£è¦</p>
# <!-- ****ãã³ããçµäº**** --><h1 id="seoTtl">
# 					<span>é£è¦&nbsp;</span>ããã«ã»æé¤¨
# 				</h1>
# 			<div id="contentInner">
# 	<div id="srchMainContent">
# 	<!-- New Tab  start -->
#
# <input type="hidden" id="abTestForDAPLink" value="471_Link_A" />
# <script type="text/javascript">
# 	var abTestForDAPLink = getABPatternForDAPLink();
# 	tags.data.page.abTestName = "trvab_2";
# 	tags.data.page.patternNumber = abTestForDAPLink;
#
# 	document.getElementById("abTestForDAPLink").value = abTestForDAPLink;
#
# 	function getABPatternForDAPLink() {
# 		var Rpstr = "";
# 		var name = "Rp" + "=";
# 		var cookies = document.cookie.split(';');
# 		if(cookies == null || cookies.length == 0) {
# 			return "471_Link_A";
# 		}
# 		for(var i=0; i<cookies.length; i++) {
# 			var c = cookies[i].trim();
# 			if (c.indexOf(name)==0) {
# 				Rpstr = c.substring(name.length,c.length);
# 				var result;
# 				var reg = /[a-zA-Z]+/;
# 				while (result = Rpstr.match(reg)) {
# 					Rpstr = Rpstr.replace(result[0], '');
# 				}
# 			}
# 		}
# 		if (!(Rpstr == null || Rpstr.length < 2)) {
# 			var checkNumber = parseInt(Rpstr.substring(Rpstr.length-2));
# 			if (checkNumber < 30) {
# 				return "471_Link_B";
# 			} else {
# 				return "471_Link_A";
# 			}
# 		}
# 		return "471_Link_A";
# 	}
# </script>
#
# <div id="listTab" class="section bleeding">
# 	<div class="sectionContent">
# 		<div style="display: none;" id="freqCap_pushdown">
# 			<div class="pushdownContainer" id="pushdownContainer">
# 				<div class="ad">
# 				</div>
# 			</div>
# 		</div>
# 		<div class="linebreak"></div>
# 		<div class="sectionColumns">
# 			<div class="gridPanel grid12">
# 				<div class="tabs">
# 					<ul>
# 						<li id="tabHtl" tns="no" class="current"><a>æ½è¨­ãã¨ã«è¡¨ç¤º</a></li>
# 						<li id="tabMap" tns="no">
# 									<a href="//search.travel.rakuten.co.jp/ds/undated/search?f_dai=japan&amp;f_chu=okinawa&amp;f_shou=nahashi&amp;f_latitude=0.0&amp;f_longitude=0.0&amp;f_sort=hotel&amp;f_page=1&amp;f_hyoji=30&amp;f_image=1&amp;f_tab=map&amp;f_point_min=0">
# 										å°å³ä¸ã«è¡¨ç¤º
# 									</a></li>
# 							</ul>
# 					<p id="dapLink" class="dpsearch__links" style="display: none;">
# 						<span class="dpsearch__links-label">ããã±ã¼ã¸ã§æ¤ç´¢</span>
# 						<a class="dpsearch__links-item" href="https://travel.rakuten.co.jp/package/ana/?l-id=471_ANA">
# 							<img src="https://trvimg.r10s.jp/share/common/images/icon_ana.svg" alt="ANA" width="44" height="12">èªç©ºå¸+å®¿æ³</a>
# 						<a class="dpsearch__links-item" href="https://travel.rakuten.co.jp/package/jal/?l-id=471_JAL">
# 							<img src="https://trvimg.r10s.jp/share/common/images/icon_jal.svg" alt="JAL" width="44" height="12">èªç©ºå¸+å®¿æ³</a>
# 					</p>
# 					<p class="attension">
# 					</p>
# 					</div>
# 			</div>
# 		</div>
# 	</div>
# </div>
# <!-- New Tab  end -->
# <input type="hidden" id="hotelNos" value="146927,182439,158644,183095,72693,149360,104526,134763,128440,163087,178447,171943,177761,181785,40768,160939,176757,130025,182884,167519,71990,38282,149369,136808,178292,148000,70884,67292,153504,76923,16693,16443,181339,172986,18195" />
# 	<input type="hidden" id="hotelPlanList" value='' />
# 	<input type="hidden" id="actionPath" value="search" />
# 	<input type="hidden" id="servicePath" value="undated" />
# 	<input type="hidden" id="fTab" value="hotel" />
# 	<input type="hidden" id="pageType" value="dateSearch" />
# 	<input type="hidden" id="squeezes" value="" />
# 	<input type="hidden" id="teikei" value="" />
# 	<input type="hidden" id="isOEM" value="0" />
# 	<input type="hidden" id="isHojin" value="0" />
# 	<input type="hidden" id="f_service" value="" />
# 	<input type="hidden" data-onetag-array-num data-onetag-name="hotelid" value="146927,182439,158644" />
# <input type="hidden" data-onetag-num data-onetag-name="checkin" value="" />
# <input type="hidden" data-onetag-num data-onetag-name="checkout" value="" /><!--sort-->
# <dl id="srtSwtch">
# 	<dt>ä¸¦ã³ãã ï¼ </dt>
# 			<dd><span>ããããé </span></dd>
# 				<dd>
# 						<a href="https://search.travel.rakuten.co.jp/ds/yado/okinawa/nahashi-low">æéã®å®ãé </a></dd>
# 				<dd>
# 						<a href="https://search.travel.rakuten.co.jp/ds/yado/okinawa/nahashi-high">æéã®é«ãé </a></dd>
# 				<dd>
# 						<a href="https://search.travel.rakuten.co.jp/ds/yado/okinawa/nahashi-review">è©ä¾¡ãé«ãé </a></dd>
# 				</dl>
#
# <!--/sort--><!--**************paging start**************-->
# <div class="paging">
#     <p class="pagingTitle"><span><em>416</em>ä»¶ä¸­</span>1ï½30ä»¶è¡¨ç¤º</p><ul class="pagingNumber"><li class="pagingTo">[ <span class="pagingActive">1</span> | <a href="https://search.travel.rakuten.co.jp/ds/yado/okinawa/nahashi-p2">2</a> | <a href="https://search.travel.rakuten.co.jp/ds/yado/okinawa/nahashi-p3">3</a> | <a href="https://search.travel.rakuten.co.jp/ds/yado/okinawa/nahashi-p4">4</a> | <a href="https://search.travel.rakuten.co.jp/ds/yado/okinawa/nahashi-p5">5</a> ï½¥ï½¥ï½¥ ]</li><li class="pagingBack"><a href="https://search.travel.rakuten.co.jp/ds/yado/okinawa/nahashi-p2">æ¬¡ã®30ä»¶</a></li></ul><div class="paging" style="float:right; display:inline-block">
#         <img class="preferredSparklePagingPc" src="https://img.travel.rakuten.co.jp/share/themes/ds/images/Sparkle_final.png">
#         <a class="preferredExplanation" href="https://travel.faq.rakuten.net/detail/000015657" style="color: #1D52A5;">ããªãã¡ã¼ãADã¨ã¯</a>
#     </div>
# </div>
# <!--**************paging end**************--><link type="text/css" rel="stylesheet" href="https://trv.r10s.jp/share/themes/ds/css/trvl_srch_undtd_page_v2.css?_=20211029" media="screen">
# <script type="text/javascript">
# <!--
# 	var cks = document.cookie.split(',');
# 	var ckname = "Rp";
# 	var rpv = "99";
# 	var pattern = "";
#
# 	// Confirm Rp value
# 	if (cks && cks.length > 0) {
# 		// find Rp value from Cookies
# 		for(var i = 0; i < cks.length; i++) {
# 			var c = cks[i];
# 			while (c.charAt(0) == ' ') {
# 				c = c.substring(1);
# 			}
# 			// Rp is set in Cookie
# 			if (c.indexOf(ckname) >= 0) {
# 				// Get value between "Rp=" and ";"
# 				var sep = c.indexOf(";", c.indexOf(ckname));
# 				if (sep >= 0) {
# 					rpv = c.substring(c.indexOf(ckname) + ckname.length + 1, sep);
# 				} else {
# 					rpv = c.substring(c.indexOf(ckname) + ckname.length + 1, c.length);
# 				}
# 				// Get last 2 digits
# 				rpv = rpv.replace(/[^0-9]/g, '');
# 				rpv = rpv.substring(rpv.length - 2);
# 				// set back to DEFAULT
# 				if (!rpv || rpv.length != 2) {
# 					rpv = "99";
# 				}
# 				break;
# 			}
# 		}
# 	}
#
# 	// Append RAT tag
# 	pattern = parseInt(rpv) < 10 ? "[PR]" : "[æ³¨ç®]";
# 	if (!tags) var tags = {};
# 	if (!tags.data) tags.data = {};
# 	tags.data.ratabtest = {
# 		"name": "lad",
# 		"pattern": pattern
# 	};
# -->
# </script>
# <!--hotel list-->
# <input type="hidden" id="cassetteCount" value="dateSearch_a-30:c-0:p-0:e-0" />
# <ul id="htlBox" class="htlList" style="visibility: hidden">
# 	<li id="146927_list" class="listing" data-ratid="hotelList_ad_L000002979_1_146927" data-ratevent="appear" data-ratparam="all" >
# 	<section>
#
#         <div class="pr_icon">
#             PR
#         </div>
#         <div class="htlHead">
#         <div class="photo">
# 	  	<div class="htlImgWrp">
# 	    <a id="146927_gaikanlisting" href="javascript:void(0)" class="htlImg" data-ratId="hotelList_ad_L000002979_1_146927_photoClick" data-ratEvent="click" data-ratParam="all" >
# 	    	<span id="thumbnail_146927_listing" video-id="" class="thumbnail"><img src="https://trvimg.r10s.jp/share/image_up/146927/origin/0b0fa54d113a402287846d1b4147ecb67cea1e4d.47.9.26.3.jpg?fit=inside|900:507&interpolation=lanczos-none" alt=""></span>
# 				</a>
#         </div>
# 	    <a href="" class="thickbox btn360dgr 146927-pano" id="146927-panorama" style="display:none;" data-lid="dateSearchC_cassette_panorama_8_pg1"><span>360ãã¥ã¼</span></a>
# 	    <!--/.photo-->
#     </div>
#
#     <div class="info">
#     <p class="area">
#     é£è¦</p>
# 	<h1 class=""><a href="https://travel.rakuten.co.jp/HOTEL/146927/146927.html?l-id=hotelList_ad_L000002979_1_146927" >ããã«ã¢ãã¹ãé£è¦å½ééã</a>
#                 <span class="preferred_sparkle_none"><img src="https://img.travel.rakuten.co.jp/share/themes/ds/images/Sparkle_final16x16.png"><span class="preferred_sparkletext">ãã¡ãã®å®¿æ³æ½è¨­ã¯ãå®¿æ³èããã®ç·åè©ä¾¡ç¹æ°ãé«ãããããã¯å¤ãã®å®¿æ³å®ç¸¾ãããç­ã®ç¬èªã®æ¡ä»¶ãæºãããããªãã¡ã¼ããã­ã°ã©ã åå æ½è¨­ã§ããæ¥½å¤©ãã©ãã«ã¸ãµã¼ãã¹å©ç¨æãæ¯æããã¨ã«ãããåååæ¡ä»¶ã®ä»ã®æ½è¨­ãããä¸ä½ã«è¡¨ç¤ºããã¦ãã¾ããï¼ãã«ããã¼ã¸åç§ï¼</span></span>
#             </h1>
# 		<p class="htlPrice">
#     		[æå®æé]
# 			<span>3,055åã</span><span class="incldTax">ï¼æ¶è²»ç¨è¾¼3,360åãï¼</span></p>
#     <p class="cstmrEvl">
#     <a id="146927_review" href="https://travel.rakuten.co.jp/HOTEL/146927/review.html?l-id=hotelList_ad_L000002979_1_146927">
# 			<span class="starfourHlf"></span>
# 				<strong>4.13</strong>
#
# 			[ãå®¢ãã¾ã®å£°ï¼526ä»¶ï¼]
# 		</a>
#     </p>
# 		<p class="htlSpecial">å½ééãå¾æ­©ï¼åã®æé«ç«å°âå°åä¸çªã®æ¥å®¢ãµã¼ãã¹ãç®æãã¾ãâæã¯å¤§å¥½è©ããã¾ï½ï¼ãæ¯ããï¼æä½ãã®æ²ç¸æçãã©ããâª</p>
# 		<div class="tagwrp_v2">
#             <p class="hometown_icon"><img src="https://trvimg.r10s.jp/share/common/images/label_hometown_tax.svg"></p>
#             <div class="othrIndIcons 146927_link_couponlisting event_146927">
#                 <ul>
#                     <input type="hidden" id="146927_link_coupon_hotelNolisting" value="146927" />
#                 </ul>
#             </div>
# 		</div>
#     <!--/.info--></div>
#     </div>
#     <p class="htlAccess">
#            ã900-0015ãæ²ç¸çé£è¦å¸ä¹èå°3-1-10<a href="//travel.rakuten.co.jp/share/gmap/map.html?f_longitude=127.6807344&f_latitude=26.2140234&TB_iframe=true&height=450&width=600" class="thickbox" title="ããã«ã¢ãã¹ãé£è¦å½ééã" data-ratId="hotelList_ad_L000002979_1_146927_mapClick" data-ratEvent="click" data-ratParam="all">[å°å³ãè¦ã]</a>
#     </p>
#     <p class="htlInfo">ã¢ã¯ã»ã¹ãï¼ããã¬ã¼ã«ï¼ã¢ãã¬ã¼ã«ï¼ãçåºåãé§ããå¾æ­©ï¼åãé£è¦ç©ºæ¸¯ããè»ã§ç´15å<br>
#         é§è»å ´ããï¼ææºé§è»å ´ã1,000å/æ³ãå¥åºåº«1æ³1åéã24æã6æå¥åºåº«ä¸å¯ãè©³ç´°ãåãåããä¸ããã</p>
# 	<ul class="btnUndtd">
# 		<li><a href="//hotel.travel.rakuten.co.jp/hotelinfo/plan/146927?f_teikei=&l-id=hotelList_ad_L000002979_1_146927"><span>å®¿æ³ãã©ã³ä¸è¦§</span></a></li>
# 			<li><a id="RM_DP_PLAN_146927" class="dplkn" hotel_no="146927" href="javascript:void(0)" data-ratId="hotelList_ad_L000002979_1_146927_dpPlanClick" data-ratEvent="click" data-ratParam="all"><span>èªç©ºå¸ä»ãã©ã³ä¸è¦§</span></a></li>
# 		</ul>
#     </section>
#
#     <div class="photoPrnt">
#     	<div class="photoBox" id="146927-photo-contents" style="display: none; opacity: 0; z-index:">
#     		<p class="photoCls"><a class="closePhotoBox" href="javascript:void(0);"  photoBoxId="146927-photo-contents">éãã</a></p>
#     		<ul>
#     		<li class="photoStck" id="photo-146927-0"></li>
#     		<li class="photoStck" id="photo-146927-1"></li>
#     		<li class="photoStck" id="photo-146927-2"></li>
#     		<li class="photoStck" id="photo-146927-3"></li>
#     		<li class="photoStck" id="photo-146927-4"></li>
#     		<li class="photoStck" id="photo-146927-5"></li>
#     		</ul>
# 			<p class="morePix"><a href="https://travel.rakuten.co.jp/HOTEL/146927/gallery.html">ãã£ã¨è¦ã</a></p>
#     <!--/.photoBox-->
#     	</div>
#     <!--/.photoPrnt-->
#     </div>
# </li>
#
# <li id="182439_list" class="listing" data-ratid="hotelList_ad_L000002979_2_182439" data-ratevent="appear" data-ratparam="all" >
# 	<section>
#
#         <div class="pr_icon">
#             PR
#         </div>
#         <div class="htlHead">
#         <div class="photo">
# 	  	<div class="htlImgWrp">
# 	    <a id="182439_gaikanlisting" href="javascript:void(0)" class="htlImg" data-ratId="hotelList_ad_L000002979_2_182439_photoClick" data-ratEvent="click" data-ratParam="all" >
# 	    	<span id="thumbnail_182439_listing" video-id="" class="thumbnail"><img src="https://trvimg.r10s.jp/share/image_up/182439/origin/c2cbee2f34315ad59baeaa1d99492a21377860bc.47.9.26.3.jpg?fit=inside|900:507&interpolation=lanczos-none" alt=""></span>
# 				</a>
#         </div>
# 	    <a href="" class="thickbox btn360dgr 182439-pano" id="182439-panorama" style="display:none;" data-lid="dateSearchC_cassette_panorama_8_pg1"><span>360ãã¥ã¼</span></a>
# 	    <!--/.photo-->
#     </div>
#
#     <div class="info">
#     <p class="area">
#     é£è¦</p>
# 	<h1 class=""><a href="https://travel.rakuten.co.jp/HOTEL/182439/182439.html?l-id=hotelList_ad_L000002979_2_182439" >ãã¹ãããã«é£è¦ä¹èå°</a>
#                 <span class="preferred_sparkle_none"><img src="https://img.travel.rakuten.co.jp/share/themes/ds/images/Sparkle_final16x16.png"><span class="preferred_sparkletext">ãã¡ãã®å®¿æ³æ½è¨­ã¯ãå®¿æ³èããã®ç·åè©ä¾¡ç¹æ°ãé«ãããããã¯å¤ãã®å®¿æ³å®ç¸¾ãããç­ã®ç¬èªã®æ¡ä»¶ãæºãããããªãã¡ã¼ããã­ã°ã©ã åå æ½è¨­ã§ããæ¥½å¤©ãã©ãã«ã¸ãµã¼ãã¹å©ç¨æãæ¯æããã¨ã«ãããåååæ¡ä»¶ã®ä»ã®æ½è¨­ãããä¸ä½ã«è¡¨ç¤ºããã¦ãã¾ããï¼ãã«ããã¼ã¸åç§ï¼</span></span>
#             </h1>
# 		<p class="htlPrice">
#     		[æå®æé]
# 			<span>2,591åã</span><span class="incldTax">ï¼æ¶è²»ç¨è¾¼2,850åãï¼</span></p>
#     <p class="cstmrEvl">
#     <a id="182439_review" href="https://travel.rakuten.co.jp/HOTEL/182439/review.html?l-id=hotelList_ad_L000002979_2_182439">
# 			<span class="starfive"></span>
# 				<strong>4.65</strong>
#
# 			[ãå®¢ãã¾ã®å£°ï¼99ä»¶ï¼]
# 		</a>
#     </p>
# 		<p class="htlSpecial">ãªã·ã£ã¬ãªããã«ã«å¤å½©ãªãé¨å±ããç¨æãã¾ããããã¡ããªã¼ããå¤«å©¦ãã«ããã«ãã1äººæ§ã§ã®ãå©ç¨ã«ãæé©ãªããã«ã§ãã</p>
# 		<div class="tagwrp_v2">
#             <p class="hometown_icon"><img src="https://trvimg.r10s.jp/share/common/images/label_hometown_tax.svg"></p>
#             <div class="othrIndIcons 182439_link_couponlisting event_182439">
#                 <ul>
#                     <input type="hidden" id="182439_link_coupon_hotelNolisting" value="182439" />
#                 </ul>
#             </div>
# 		</div>
#     <!--/.info--></div>
#     </div>
#     <p class="htlAccess">
#            ã900-0015ãæ²ç¸çé£è¦å¸ä¹èå°2-22-5<a href="//travel.rakuten.co.jp/share/gmap/map.html?f_longitude=127.6822461&f_latitude=26.2195155&TB_iframe=true&height=450&width=600" class="thickbox" title="ãã¹ãããã«é£è¦ä¹èå°" data-ratId="hotelList_ad_L000002979_2_182439_mapClick" data-ratEvent="click" data-ratParam="all">[å°å³ãè¦ã]</a>
#     </p>
#     <p class="htlInfo">ã¢ã¯ã»ã¹ãï¼ããã¬ã¼ã«ç¾æ æ©é§ããå¾æ­©ï¼åï¼é£è¦ç©ºæ¸¯ãããè»ã«ã¦ç´ï¼ï¼å<br>
#         é§è»å ´ããï¼æãã40å°ã1500å/1æ¥ãäºç´ä¸è¦</p>
# 	<ul class="btnUndtd">
# 		<li><a href="//hotel.travel.rakuten.co.jp/hotelinfo/plan/182439?f_teikei=&l-id=hotelList_ad_L000002979_2_182439"><span>å®¿æ³ãã©ã³ä¸è¦§</span></a></li>
# 			<li><a id="RM_DP_PLAN_182439" class="dplkn" hotel_no="182439" href="javascript:void(0)" data-ratId="hotelList_ad_L000002979_2_182439_dpPlanClick" data-ratEvent="click" data-ratParam="all"><span>èªç©ºå¸ä»ãã©ã³ä¸è¦§</span></a></li>
# 		</ul>
#     </section>
#
#     <div class="photoPrnt">
#     	<div class="photoBox" id="182439-photo-contents" style="display: none; opacity: 0; z-index:">
#     		<p class="photoCls"><a class="closePhotoBox" href="javascript:void(0);"  photoBoxId="182439-photo-contents">éãã</a></p>
#     		<ul>
#     		<li class="photoStck" id="photo-182439-0"></li>
#     		<li class="photoStck" id="photo-182439-1"></li>
#     		<li class="photoStck" id="photo-182439-2"></li>
#     		<li class="photoStck" id="photo-182439-3"></li>
#     		<li class="photoStck" id="photo-182439-4"></li>
#     		<li class="photoStck" id="photo-182439-5"></li>
#     		</ul>
# 			<p class="morePix"><a href="https://travel.rakuten.co.jp/HOTEL/182439/gallery.html">ãã£ã¨è¦ã</a></p>
#     <!--/.photoBox-->
#     	</div>
#     <!--/.photoPrnt-->
#     </div>
# </li>
#
# <li id="158644_list" class="listing" data-ratid="hotelList_ad_L000002979_3_158644" data-ratevent="appear" data-ratparam="all" >
# 	<section>
#
#         <div class="pr_icon">
#             PR
#         </div>
#         <div class="htlHead">
#         <div class="photo">
# 	  	<div class="htlImgWrp">
# 	    <a id="158644_gaikanlisting" href="javascript:void(0)" class="htlImg" data-ratId="hotelList_ad_L000002979_3_158644_photoClick" data-ratEvent="click" data-ratParam="all" >
# 	    	<span id="thumbnail_158644_listing" video-id="" class="thumbnail"><img src="https://trvimg.r10s.jp/share/image_up/158644/origin/2c14024f0c124051b2cc427e34ea985c70e7b881.47.9.26.3.jpg?fit=inside|900:507&interpolation=lanczos-none" alt=""></span>
# 				</a>
#         </div>
# 	    <a href="" class="thickbox btn360dgr 158644-pano" id="158644-panorama" style="display:none;" data-lid="dateSearchC_cassette_panorama_8_pg1"><span>360ãã¥ã¼</span></a>
# 	    <!--/.photo-->
#     </div>
#
#     <div class="info">
#     <p class="area">
#     é£è¦</p>
# 	<h1 class=""><a href="https://travel.rakuten.co.jp/HOTEL/158644/158644.html?l-id=hotelList_ad_L000002979_3_158644" >ã¢ãã¹ãï¼£ï¼µï¼¢ï¼¥é£è¦å½ééãã¼å¨å®¤éµä»ãã­ã£ãã³åããã«ã¼</a>
#                 <span class="preferred_sparkle_none"><img src="https://img.travel.rakuten.co.jp/share/themes/ds/images/Sparkle_final16x16.png"><span class="preferred_sparkletext">ãã¡ãã®å®¿æ³æ½è¨­ã¯ãå®¿æ³èããã®ç·åè©ä¾¡ç¹æ°ãé«ãããããã¯å¤ãã®å®¿æ³å®ç¸¾ãããç­ã®ç¬èªã®æ¡ä»¶ãæºãããããªãã¡ã¼ããã­ã°ã©ã åå æ½è¨­ã§ããæ¥½å¤©ãã©ãã«ã¸ãµã¼ãã¹å©ç¨æãæ¯æããã¨ã«ãããåååæ¡ä»¶ã®ä»ã®æ½è¨­ãããä¸ä½ã«è¡¨ç¤ºããã¦ãã¾ããï¼ãã«ããã¼ã¸åç§ï¼</span></span>
#             </h1>
# 		<p class="htlPrice">
#     		[æå®æé]
# 			<span>2,728åã</span><span class="incldTax">ï¼æ¶è²»ç¨è¾¼3,000åãï¼</span></p>
#     <p class="cstmrEvl">
#     <a id="158644_review" href="https://travel.rakuten.co.jp/HOTEL/158644/review.html?l-id=hotelList_ad_L000002979_3_158644">
# 			<span class="starfourHlf"></span>
# 				<strong>4.38</strong>
#
# 			[ãå®¢ãã¾ã®å£°ï¼211ä»¶ï¼]
# 		</a>
#     </p>
# 		<p class="htlSpecial">ãå½ééãæ²¿ãã®ã­ã£ãã³åããã«ãç¸é¨å±ç¡ãã§å¨å®¤æ½é å¯è½âãå®¿æ³èæé£ç¡æâ2åã4åé¨å±ãããâ</p>
# 		<div class="tagwrp_v2">
#             <p class="hometown_icon"><img src="https://trvimg.r10s.jp/share/common/images/label_hometown_tax.svg"></p>
#             <div class="othrIndIcons 158644_link_couponlisting event_158644">
#                 <ul>
#                     <input type="hidden" id="158644_link_coupon_hotelNolisting" value="158644" />
#                 </ul>
#             </div>
# 		</div>
#     <!--/.info--></div>
#     </div>
#     <p class="htlAccess">
#            ã900-0013ãæ²ç¸çé£è¦å¸ç§å¿3-13-17<a href="//travel.rakuten.co.jp/share/gmap/map.html?f_longitude=127.69160280000006&f_latitude=26.2172288&TB_iframe=true&height=450&width=600" class="thickbox" title="ã¢ãã¹ãï¼£ï¼µï¼¢ï¼¥é£è¦å½ééãã¼å¨å®¤éµä»ãã­ã£ãã³åããã«ã¼" data-ratId="hotelList_ad_L000002979_3_158644_mapClick" data-ratEvent="click" data-ratParam="all">[å°å³ãè¦ã]</a>
#     </p>
#     <p class="htlInfo">ã¢ã¯ã»ã¹ãï¼ããã¬ã¼ã«ãç§å¿é§ãããå¾æ­©ï¼åã»å½ééãã¾ã§å¾æ­©0åâªé£è¦ç©ºæ¸¯ããããã«ã¾ã§ããã¬ã¼ã«ã§15åâª<br>
#         é§è»å ´ããï¼ç¡ã</p>
# 	<ul class="btnUndtd">
# 		<li><a href="//hotel.travel.rakuten.co.jp/hotelinfo/plan/158644?f_teikei=&l-id=hotelList_ad_L000002979_3_158644"><span>å®¿æ³ãã©ã³ä¸è¦§</span></a></li>
# 			<li><a id="RM_DP_PLAN_158644" class="dplkn" hotel_no="158644" href="javascript:void(0)" data-ratId="hotelList_ad_L000002979_3_158644_dpPlanClick" data-ratEvent="click" data-ratParam="all"><span>èªç©ºå¸ä»ãã©ã³ä¸è¦§</span></a></li>
# 		</ul>
#     </section>
#
#     <div class="photoPrnt">
#     	<div class="photoBox" id="158644-photo-contents" style="display: none; opacity: 0; z-index:">
#     		<p class="photoCls"><a class="closePhotoBox" href="javascript:void(0);"  photoBoxId="158644-photo-contents">éãã</a></p>
#     		<ul>
#     		<li class="photoStck" id="photo-158644-0"></li>
#     		<li class="photoStck" id="photo-158644-1"></li>
#     		<li class="photoStck" id="photo-158644-2"></li>
#     		<li class="photoStck" id="photo-158644-3"></li>
#     		<li class="photoStck" id="photo-158644-4"></li>
#     		<li class="photoStck" id="photo-158644-5"></li>
#     		</ul>
# 			<p class="morePix"><a href="https://travel.rakuten.co.jp/HOTEL/158644/gallery.html">ãã£ã¨è¦ã</a></p>
#     <!--/.photoBox-->
#     	</div>
#     <!--/.photoPrnt-->
#     </div>
# </li>
#
# <li id="183095_list" class="listing" data-ratid="hotelList_ad_L000002979_4_183095" data-ratevent="appear" data-ratparam="all" >
# 	<section>
#
#         <div class="pr_icon">
#             PR
#         </div>
#         <div class="htlHead">
#         <div class="photo">
# 	  	<div class="htlImgWrp">
# 	    <a id="183095_gaikanlisting" href="javascript:void(0)" class="htlImg" data-ratId="hotelList_ad_L000002979_4_183095_photoClick" data-ratEvent="click" data-ratParam="all" >
# 	    	<span id="thumbnail_183095_listing" video-id="" class="thumbnail"><img src="https://trvimg.r10s.jp/share/image_up/183095/origin/9ab5482f672ee9c93113ee355d3f105e22fa3be4.47.9.26.3.jpg?fit=inside|900:507&interpolation=lanczos-none" alt=""></span>
# 				</a>
#         </div>
# 	    <a href="" class="thickbox btn360dgr 183095-pano" id="183095-panorama" style="display:none;" data-lid="dateSearchC_cassette_panorama_8_pg1"><span>360ãã¥ã¼</span></a>
# 	    <!--/.photo-->
#     </div>
#
#     <div class="info">
#     <p class="area">
#     é£è¦</p>
# 	<h1 class=""><a href="https://travel.rakuten.co.jp/HOTEL/183095/183095.html?l-id=hotelList_ad_L000002979_4_183095" >ããã«ã°ã©ã³ã³ã³ã½ã«ãé£è¦</a>
#                 <span class="preferred_sparkle_none"><img src="https://img.travel.rakuten.co.jp/share/themes/ds/images/Sparkle_final16x16.png"><span class="preferred_sparkletext">ãã¡ãã®å®¿æ³æ½è¨­ã¯ãå®¿æ³èããã®ç·åè©ä¾¡ç¹æ°ãé«ãããããã¯å¤ãã®å®¿æ³å®ç¸¾ãããç­ã®ç¬èªã®æ¡ä»¶ãæºãããããªãã¡ã¼ããã­ã°ã©ã åå æ½è¨­ã§ããæ¥½å¤©ãã©ãã«ã¸ãµã¼ãã¹å©ç¨æãæ¯æããã¨ã«ãããåååæ¡ä»¶ã®ä»ã®æ½è¨­ãããä¸ä½ã«è¡¨ç¤ºããã¦ãã¾ããï¼ãã«ããã¼ã¸åç§ï¼</span></span>
#             </h1>
# 		<p class="htlPrice">
#     		[æå®æé]
# 			<span>4,546åã</span><span class="incldTax">ï¼æ¶è²»ç¨è¾¼5,000åãï¼</span></p>
#     <p class="cstmrEvl">
#     <a id="183095_review" href="https://travel.rakuten.co.jp/HOTEL/183095/review.html?l-id=hotelList_ad_L000002979_4_183095">
# 			<span class="starfourHlf"></span>
# 				<strong>4.44</strong>
#
# 			[ãå®¢ãã¾ã®å£°ï¼62ä»¶ï¼]
# 		</a>
#     </p>
# 		<p class="htlSpecial">2022å¹´9ææ°è¦OPENï¼å½ééãå¾æ­©3åã»ãå®¿æ³ã®çæ§ãå©ç¨å¯è½ãªããªã¼ã©ã¦ã³ã¸ãããã¾ã</p>
# 		<div class="tagwrp_v2">
#             <p class="hometown_icon"><img src="https://trvimg.r10s.jp/share/common/images/label_hometown_tax.svg"></p>
#             <div class="othrIndIcons 183095_link_couponlisting event_183095">
#                 <ul>
#                     <input type="hidden" id="183095_link_coupon_hotelNolisting" value="183095" />
#                 </ul>
#             </div>
# 		</div>
#     <!--/.info--></div>
#     </div>
#     <p class="htlAccess">
#            ã900-0014ãæ²ç¸çé£è¦å¸æ¾å°¾1-18-25<a href="//travel.rakuten.co.jp/share/gmap/map.html?f_longitude=127.6823056208321&f_latitude=26.21238991042739&TB_iframe=true&height=450&width=600" class="thickbox" title="ããã«ã°ã©ã³ã³ã³ã½ã«ãé£è¦" data-ratId="hotelList_ad_L000002979_4_183095_mapClick" data-ratEvent="click" data-ratParam="all">[å°å³ãè¦ã]</a>
#     </p>
#     <p class="htlInfo">ã¢ã¯ã»ã¹ãï¼é£è¦ç©ºæ¸¯ããè»ã§ç´15åãããã¬ã¼ã«ãçåºåé§ãããå¾æ­©ç´ï¼å<br>
#         é§è»å ´ããï¼æãï¼28å°ãæéï¼1,650å/æ³ (ç¨è¾¼ã¿ï¼é«ãå¶éããããã¾ãã</p>
# 	<ul class="btnUndtd">
# 		<li><a href="//hotel.travel.rakuten.co.jp/hotelinfo/plan/183095?f_teikei=&l-id=hotelList_ad_L000002979_4_183095"><span>å®¿æ³ãã©ã³ä¸è¦§</span></a></li>
# 			<li><a id="RM_DP_PLAN_183095" class="dplkn" hotel_no="183095" href="javascript:void(0)" data-ratId="hotelList_ad_L000002979_4_183095_dpPlanClick" data-ratEvent="click" data-ratParam="all"><span>èªç©ºå¸ä»ãã©ã³ä¸è¦§</span></a></li>
# 		</ul>
#     </section>
#
#     <div class="photoPrnt">
#     	<div class="photoBox" id="183095-photo-contents" style="display: none; opacity: 0; z-index:">
#     		<p class="photoCls"><a class="closePhotoBox" href="javascript:void(0);"  photoBoxId="183095-photo-contents">éãã</a></p>
#     		<ul>
#     		<li class="photoStck" id="photo-183095-0"></li>
#     		<li class="photoStck" id="photo-183095-1"></li>
#     		<li class="photoStck" id="photo-183095-2"></li>
#     		<li class="photoStck" id="photo-183095-3"></li>
#     		<li class="photoStck" id="photo-183095-4"></li>
#     		<li class="photoStck" id="photo-183095-5"></li>
#     		</ul>
# 			<p class="morePix"><a href="https://travel.rakuten.co.jp/HOTEL/183095/gallery.html">ãã£ã¨è¦ã</a></p>
#     <!--/.photoBox-->
#     	</div>
#     <!--/.photoPrnt-->
#     </div>
# </li>
#
# <li id="72693_list" class="listing" data-ratid="hotelList_ad_L000002979_5_72693" data-ratevent="appear" data-ratparam="all" >
# 	<section>
#
#         <div class="pr_icon">
#             PR
#         </div>
#         <div class="htlHead">
#         <div class="photo">
# 	  	<div class="htlImgWrp">
# 	    <a id="72693_gaikanlisting" href="javascript:void(0)" class="htlImg" data-ratId="hotelList_ad_L000002979_5_72693_photoClick" data-ratEvent="click" data-ratParam="all" >
# 	    	<span id="thumbnail_72693_listing" video-id="" class="thumbnail"><img src="https://trvimg.r10s.jp/share/image_up/72693/origin/e5aa44d94a8047b44f8ab75dd2e57cb18a0772ba.47.9.26.3.jpg?fit=inside|900:507&interpolation=lanczos-none" alt=""></span>
# 				</a>
#         </div>
# 	    <a href="" class="thickbox btn360dgr 72693-pano" id="72693-panorama" style="display:none;" data-lid="dateSearchC_cassette_panorama_8_pg1"><span>360ãã¥ã¼</span></a>
# 	    <!--/.photo-->
#     </div>
#
#     <div class="info">
#     <p class="area">
#     é£è¦</p>
# 	<h1 class=""><a href="https://travel.rakuten.co.jp/HOTEL/72693/72693.html?l-id=hotelList_ad_L000002979_5_72693" >é£è¦ã¦ã¨ã¹ãã»ã¤ã³</a>
#                 <span class="preferred_sparkle_none"><img src="https://img.travel.rakuten.co.jp/share/themes/ds/images/Sparkle_final16x16.png"><span class="preferred_sparkletext">ãã¡ãã®å®¿æ³æ½è¨­ã¯ãå®¿æ³èããã®ç·åè©ä¾¡ç¹æ°ãé«ãããããã¯å¤ãã®å®¿æ³å®ç¸¾ãããç­ã®ç¬èªã®æ¡ä»¶ãæºãããããªãã¡ã¼ããã­ã°ã©ã åå æ½è¨­ã§ããæ¥½å¤©ãã©ãã«ã¸ãµã¼ãã¹å©ç¨æãæ¯æããã¨ã«ãããåååæ¡ä»¶ã®ä»ã®æ½è¨­ãããä¸ä½ã«è¡¨ç¤ºããã¦ãã¾ããï¼ãã«ããã¼ã¸åç§ï¼</span></span>
#             </h1>
# 		<p class="htlPrice">
#     		[æå®æé]
# 			<span>2,400åã</span><span class="incldTax">ï¼æ¶è²»ç¨è¾¼2,640åãï¼</span></p>
#     <p class="cstmrEvl">
#     <a id="72693_review" href="https://travel.rakuten.co.jp/HOTEL/72693/review.html?l-id=hotelList_ad_L000002979_5_72693">
# 			<span class="starfourHlf"></span>
# 				<strong>4.16</strong>
#
# 			[ãå®¢ãã¾ã®å£°ï¼692ä»¶ï¼]
# 		</a>
#     </p>
# 		<p class="htlSpecial">å¨å®¤åå¥Wi-Fiï¼ãã«ã³ãã¼ä»ãã³ã³ã¯ãªã¼ãæã¡ã£ã±ãªããã¯ã¼ã«ãã¨æ¸æ½æãæ¼åºããã¹ãã¤ã¬ã»ãã¬ã¼ã</p>
# 		<div class="tagwrp_v2">
#             <p class="hometown_icon"><img src="https://trvimg.r10s.jp/share/common/images/label_hometown_tax.svg"></p>
#             <div class="othrIndIcons 72693_link_couponlisting event_72693">
#                 <ul>
#                     <input type="hidden" id="72693_link_coupon_hotelNolisting" value="72693" />
#                 </ul>
#             </div>
# 		</div>
#     <!--/.info--></div>
#     </div>
#     <p class="htlAccess">
#            ã900-0036ãæ²ç¸çé£è¦å¸è¥¿1-16-7<a href="//travel.rakuten.co.jp/share/gmap/map.html?f_longitude=127.67097680000006&f_latitude=26.213301&TB_iframe=true&height=450&width=600" class="thickbox" title="é£è¦ã¦ã¨ã¹ãã»ã¤ã³" data-ratId="hotelList_ad_L000002979_5_72693_mapClick" data-ratEvent="click" data-ratParam="all">[å°å³ãè¦ã]</a>
#     </p>
#     <p class="htlInfo">ã¢ã¯ã»ã¹ãï¼ã³ã³ããç®ã®åï¼æ°é¤¨ï¼æ¬é¤¨ãå¨150å®¤ãç©ºæ¸¯âããã«è»ã§ç´10åãæ­æ©é§âããã«å¾æ­©ç´ï¼åãé£è¦æ¸¯ã¾ã§å¾æ­©ç´2åã<br>
#         é§è»å ´ããï¼æãåå®¹å°æ°50å°ï¼åçé /äºç´ä¸å¯ï¼1æ³1,100åè¾¼</p>
# 	<ul class="btnUndtd">
# 		<li><a href="//hotel.travel.rakuten.co.jp/hotelinfo/plan/72693?f_teikei=&l-id=hotelList_ad_L000002979_5_72693"><span>å®¿æ³ãã©ã³ä¸è¦§</span></a></li>
# 			<li><a id="RM_DP_PLAN_72693" class="dplkn" hotel_no="72693" href="javascript:void(0)" data-ratId="hotelList_ad_L000002979_5_72693_dpPlanClick" data-ratEvent="click" data-ratParam="all"><span>èªç©ºå¸ä»ãã©ã³ä¸è¦§</span></a></li>
# 		</ul>
#     </section>
#
#     <div class="photoPrnt">
#     	<div class="photoBox" id="72693-photo-contents" style="display: none; opacity: 0; z-index:">
#     		<p class="photoCls"><a class="closePhotoBox" href="javascript:void(0);"  photoBoxId="72693-photo-contents">éãã</a></p>
#     		<ul>
# ...
#                                                 <label for="kinen">ç¦çã«ã¼ã </label>
#                                             </li>
#                                             <li class="feature-parent-kitsuen">
#                                                 <input type="checkbox"  class="feature-kitsuen" onchange="autoSelectDuplication(this);autoSelectChildren(this)" id="kitsuen" value="kitsuen"/>
#                                                 <label for="kitsuen">å«çã«ã¼ã </label>
#                                             </li>
#                                             <li class="feature-parent-internet">
#                                                 <input type="checkbox" name="f_squeezes" class="feature-internet" onchange="autoSelectDuplication(this);autoSelectChildren(this)" id="internet" value="internet"/>
#                                                 <label for="internet">ã¤ã³ã¿ã¼ãããå¯</label>
#                                             </li>
#                                             <li class="feature-parent-roten">
#                                                 <input type="checkbox"  class="feature-roten" onchange="autoSelectDuplication(this);autoSelectChildren(this)" id="roten" value="roten"/>
#                                                 <label for="roten">é²å¤©é¢¨åä»ãå®¢å®¤</label>
#                                             </li>
#                                             </ul>
#                             </dd>
#                         <dt>æ°åã³ã­ãã¦ã¤ã«ã¹å¯¾ç­</dt>
#                             <dd>
#                                 <ul>
#                                     <li class="feature-parent-via_staff">
#                                                 <input type="checkbox" name="f_squeezes" class="feature-via_staff" onchange="autoSelectDuplication(this);autoSelectChildren(this)" id="via_staff" value="via_staff"/>
#                                                 <label for="via_staff">ã¹ã¿ããã®ã¦ã¤ã«ã¹å¯¾ç­ãã</label>
#                                             </li>
#                                             <li class="feature-parent-via_disinfect">
#                                                 <input type="checkbox" name="f_squeezes" class="feature-via_disinfect" onchange="autoSelectDuplication(this);autoSelectChildren(this)" id="via_disinfect" value="via_disinfect"/>
#                                                 <label for="via_disinfect">é¤¨åã»å®¢å®¤ãªã©ã®æ¶æ¯æ¸æãã</label>
#                                             </li>
#                                             <li class="feature-parent-via_vent">
#                                                 <input type="checkbox" name="f_squeezes" class="feature-via_vent" onchange="autoSelectDuplication(this);autoSelectChildren(this)" id="via_vent" value="via_vent"/>
#                                                 <label for="via_vent">é¤¨åã»å®¢å®¤ãªã©ã®ææ°ãã</label>
#                                             </li>
#                                             <li class="feature-parent-via_chkinout">
#                                                 <input type="checkbox" name="f_squeezes" class="feature-via_chkinout" onchange="autoSelectDuplication(this);autoSelectChildren(this)" id="via_chkinout" value="via_chkinout"/>
#                                                 <label for="via_chkinout">ãã§ãã¯ã¤ã³ã»ã¢ã¦ãæã®æ¥è§¦åé¿ç­ãã</label>
#                                             </li>
#                                             <li class="feature-parent-via_room">
#                                                 <input type="checkbox" name="f_squeezes" class="feature-via_room" onchange="autoSelectDuplication(this);autoSelectChildren(this)" id="via_room" value="via_room"/>
#                                                 <label for="via_room">å®¢å®¤ã«æ¶æ¯æ¶²ãªã©ãã</label>
#                                             </li>
#                                             <li class="feature-parent-via_meal more hidden">
#                                                 <input type="checkbox" name="f_squeezes" class="feature-via_meal" onchange="autoSelectDuplication(this);autoSelectChildren(this)" id="via_meal" value="via_meal"/>
#                                                 <label for="via_meal">é£äºæã®æ¥è§¦åé¿ç­ãã</label>
#                                             </li>
#                                             <li class="feature-parent-via_bath more hidden">
#                                                 <input type="checkbox" name="f_squeezes" class="feature-via_bath" onchange="autoSelectDuplication(this);autoSelectChildren(this)" id="via_bath" value="via_bath"/>
#                                                 <label for="via_bath">å¤§æµ´å ´ã®æ¶æ¯ã»æ¥è§¦åé¿ç­ãã</label>
#                                             </li>
#                                             <li class="feature-parent-via_other_req more hidden">
#                                                 <input type="checkbox" name="f_squeezes" class="feature-via_other_req" onchange="autoSelectDuplication(this);autoSelectChildren(this)" id="via_other_req" value="via_other_req"/>
#                                                 <label for="via_other_req">å®¿æ³èã¸ã®æ¶æ¯ãªã©ãé¡ããã</label>
#                                             </li>
#                                             <li class="feature-parent-via_emergency more hidden">
#                                                 <input type="checkbox" name="f_squeezes" class="feature-via_emergency" onchange="autoSelectDuplication(this);autoSelectChildren(this)" id="via_emergency" value="via_emergency"/>
#                                                 <label for="via_emergency">ç·æ¥æã®ããã¥ã¢ã«ã»ã¹ã¿ããæè²ãã</label>
#                                             </li>
#                                             <li>
#                                             <div class="positionDiv">
#                                                 <img src="https://img.travel.rakuten.co.jp/share/themes/header/images/icon_arrow01_hover.gif" id="sideImg" class="sideImg">
#                                                 <a class="showMoreCheckbox" onclick="showMore(this)">ãã£ã¨è¦ã</a>
#                                             </div>
#                                         </li>
#                                     </ul>
#                             </dd>
#                         <dt>ããªã¢ããªã¼</dt>
#                             <dd>
#                                 <ul>
#                                     <li class="feature-parent-uwhlchair">
#                                                 <input type="checkbox" name="f_squeezes" class="feature-uwhlchair" onchange="autoSelectDuplication(this);autoSelectChildren(this)" id="uwhlchair" value="uwhlchair"/>
#                                                 <label for="uwhlchair">è»æ¤å­å¯</label>
#                                             </li>
#                                             <li class="feature-parent-bfroom">
#                                                 <input type="checkbox" name="f_squeezes" class="feature-bfroom" onchange="autoSelectDuplication(this);autoSelectChildren(this)" id="bfroom" value="bfroom"/>
#                                                 <label for="bfroom">ããªã¢ããªã¼ã«ã¼ã </label>
#                                             </li>
#                                             <li class="feature-parent-bftoilet">
#                                                 <input type="checkbox" name="f_squeezes" class="feature-bftoilet" onchange="autoSelectDuplication(this);autoSelectChildren(this)" id="bftoilet" value="bftoilet"/>
#                                                 <label for="bftoilet">ããªã¢ããªã¼ç¨ãã¤ã¬</label>
#                                             </li>
#                                             <li class="feature-parent-rwhlchair">
#                                                 <input type="checkbox" name="f_squeezes" class="feature-rwhlchair" onchange="autoSelectDuplication(this);autoSelectChildren(this)" id="rwhlchair" value="rwhlchair"/>
#                                                 <label for="rwhlchair">è²¸åºç¨è»æ¤å­</label>
#                                             </li>
#                                             </ul>
#                             </dd>
#                         <dt>ãµããã¨ç´ç¨</dt>
#                             <dd>
#                                 <ul>
#                                     <li class="feature-parent-hmtwntax">
#                                                 <input type="checkbox" name="f_squeezes" class="feature-hmtwntax" onchange="autoSelectDuplication(this);autoSelectChildren(this)" id="hmtwntax" value="hmtwntax"/>
#                                                 <label for="hmtwntax">ãµããã¨ç´ç¨ã¯ã¼ãã³å¯¾è±¡</label>
#                                             </li>
#                                             </ul>
#                             </dd>
#                         </dl>
#
#                 <p class="stdSrchBtn smlSz">
#                     <a id="dh-squeeze-submit" href="javascript:document.getElementById('dh-form-squeeze').submit();">çµãè¾¼ã</a>
#                 </p>
#             </dd>
#         </dl>
#     </form>
# </div>
# <div class="mboxDefault"></div>
#
# <script type="text/javascript" src="https://trv.r10s.jp/share/themes/ds/js/lowerprice.js?p=20200722"></script>
# <!-- end of domestic squeeze form -->
# <dl id="aroundArea">
# <dt class="ttlBar">å¨è¾ºã¨ãªã¢ã®ããã«ã»æé¤¨</dt>
# <dd class="outerBox">
# <ul>
# <li class="first"><a href="https://travel.rakuten.co.jp/yado/okinawa/">æ²ç¸ç ããã«ã»æé¤¨</a></li>
# 	<li id="t-01"><a href="https://travel.rakuten.co.jp/yado/okinawa/nahashi.html" class="rtcond">é£è¦ ããã«ã»æé¤¨</a></li>
# 	<li id="t-02"><a href="https://travel.rakuten.co.jp/yado/okinawa/hokubu.html" class="rtcond">æ©ç´ã»åè­·ã»æ¬é¨ã»ä»å¸°ä» ããã«ã»æé¤¨</a></li>
# 	<li id="t-03"><a href="https://travel.rakuten.co.jp/yado/okinawa/chubu.html" class="rtcond">å®éæ¹¾ã»åè°·ã»èª­è°·ã»æ²ç¸å¸ã»ããã¾ ããã«ã»æé¤¨</a></li>
# 	<li id="t-04"><a href="https://travel.rakuten.co.jp/yado/okinawa/nanbu.html" class="rtcond">ç³¸æºã»è±è¦åã»åå ããã«ã»æé¤¨</a></li>
# 	<li id="t-05"><a href="https://travel.rakuten.co.jp/yado/okinawa/kerama.html" class="rtcond">æ¶è¯éã»æ¸¡åæ·ã»åº§éå³ã»é¿å ããã«ã»æé¤¨</a></li>
# 	<li id="t-06"><a href="https://travel.rakuten.co.jp/yado/okinawa/kumejima.html" class="rtcond">ä¹ç±³å³¶ ããã«ã»æé¤¨</a></li>
# 	<li id="t-07"><a href="https://travel.rakuten.co.jp/yado/okinawa/Miyako.html" class="rtcond">å®®å¤å³¶ã»ä¼è¯é¨å³¶ ããã«ã»æé¤¨</a></li>
# 	<li id="t-08"><a href="https://travel.rakuten.co.jp/yado/okinawa/ritou.html" class="rtcond">ç³å£ã»è¥¿è¡¨ã»å°æµå³¶ ããã«ã»æé¤¨</a></li>
# 	<li id="t-09"><a href="https://travel.rakuten.co.jp/yado/okinawa/yonaguni.html" class="rtcond">ä¸é£å½å³¶ ããã«ã»æé¤¨</a></li>
# 	<li id="t-10"><a href="https://travel.rakuten.co.jp/yado/okinawa/daito.html" class="rtcond">å¤§æ±å³¶ ããã«ã»æé¤¨</a></li>
# 	</ul>
#   <dl class="rtprts__area_links-wrap">
#       <dt><a href=""><span>ãã£ã¨ç´°ããå°åããæ¢ã</span></a></dt>
#       <dd>
#           <ul style="top:0; left:0;">
#           </ul>
#       </dd>
#   </dl>
# </dd>
# </dl>
# <div class="module-history-domsearch">
#     <section id="browsing-history-container">
#     </section>
#     <section id="browsing-history-correlatedItem-container">
#     </section>
# </div></div>
# 	<div id="srchSide-B">
# 	</div>
#     <script src="https://trv.r10s.jp/share/common/js/lib/jquery/jquery.js" type="text/javascript" ></script>
# <script charset="UTF-8" type="text/javascript" src="https://trv.r10s.jp/share/recipe/js/recipe.js" data-menu="ds.v4" async></script>
# <script src="https://trv.r10s.jp/share/themes/top/js/top_global_link.js" type="text/javascript" charset="Shift_jis"></script>
# <script src="https://trv.r10s.jp/share/themes/ds/js/actionviruslistcommon.js" type="text/javascript" ></script>
# <!--[if gte IE 9]>
#   <style type="text/css">
#     .gradient {
#        filter: none;
#     }
#   </style>
# <![endif]-->
# <script type="text/javascript" src="https://trv.r10s.jp/share/wat/list/undated_hotel.js"></script>
# 	<script type="text/javascript" src="https://trv.r10s.jp/share/themes/ds/js/rakutenTr_domesticAirPackageCarrier4UdSrch.js"></script>
# 	<!-- UserInsight start -->
# 	<script type="text/javascript" src="https://trv.r10s.jp/share/themes/top/js/userLocal.js"></script>
# 	<!-- UserInsight end -->
# 	<!-- SiteCatalyst code version: H.9.Copyright 1997-2007 Omniture, Inc. More info available at http://www.omniture.com -->
# <div id="dynamicElement"></div>
# <script language="JavaScript" src="https://trv.r10s.jp/share/wat/sc/s_code.js"></script>
# <script language="JavaScript" src="https://trv.r10s.jp/share/wat/sc/code_to_paste.js"></script>
# <!-- End SiteCatalyst code version: H.9. -->
#
# <!-- Mebius -->
# <script type="text/javascript">
# var mbHost = (("https:" == document.location.protocol) ? "https://" : "http://");
# document.write(unescape("%3Cscript src='" + mbHost + "rd.rakuten.co.jp/js/p_code.js' type='text/javascript'%3E%3C/script%3E"));
# </script>
# <script type="text/javascript"><!--
#     i="6.2994.0";
#     n="travel";
#     l="travel";
#     r=document.referrer;
#     document.write(p(i,n,l,r));
# //--></script>
# <noscript>
#     <img src="//rd.rakuten.co.jp/p/?i=6.2994.0&n=travel&l=travel&r=" />
# </noscript>
# <!-- /Mebius -->
#
# <script type="text/javascript" charset="Shift_JIS" src="https://trv.r10s.jp/share/themes/ds/js/undated_s_code_setting.js"></script>
#
# <script type="text/javascript">
# 	<!--
# 	function showCovid(){
#
# 		if ( typeof antivirushotellist !== 'undefined' && document.getElementById('hotelNos') != null){
# 			// var hnolist = $('#hotelNos').val().split(',');
# 			// for(var i = 0 ; i < hnolist.length; i++ ){
# 			// 	if(antivirushotellist[hnolist[i]] ){
# 			// 		if(document.getElementById('via_' + hnolist[i] + '_listing')){
# 			// 			document.getElementById('via_' + hnolist[i] + '_listing').style.display ="inline-block";
# 			// 		}
# 			// 		if(document.getElementById('via_' + hnolist[i])){
# 			// 			document.getElementById('via_' + hnolist[i]).style.display ="inline-block";
# 			// 		}
# 			// 	}
# 			// }
# 			return;
# 		}
#
# 	}
# 	//-->
# </script><script type="text/javascript" src="https://trv.r10s.jp/share/themes/ds/js/show_ads_randomly.js?p=20210522"></script>
#     </div>
# <!--START_FOORTER -->
# <!--@FOOTER_MENU-->
# <!--START_FOOTER-->
# <script charset="UTF-8" type="text/javascript" src="https://img.travel.rakuten.co.jp/share/rtl/js/navigation.js?_=20210719"> </script>
# <div class="rt-footer">
# <dl id="rt-switch-device" class="rt-switch-device">
# <dt>è¡¨ç¤ºã¢ã¼ãï¼</dt>
# <dd><ul>
# <li>ã¢ãã¤ã«</li>
# <li><a id="linkFtToPC" href="#">PC</a></li>
# </ul></dd>
# </dl>
# <ul class="rt-foot-nav">
# <li><a href="https://travel.rakuten.co.jp/corporate/" rel="nofollow">ä¼ç¤¾æå ±</a></li>
# <li><a href="https://privacy.rakuten.co.jp/" rel="nofollow">åäººæå ±ä¿è­·æ¹é</a></li>
# <li class="rt-for-pc"><a href="https://corp.rakuten.co.jp/csr/">ç¤¾ä¼çè²¬ä»»[CSR]</a></li>
# <li class="rt-for-pc"><a href="https://travel.rakuten.co.jp/recruit/">æ¡ç¨æå ±</a></li>
# <li class="rt-for-pc"><a href="https://travel.rakuten.co.jp/info/" rel="nofollow">è¦ç´é</a></li>
# <li class="rt-for-pc"><a href="https://travel.rakuten.co.jp/info/hotel_msg.html">è³æè«æ±</a></li>
# </ul>
# <p class="rt-copyright">&copy; Rakuten Group, Inc.</p>
# <!--/.rt-footer--></div>
# <!--END_FOOTER-->
# <span id="footerBannerAppDL"></span>
# <script charset="UTF-8" type="text/javascript" src="//trv.r10s.jp/share/tags/js/tags.env.js"></script>
# <script charset="UTF-8" type="text/javascript" src="//trv.r10s.jp/share/tags/js/tags.track.js?_=20210522"></script><!--END_FOORTER--></body>
# </html>

# %% [markdown]
# 一部文字化けしているので修正しましょう！
# 一般的に使われている文字コードはutf-8
# そのコードが違うときに、別の文字が呼び出されて文字化けに見えます。

# %%
# res.encodingで文字エンコードを確認できます。
print(res.encoding)
# Out:
# ISO-8859-1

# %% [markdown]
# >文字化けしていた場合の対処

# %% [markdown]
# 文字コードがISO-8859-1なので、utf-8に変更してみましょう！
# res.encoding = 'utf-8'でutf-8に上書きできます。

# %%
#文字エンコードを上書きします。
res.encoding = "utf-8"
# 文字化けしていないかhtmlを確認します。
print(res.text)
# Out:
# <!DOCTYPE HTML>
# <html lang="ja" prefix="og: http://ogp.me/ns# fb: http://www.facebook.com/2008/fbml mixi: http://mixi-platform.com/ns# gr: http://gree.jp/ns">
# <head>
# <meta charset="utf-8">
# <title>那覇のホテル・旅館 宿泊予約 【楽天トラベル】</title>
# <meta name="description" content="那覇のホテル・旅館の予約は楽天トラベルで！人気ビジネス,シティホテルから旅館までお客様の声など宿情報満載">
# <meta name="keywords" content="宿泊,出張,予約,施設,ビジネス,ホテル,旅館,楽天トラベル,旅の窓口,那覇">
# <meta name="robots" content="index,follow">
# <meta property="og:title" content="那覇のホテル・旅館 宿泊予約 【楽天トラベル】">
# <meta property="og:description" content="那覇のホテル・旅館の予約は楽天トラベルで！人気ビジネス,シティホテルから旅館までお客様の声など宿情報満載">
# <meta property="og:type" content="article">
# <meta property="og:url" content="https://travel.rakuten.co.jp/yado/okinawa/nahashi.html">
# <meta property="og:image" content="https://trvimg.r10s.jp/share/common/images/bnr_ogp_logo.gif">
# 	<link rel="canonical" href="https://travel.rakuten.co.jp/yado/okinawa/nahashi.html">
# <meta property="og:site_name" content="楽天トラベル">
# <meta property="og:locale" content="ja_JP">
# <meta name="format-detection" content="telephone=no">
#
# <link rel="stylesheet" href="https://img.travel.rakuten.co.jp/share/common/css/style-pc.css?_=20221213" >
#
# <link type="text/css" rel="stylesheet" href="https://img.travel.rakuten.co.jp/share/themes/ds/css/trvl_srch_undtd_page.css?_=20230717" media="screen">
# <link type="text/css" rel="stylesheet" href="https://img.travel.rakuten.co.jp/share/themes/ds/css/trvl_srch_undtd_dp_pop.css" media="screen">
# <link type="text/css" rel="stylesheet" href="https://img.travel.rakuten.co.jp/share/rtl/css/util.calendar.css" media="screen">
# <link type="text/css" rel="stylesheet" href="https://img.travel.rakuten.co.jp/share/themes/ds/css/searchSide_B.css" media="screen">
# <link type="text/css" rel="stylesheet" href="https://img.travel.rakuten.co.jp/share/common/css/thickbox.css" media="screen">
# <link type="text/css" rel="stylesheet" href="https://img.travel.rakuten.co.jp/share/themes/ds/css/station_C.css" media="screen">
# <link type="text/css" rel="stylesheet" href="https://img.travel.rakuten.co.jp/share/themes/ds/css/preferred_sparkle.css?=_20210525" media="all">
# <link rel="next" href="https://search.travel.rakuten.co.jp/ds/yado/okinawa/nahashi-p2">
# <LINK type="text/css" rel="stylesheet" href="https://img.travel.rakuten.co.jp/share/rtl/css/widget_history_correlated-pc.css" media="all">
# <LINK type="text/css" rel="stylesheet" href="https://trv.r10s.jp/share/rtl/css/widget_history_correlated-pc_imgOpt.css" media="all">
# <!--[if lt IE 9]><script src="https://img.travel.rakuten.co.jp/share/common/js/lib/html5shiv.js"></script><![endif]-->
#
# </head>
# <body id="TOP" class="">
# <script>
#  if(!tags) var tags = {};
#  if(!tags.data) tags.data = {};
#  tags.data = {"contents":{"type":"hotel"},"page":{"type":"search","step":"","pageNo":1,"abTestName":"E20210630","patternNumber":"0"},"query":{"items":[{"from":{"date":"","country":"japan","prefecture":"okinawa","city":"nahashi","district":"","spot":""},"to":{"date":"","country":"japan","prefecture":"okinawa","city":"nahashi","district":"","spot":""},"guest":{"adult":"","child":"","infant":""},"id":"","type":"","category":"","provider":{"id":"","type":"hotel","category":""}}],"price":"","currency":"JPY","abTestHotelIdList":["hotelList_ad_L000002979_1_146927","hotelList_ad_L000002979_2_182439","hotelList_ad_L000002979_3_158644","hotelList_ad_L000002979_4_183095","hotelList_ad_L000002979_5_72693","hotelList_ad_L000002979_6_149360","hotelList_7_104526","hotelList_8_134763","hotelList_9_128440","hotelList_10_163087","hotelList_11_178447","hotelList_12_171943","hotelList_13_177761","hotelList_14_181785","hotelList_15_40768","hotelList_16_160939","hotelList_17_176757","hotelList_18_130025","hotelList_19_182884","hotelList_20_167519","hotelList_21_71990","hotelList_22_38282","hotelList_23_149369","hotelList_24_136808","hotelList_25_178292","hotelList_26_148000","hotelList_27_70884","hotelList_28_67292","hotelList_29_153504","hotelList_30_76923","hotelList_31_183095","hotelList_32_16693","hotelList_33_16443","hotelList_34_181339","hotelList_35_172986","hotelList_36_18195"]},"browse":{"items":[{"id":"","type":"room","provider":{"id":"146927","type":"hotel"}},{"id":"","type":"room","provider":{"id":"182439","type":"hotel"}},{"id":"","type":"room","provider":{"id":"158644","type":"hotel"}},{"id":"","type":"room","provider":{"id":"183095","type":"hotel"}},{"id":"","type":"room","provider":{"id":"72693","type":"hotel"}},{"id":"","type":"room","provider":{"id":"149360","type":"hotel"}},{"id":"","type":"room","provider":{"id":"104526","type":"hotel"}},{"id":"","type":"room","provider":{"id":"134763","type":"hotel"}},{"id":"","type":"room","provider":{"id":"128440","type":"hotel"}},{"id":"","type":"room","provider":{"id":"163087","type":"hotel"}},{"id":"","type":"room","provider":{"id":"178447","type":"hotel"}},{"id":"","type":"room","provider":{"id":"171943","type":"hotel"}},{"id":"","type":"room","provider":{"id":"177761","type":"hotel"}},{"id":"","type":"room","provider":{"id":"181785","type":"hotel"}},{"id":"","type":"room","provider":{"id":"40768","type":"hotel"}},{"id":"","type":"room","provider":{"id":"160939","type":"hotel"}},{"id":"","type":"room","provider":{"id":"176757","type":"hotel"}},{"id":"","type":"room","provider":{"id":"130025","type":"hotel"}},{"id":"","type":"room","provider":{"id":"182884","type":"hotel"}},{"id":"","type":"room","provider":{"id":"167519","type":"hotel"}},{"id":"","type":"room","provider":{"id":"71990","type":"hotel"}},{"id":"","type":"room","provider":{"id":"38282","type":"hotel"}},{"id":"","type":"room","provider":{"id":"149369","type":"hotel"}},{"id":"","type":"room","provider":{"id":"136808","type":"hotel"}},{"id":"","type":"room","provider":{"id":"178292","type":"hotel"}},{"id":"","type":"room","provider":{"id":"148000","type":"hotel"}},{"id":"","type":"room","provider":{"id":"70884","type":"hotel"}},{"id":"","type":"room","provider":{"id":"67292","type":"hotel"}},{"id":"","type":"room","provider":{"id":"153504","type":"hotel"}},{"id":"","type":"room","provider":{"id":"76923","type":"hotel"}},{"id":"","type":"room","provider":{"id":"183095","type":"hotel"}},{"id":"","type":"room","provider":{"id":"16693","type":"hotel"}},{"id":"","type":"room","provider":{"id":"16443","type":"hotel"}},{"id":"","type":"room","provider":{"id":"181339","type":"hotel"}},{"id":"","type":"room","provider":{"id":"172986","type":"hotel"}},{"id":"","type":"room","provider":{"id":"18195","type":"hotel"}}]}};
# </script>
# <script type="text/javascript">
# if(!rtp) var rtp = {};
# rtp.service = "dh";
#
# var abtest = {};
#
#
# 	var ds = {"actionPath":"search","areaName":"那覇","conditions":{"f_sort":["hotel"],"f_campaign":[""],"f_point_min":["0"],"f_page":["1"],"seo_f_chu":["okinawa"],"seo_f_shou":["nahashi"],"f_gcode":[""],"f_cd":[""],"f_dai":["japan"],"f_chu":["okinawa"],"f_shou":["nahashi"],"f_sai":[""],"f_latitude":["0.0"],"f_longitude":["0.0"],"f_km":[""],"f_squeezes":[],"f_rm_bed":[],"f_rm_type":[],"f_tab":["hotel"],"f_service":null},"displayedHotels":[146927,182439,158644,183095,72693,149360,104526,134763,128440,163087,178447,171943,177761,181785,40768,160939,176757,130025,182884,167519,71990,38282,149369,136808,178292,148000,70884,67292,153504,76923,16693,16443,181339,172986,18195],"facilityName":"","hotels":{},"isCamby":false,"isDated":false,"isHotelFixed":false,"isNearbySearch":false,"isSecret":false,"isShowCrossSearch":true,"isSqueezingCambyFlag":false,"narrowingArea":[],"rtcond":{"f_sort":["hotel"],"f_campaign":[""],"f_point_min":["0"],"f_gcode":[""],"f_cd":[""],"f_dai":["japan"],"f_chu":["okinawa"],"f_shou":["nahashi"],"f_sai":[""],"f_latitude":["0.0"],"f_longitude":["0.0"],"f_km":[""],"f_squeezes":[]},"rtcondex":{"dated":false,"f_tab":"hotel"},"totalResults":[416]};
#
# var searchHotelNo = "";
#
# if (!tags) var tags = {};
# if (!tags.data) tags.data = {};
# </script>
# <!--START_HEADER-->
# <span id="headerBannerAppDL"></span>
# <div class="rt-header">
# <ul class="rt-group-link">
# <li><a href="https://travel-smp.faq.rakuten.net/detail/000013745" target="_blank">新型コロナウイルスの対応について</a></li>
# <li><a href="https://ad2.trafficgate.net/t/r/9091/1441/99636_99636/">カード</a></li>
# <li><a href="https://gora.golf.rakuten.co.jp/?scid=wi_grp_gmx_trv_hetopbu_gra">GORA</a></li>
# <li><a href="https://www.rakuten.co.jp/">楽天市場</a></li>
# <!--/.rt-group-link--></ul>
# <div class="rt-service-bar">
# <div class="rt-site-id">
# <p class="rt-site-name"><a href="https://travel.rakuten.co.jp/">楽天トラベル</a></p>
# <p class="rt-outline">宿・航空券・ツアー予約</p>
# <!--/.rt-site-id--></div>
# <div class="rt-promotion">
# <a id="rt-header-square-banner" href="#"><img src="https://img.travel.rakuten.co.jp/share/images/null.gif" width="170" height="53" alt="" border="0"></a>
# <!--/.rt-promotion --></div>
# <div class="rt-utility">
# <ul class="rt-help-link">
# <li><a href="https://travel.rakuten.co.jp/howto/">楽天トラベルの使い方</a></li>
# <li><a href="https://travel.rakuten.co.jp/sitemap/">サイトマップ</a></li>
# <li><a href="https://travel.faq.rakuten.net/">ヘルプ</a></li>
# <li class="rt-lang-link"><a id="rt-lang-link-a" href="javascript:void(0);">Languages</a>
#   <ul id="rt-lang-box" style="display: none;">
#   <li><a id="lnkEnglish" href="https://travel.rakuten.com/"><span>English</span></a></li>
#   <li><a id="lnkKorea" href="https://travel.rakuten.co.kr/"><span>&#xB300;&#xD55C;&#xBBFC;&#xAD6D;(&#xD55C;&#xAD6D;&#xC5B4;)</span></a></li>
#   <li><a id="lnkTaiwanese" href="https://travel.rakuten.com.tw/"><span>&#x53F0;&#x7063;(&#x7E41;&#x9AD4;&#x4E2D;&#x6587;)</span></a></li>
#   <li><a id="lnkHonkKong" href="https://travel.rakuten.com.hk/"><span>&#x9999;&#x6E2F;(&#x7E41;&#x9AD4;&#x4E2D;&#x6587;)</span></a></li>
#   <li><a id="lnkChinese" href="https://travel.rakuten.cn/"><span>&#x4E2D;&#x56FD;(&#x7B80;&#x4F53;&#x4E2D;&#x6587;)</span></a></li>
#   <li><a id="lnkThai" href="https://travel.rakuten.co.th/"><span>&#xE1B;&#xE23;&#xE30;&#xE40;&#xE17;&#xE28;&#xE44;&#xE17;&#xE22; (&#xE20;&#xE32;&#xE29;&#xE32;&#xE44;&#xE17;&#xE22;)</span></a></li>
#   </ul>
# </li>
# </ul>
#
# <div class="rt-mytrv">
# <a href="https://auth.travel.rakuten.co.jp/fwd/memberDispatcher/staticPageLogin?service_id=t01&return_url=cgi-bin/rakuten_id_reference&_guestLoginServiceKey=guestReservation&f_next_url=https://mypage.travel.rakuten.co.jp/">予約の確認・キャンセル</a>
# <!--/.rt-mytrv--></div>
#
# <div id="rt-notification-container" class="rt-notification-btn-box" style="display:none;">
#   <button class="rt-notification-btn" id="notificationButton">
#     お知らせ
#   <!--/.rt-notification--></button>
#   <span class="rt-count-badge" id="notificationBadge" style="display:none;">0</span>
# </div>
#
# <div id="pbox-container">
#   <script type="text/x-jquery-tmpl" id="pbox-member">
#   <div class="rt-member-notification">
#   <dl class="rt-member">
#   <dt class="rt-member-${body.userRank}"><span>ようこそ</span><a href="https://my.travel.rakuten.co.jp/mytravel/"><b>${body.name}</b>さん</a></dt>
#   <dd><b>${body.totalPoint}</b>ポイント</dd>
#   </dl>
#   </div>
#   <div id="rt-btn-info" class="rt-btn-info">
#   <a href="#">会員情報</a>
#   <!--/.rt-btn-info--></div>
#
#   <!-- member detail -->
#   <div id="memberDetail">
#
#   <!-- detailMenu -->
#   <div class="detailMenu">
#   <ul id="menuTab"><!--
#   --><li class="memberMenu open">会員情報</li><!--
#   --><li class="serviceMenu">関連サービス</li><!--
#   --></ul><!--
#   --><div class="close">閉じる</div>
#   </div>
#   <!-- /detailMenu -->
#
#   <!-- statusInfo -->
#   <div id="statusInfo">
#   <div id="loginForm" class="${body.userRank}">
#   <div class="loginStatus" id="loginStatus">
#   <p class="user-name">ようこそ、<a href="https://my.travel.rakuten.co.jp/mytravel/"><span>${body.name}</span>さん</a></p>
#   <p class="member-rank">あなたは<em>${body.kaiinRank}</em></p>
#
#   <div class="pointInfo">
#   {{if body.loadPrivateFile}}
#   <p class="invitation"><a href="${body.loadPrivateFile}"><img width="20" hspace="2" height="24" border="0" style="vertical-align:middle;" src="https://img.travel.rakuten.co.jp/share/themes/top/images/env_anime.gif" alt="特別ご招待">特別ご招待</a></p>
#   {{/if}}
#   <p class="point">現在の保有ポイント<em>${body.totalPoint}ポイント</em>
#   {{if body.limitedTermPoint != 0}}
#   <span class="limit">うち、期間限定ポイント: ${body.limitedTermPoint}ポイント</span>
#       {{if body.pointrCash != 0 }}
#           <span class="note">楽天キャッシュ ${rtl.widget.pbox.viewHelper.numSeparate3Format(body.pointrCash)} 円</span>
#       {{/if}}
#   {{else  body.pointrCash != 0 }}
#   <span class="cash">うち、楽天キャッシュ ${rtl.widget.pbox.viewHelper.numSeparate3Format(body.pointrCash)} 円</span>
#   {{/if}}
#   </p>
#   <!-- /pointInfo --></div>
#   <!-- /loginStatus --></div>
#
#   <div class="btn-point"><a href="https://travel.rakuten.co.jp/point/">楽天ポイントについて</a><!-- /.btn-point --></div>
#   <ul class="link">
#   <li><a href="https://coupon.rakuten.co.jp/myCoupon">獲得済みのクーポン</a><img src="https://img.travel.rakuten.co.jp/share/themes/top/images/icon_new.gif"></li>
#   </ul>
#
#   <div class="btn-confirm">
#   <a href="https://auth.travel.rakuten.co.jp/fwd/memberDispatcher/staticPageLogin?service_id=t01&return_url=cgi-bin/rakuten_id_reference&_guestLoginServiceKey=guestReservation&f_next_url=https://mypage.travel.rakuten.co.jp/">予約の確認・変更・取消</a>
#   <!-- /.btn-confirm --></div>
#   <div class="btn-change">
#   <a href="https://auth.travel.rakuten.co.jp/fwd/memberDispatcher/staticPageLogin?service_id=t01&return_url=cgi-bin/rakuten_id_reference&f_next_url=https://aps1.travel.rakuten.co.jp/portal/my/rakuten_kaiin_supplement.main?f_henkou_flg=HENKOU">登録内容変更</a>
#   <!-- /.btn-change --></div>
#
#   <!-- /loginForm --></div>
#
#   <div class="btn-logout"><a href="https://auth.travel.rakuten.co.jp/fwd/omniLogout">ログアウト</a><!-- /.btn-logout --></div>
#   </div><!-- /div#statusInfo -->
#
#   <div id="serviceInfo">
#   <p class="title">楽天グループのサービス</p>
#   <ul class="serviceList"><!--
#   --><li><a href="https://www.rakuten.co.jp/"><span>楽天市場</span></a></li><!--
#   --><li><a href="https://www.rakuten-card.co.jp/smart/"><span>楽天カード</span></a></li><!--
#   --><li><a href="https://books.rakuten.co.jp/"><span>楽天ブックス</span></a></li><!--
#   --><li><a href="https://auction.rakuten.co.jp/"><span>楽天オークション</span></a></li><!--
#   --><li><a href="https://sp.rakuten-edy.co.jp/"><span>楽天Edy</span></a></li><!--
#   --><li><a href="https://www.rakuten-bank.co.jp/smartphone/index.html"><span>楽天銀行</span></a></li><!--
#   --><li><a href="https://gora.golf.rakuten.co.jp/smart/iphone_top.html"><span>楽天GORA</span></a></li><!--
#   --><li><a href="https://www.rakuten-sec.co.jp/smartphone/"><span>楽天証券</span></a></li><!--
#   --><li><a href="https://www.rakuten.co.jp/sitemap/sp/"><span>楽天サービス一覧</span></a></li><!--
#   --><li><a href="https://www.rakuten.co.jp/sitemap/spapp/"><span>楽天アプリ一覧</span></a></li><!--
#   --></ul><!-- /.serviceLst -->
#   <!-- /div#serviceInfo --></div>
#   <!-- /member detail --></div>
#   </script>
#
#   <script type="text/x-jquery-tmpl" id="pbox-nologin">
#   <dl class="rt-nologin">
#   <dt>ようこそ、楽天トラベルへ</dt>
#   <dd><ul>
#       <li class="rt-btn-register"><a href="https://travel.rakuten.co.jp/kaiin.html">会員登録</a></li>
#       <li class="rt-btn-login"><a href="${body.redirect}">ログイン</a></li>
#   </ul></dd>
#   </dl>
#   </script>
# </div>
#
# <!--/.rtUtility--></div>
# <!--/.rt-service-bar--></div>
# <dl class="rt-nav-link">
# <dt><a id="rt-nav-link-a" href="#">メニュー</a></dt>
# <dd><ul id="rt-nav-box" class="rt-hide" >
# <li class="rt-nav-active"><a href="https://travel.rakuten.co.jp/?l-id=top_navi_dh">国内旅行</a></li>
# <li class=" rt-nav-down"><a href="https://travel.rakuten.co.jp/package/?l-id=top_navi_dp">国内ツアー</a>
#   <ul class="rt-nav-secondary">
#   <li><a href="https://travel.rakuten.co.jp/package/ana/?l-id=top_navi_dp_ana">ANA楽パック（航空券＋宿）</a></li>
#   <li><a href="https://travel.rakuten.co.jp/package/jal/?l-id=top_navi_dp_jal">JAL楽パック（航空券＋宿）</a></li>
#   </ul>
# </li>
# <li class=""><a href="https://travel.rakuten.co.jp/cars/?scid=wi_trv_top_navi_car">レンタカー</a></li>
# <li class=""><a href="https://travel.rakuten.co.jp/bus/?scid=wi_trv_top_navi_bus">高速バス・バスツアー</a></li>
# <li class=""><a href="https://travel.rakuten.co.jp/kaigai/?scid=wi_trv_top_navi_kaigai">海外旅行</a></li>
# <li class=""><a href="https://experiences.travel.rakuten.co.jp/?scid=wi_txp_trv_pc-nav">遊び・体験</a></li>
# <li class=""><a href="https://camp.travel.rakuten.co.jp/?scid=wi_trv_top_navi_camp">キャンプ場</a></li>
# <li class=""><a href="https://travel.rakuten.co.jp/coupon/?l-id=top_navi_coupon">割引クーポン</a></li>
# <li class=""><a href="https://travel.rakuten.co.jp/special/furusato/?l-id=top_navi_furusato">ふるさと納税</a></li>
# <li class=""><a href="https://travel.rakuten.co.jp/mytrip/?scid=wi_trv_top_navi_guide">旅行ガイド</a></li>
# </ul></dd>
# <!--/.rt-nav-link--></dl>
# <!--ds-->
# <div id="widgetPointupBannerRef"></div>
# <!--/.rt-header--></div>
# <div id="widgetPointupModalRef" data-ratid="Point_Banner" data-ratevent="appear" data-ratparam="all"></div>
#
# <input type="hidden" id="rt-service-hidden" value="domestic-travel">
# <!--END_HEADER-->
# <div id="wideEventBanner" style="display:none;">
# </div>
# <div id="srchContents" class="htlList">
# <!-- ****パンくず開始**** -->
# <p id="srchBrdCrmbs">
# 		<a href="//travel.rakuten.co.jp/">楽天トラベルトップ</a>&nbsp;&gt;
# 				<span class="grpLocationLocus"><a href="//travel.rakuten.co.jp/yado/japan.html">全国</a></span>&nbsp;&gt;&nbsp;
# 							<span class="grpLocationLocus"><a href="//travel.rakuten.co.jp/yado/okinawa/map.html">沖縄県</a></span>
#
# 								&nbsp;&gt;&nbsp;
# 								那覇</p>
# <!-- ****パンくず終了**** --><h1 id="seoTtl">
# 					<span>那覇&nbsp;</span>ホテル・旅館
# 				</h1>
# 			<div id="contentInner">
# 	<div id="srchMainContent">
# 	<!-- New Tab  start -->
#
# <input type="hidden" id="abTestForDAPLink" value="471_Link_A" />
# <script type="text/javascript">
# 	var abTestForDAPLink = getABPatternForDAPLink();
# 	tags.data.page.abTestName = "trvab_2";
# 	tags.data.page.patternNumber = abTestForDAPLink;
#
# 	document.getElementById("abTestForDAPLink").value = abTestForDAPLink;
#
# 	function getABPatternForDAPLink() {
# 		var Rpstr = "";
# 		var name = "Rp" + "=";
# 		var cookies = document.cookie.split(';');
# 		if(cookies == null || cookies.length == 0) {
# 			return "471_Link_A";
# 		}
# 		for(var i=0; i<cookies.length; i++) {
# 			var c = cookies[i].trim();
# 			if (c.indexOf(name)==0) {
# 				Rpstr = c.substring(name.length,c.length);
# 				var result;
# 				var reg = /[a-zA-Z]+/;
# 				while (result = Rpstr.match(reg)) {
# 					Rpstr = Rpstr.replace(result[0], '');
# 				}
# 			}
# 		}
# 		if (!(Rpstr == null || Rpstr.length < 2)) {
# 			var checkNumber = parseInt(Rpstr.substring(Rpstr.length-2));
# 			if (checkNumber < 30) {
# 				return "471_Link_B";
# 			} else {
# 				return "471_Link_A";
# 			}
# 		}
# 		return "471_Link_A";
# 	}
# </script>
#
# <div id="listTab" class="section bleeding">
# 	<div class="sectionContent">
# 		<div style="display: none;" id="freqCap_pushdown">
# 			<div class="pushdownContainer" id="pushdownContainer">
# 				<div class="ad">
# 				</div>
# 			</div>
# 		</div>
# 		<div class="linebreak"></div>
# 		<div class="sectionColumns">
# 			<div class="gridPanel grid12">
# 				<div class="tabs">
# 					<ul>
# 						<li id="tabHtl" tns="no" class="current"><a>施設ごとに表示</a></li>
# 						<li id="tabMap" tns="no">
# 									<a href="//search.travel.rakuten.co.jp/ds/undated/search?f_dai=japan&amp;f_chu=okinawa&amp;f_shou=nahashi&amp;f_latitude=0.0&amp;f_longitude=0.0&amp;f_sort=hotel&amp;f_page=1&amp;f_hyoji=30&amp;f_image=1&amp;f_tab=map&amp;f_point_min=0">
# 										地図上に表示
# 									</a></li>
# 							</ul>
# 					<p id="dapLink" class="dpsearch__links" style="display: none;">
# 						<span class="dpsearch__links-label">パッケージで検索</span>
# 						<a class="dpsearch__links-item" href="https://travel.rakuten.co.jp/package/ana/?l-id=471_ANA">
# 							<img src="https://trvimg.r10s.jp/share/common/images/icon_ana.svg" alt="ANA" width="44" height="12">航空券+宿泊</a>
# 						<a class="dpsearch__links-item" href="https://travel.rakuten.co.jp/package/jal/?l-id=471_JAL">
# 							<img src="https://trvimg.r10s.jp/share/common/images/icon_jal.svg" alt="JAL" width="44" height="12">航空券+宿泊</a>
# 					</p>
# 					<p class="attension">
# 					</p>
# 					</div>
# 			</div>
# 		</div>
# 	</div>
# </div>
# <!-- New Tab  end -->
# <input type="hidden" id="hotelNos" value="146927,182439,158644,183095,72693,149360,104526,134763,128440,163087,178447,171943,177761,181785,40768,160939,176757,130025,182884,167519,71990,38282,149369,136808,178292,148000,70884,67292,153504,76923,16693,16443,181339,172986,18195" />
# 	<input type="hidden" id="hotelPlanList" value='' />
# 	<input type="hidden" id="actionPath" value="search" />
# 	<input type="hidden" id="servicePath" value="undated" />
# 	<input type="hidden" id="fTab" value="hotel" />
# 	<input type="hidden" id="pageType" value="dateSearch" />
# 	<input type="hidden" id="squeezes" value="" />
# 	<input type="hidden" id="teikei" value="" />
# 	<input type="hidden" id="isOEM" value="0" />
# 	<input type="hidden" id="isHojin" value="0" />
# 	<input type="hidden" id="f_service" value="" />
# 	<input type="hidden" data-onetag-array-num data-onetag-name="hotelid" value="146927,182439,158644" />
# <input type="hidden" data-onetag-num data-onetag-name="checkin" value="" />
# <input type="hidden" data-onetag-num data-onetag-name="checkout" value="" /><!--sort-->
# <dl id="srtSwtch">
# 	<dt>並びかえ ： </dt>
# 			<dd><span>おすすめ順</span></dd>
# 				<dd>
# 						<a href="https://search.travel.rakuten.co.jp/ds/yado/okinawa/nahashi-low">料金の安い順</a></dd>
# 				<dd>
# 						<a href="https://search.travel.rakuten.co.jp/ds/yado/okinawa/nahashi-high">料金の高い順</a></dd>
# 				<dd>
# 						<a href="https://search.travel.rakuten.co.jp/ds/yado/okinawa/nahashi-review">評価が高い順</a></dd>
# 				</dl>
#
# <!--/sort--><!--**************paging start**************-->
# <div class="paging">
#     <p class="pagingTitle"><span><em>416</em>件中</span>1～30件表示</p><ul class="pagingNumber"><li class="pagingTo">[ <span class="pagingActive">1</span> | <a href="https://search.travel.rakuten.co.jp/ds/yado/okinawa/nahashi-p2">2</a> | <a href="https://search.travel.rakuten.co.jp/ds/yado/okinawa/nahashi-p3">3</a> | <a href="https://search.travel.rakuten.co.jp/ds/yado/okinawa/nahashi-p4">4</a> | <a href="https://search.travel.rakuten.co.jp/ds/yado/okinawa/nahashi-p5">5</a> ･･･ ]</li><li class="pagingBack"><a href="https://search.travel.rakuten.co.jp/ds/yado/okinawa/nahashi-p2">次の30件</a></li></ul><div class="paging" style="float:right; display:inline-block">
#         <img class="preferredSparklePagingPc" src="https://img.travel.rakuten.co.jp/share/themes/ds/images/Sparkle_final.png">
#         <a class="preferredExplanation" href="https://travel.faq.rakuten.net/detail/000015657" style="color: #1D52A5;">プリファードADとは</a>
#     </div>
# </div>
# <!--**************paging end**************--><link type="text/css" rel="stylesheet" href="https://trv.r10s.jp/share/themes/ds/css/trvl_srch_undtd_page_v2.css?_=20211029" media="screen">
# <script type="text/javascript">
# <!--
# 	var cks = document.cookie.split(',');
# 	var ckname = "Rp";
# 	var rpv = "99";
# 	var pattern = "";
#
# 	// Confirm Rp value
# 	if (cks && cks.length > 0) {
# 		// find Rp value from Cookies
# 		for(var i = 0; i < cks.length; i++) {
# 			var c = cks[i];
# 			while (c.charAt(0) == ' ') {
# 				c = c.substring(1);
# 			}
# 			// Rp is set in Cookie
# 			if (c.indexOf(ckname) >= 0) {
# 				// Get value between "Rp=" and ";"
# 				var sep = c.indexOf(";", c.indexOf(ckname));
# 				if (sep >= 0) {
# 					rpv = c.substring(c.indexOf(ckname) + ckname.length + 1, sep);
# 				} else {
# 					rpv = c.substring(c.indexOf(ckname) + ckname.length + 1, c.length);
# 				}
# 				// Get last 2 digits
# 				rpv = rpv.replace(/[^0-9]/g, '');
# 				rpv = rpv.substring(rpv.length - 2);
# 				// set back to DEFAULT
# 				if (!rpv || rpv.length != 2) {
# 					rpv = "99";
# 				}
# 				break;
# 			}
# 		}
# 	}
#
# 	// Append RAT tag
# 	pattern = parseInt(rpv) < 10 ? "[PR]" : "[注目]";
# 	if (!tags) var tags = {};
# 	if (!tags.data) tags.data = {};
# 	tags.data.ratabtest = {
# 		"name": "lad",
# 		"pattern": pattern
# 	};
# -->
# </script>
# <!--hotel list-->
# <input type="hidden" id="cassetteCount" value="dateSearch_a-30:c-0:p-0:e-0" />
# <ul id="htlBox" class="htlList" style="visibility: hidden">
# 	<li id="146927_list" class="listing" data-ratid="hotelList_ad_L000002979_1_146927" data-ratevent="appear" data-ratparam="all" >
# 	<section>
#
#         <div class="pr_icon">
#             PR
#         </div>
#         <div class="htlHead">
#         <div class="photo">
# 	  	<div class="htlImgWrp">
# 	    <a id="146927_gaikanlisting" href="javascript:void(0)" class="htlImg" data-ratId="hotelList_ad_L000002979_1_146927_photoClick" data-ratEvent="click" data-ratParam="all" >
# 	    	<span id="thumbnail_146927_listing" video-id="" class="thumbnail"><img src="https://trvimg.r10s.jp/share/image_up/146927/origin/0b0fa54d113a402287846d1b4147ecb67cea1e4d.47.9.26.3.jpg?fit=inside|900:507&interpolation=lanczos-none" alt=""></span>
# 				</a>
#         </div>
# 	    <a href="" class="thickbox btn360dgr 146927-pano" id="146927-panorama" style="display:none;" data-lid="dateSearchC_cassette_panorama_8_pg1"><span>360ビュー</span></a>
# 	    <!--/.photo-->
#     </div>
#
#     <div class="info">
#     <p class="area">
#     那覇</p>
# 	<h1 class=""><a href="https://travel.rakuten.co.jp/HOTEL/146927/146927.html?l-id=hotelList_ad_L000002979_1_146927" >ホテルアベスト那覇国際通り</a>
#                 <span class="preferred_sparkle_none"><img src="https://img.travel.rakuten.co.jp/share/themes/ds/images/Sparkle_final16x16.png"><span class="preferred_sparkletext">こちらの宿泊施設は、宿泊者からの総合評価点数が高い、もしくは多くの宿泊実績がある等の独自の条件を満たしたプリファードプログラム参加施設です。楽天トラベルへサービス利用料を支払うことにより、原則同条件の他の施設よりも上位に表示されています。（ヘルプページ参照）</span></span>
#             </h1>
# 		<p class="htlPrice">
#     		[最安料金]
# 			<span>3,055円〜</span><span class="incldTax">（消費税込3,360円〜）</span></p>
#     <p class="cstmrEvl">
#     <a id="146927_review" href="https://travel.rakuten.co.jp/HOTEL/146927/review.html?l-id=hotelList_ad_L000002979_1_146927">
# 			<span class="starfourHlf"></span>
# 				<strong>4.13</strong>
#
# 			[お客さまの声（526件）]
# 		</a>
#     </p>
# 		<p class="htlSpecial">国際通り徒歩０分の最高立地★地域一番の接客サービスを目指します★朝は大好評あんま～（お母さん）手作りの沖縄料理をどうぞ♪</p>
# 		<div class="tagwrp_v2">
#             <p class="hometown_icon"><img src="https://trvimg.r10s.jp/share/common/images/label_hometown_tax.svg"></p>
#             <div class="othrIndIcons 146927_link_couponlisting event_146927">
#                 <ul>
#                     <input type="hidden" id="146927_link_coupon_hotelNolisting" value="146927" />
#                 </ul>
#             </div>
# 		</div>
#     <!--/.info--></div>
#     </div>
#     <p class="htlAccess">
#            〒900-0015　沖縄県那覇市久茂地3-1-10<a href="//travel.rakuten.co.jp/share/gmap/map.html?f_longitude=127.6807344&f_latitude=26.2140234&TB_iframe=true&height=450&width=600" class="thickbox" title="ホテルアベスト那覇国際通り" data-ratId="hotelList_ad_L000002979_1_146927_mapClick" data-ratEvent="click" data-ratParam="all">[地図を見る]</a>
#     </p>
#     <p class="htlInfo">アクセス　：ゆいレール（モノレール）「県庁前」駅より徒歩２分、那覇空港より車で約15分<br>
#         駐車場　　：提携駐車場　1,000円/泊　入出庫1泊1回限　24時〜6時入出庫不可　詳細お問い合わせ下さい。</p>
# 	<ul class="btnUndtd">
# 		<li><a href="//hotel.travel.rakuten.co.jp/hotelinfo/plan/146927?f_teikei=&l-id=hotelList_ad_L000002979_1_146927"><span>宿泊プラン一覧</span></a></li>
# 			<li><a id="RM_DP_PLAN_146927" class="dplkn" hotel_no="146927" href="javascript:void(0)" data-ratId="hotelList_ad_L000002979_1_146927_dpPlanClick" data-ratEvent="click" data-ratParam="all"><span>航空券付プラン一覧</span></a></li>
# 		</ul>
#     </section>
#
#     <div class="photoPrnt">
#     	<div class="photoBox" id="146927-photo-contents" style="display: none; opacity: 0; z-index:">
#     		<p class="photoCls"><a class="closePhotoBox" href="javascript:void(0);"  photoBoxId="146927-photo-contents">閉じる</a></p>
#     		<ul>
#     		<li class="photoStck" id="photo-146927-0"></li>
#     		<li class="photoStck" id="photo-146927-1"></li>
#     		<li class="photoStck" id="photo-146927-2"></li>
#     		<li class="photoStck" id="photo-146927-3"></li>
#     		<li class="photoStck" id="photo-146927-4"></li>
#     		<li class="photoStck" id="photo-146927-5"></li>
#     		</ul>
# 			<p class="morePix"><a href="https://travel.rakuten.co.jp/HOTEL/146927/gallery.html">もっと見る</a></p>
#     <!--/.photoBox-->
#     	</div>
#     <!--/.photoPrnt-->
#     </div>
# </li>
#
# <li id="182439_list" class="listing" data-ratid="hotelList_ad_L000002979_2_182439" data-ratevent="appear" data-ratparam="all" >
# 	<section>
#
#         <div class="pr_icon">
#             PR
#         </div>
#         <div class="htlHead">
#         <div class="photo">
# 	  	<div class="htlImgWrp">
# 	    <a id="182439_gaikanlisting" href="javascript:void(0)" class="htlImg" data-ratId="hotelList_ad_L000002979_2_182439_photoClick" data-ratEvent="click" data-ratParam="all" >
# 	    	<span id="thumbnail_182439_listing" video-id="" class="thumbnail"><img src="https://trvimg.r10s.jp/share/image_up/182439/origin/c2cbee2f34315ad59baeaa1d99492a21377860bc.47.9.26.3.jpg?fit=inside|900:507&interpolation=lanczos-none" alt=""></span>
# 				</a>
#         </div>
# 	    <a href="" class="thickbox btn360dgr 182439-pano" id="182439-panorama" style="display:none;" data-lid="dateSearchC_cassette_panorama_8_pg1"><span>360ビュー</span></a>
# 	    <!--/.photo-->
#     </div>
#
#     <div class="info">
#     <p class="area">
#     那覇</p>
# 	<h1 class=""><a href="https://travel.rakuten.co.jp/HOTEL/182439/182439.html?l-id=hotelList_ad_L000002979_2_182439" >ネストホテル那覇久茂地</a>
#                 <span class="preferred_sparkle_none"><img src="https://img.travel.rakuten.co.jp/share/themes/ds/images/Sparkle_final16x16.png"><span class="preferred_sparkletext">こちらの宿泊施設は、宿泊者からの総合評価点数が高い、もしくは多くの宿泊実績がある等の独自の条件を満たしたプリファードプログラム参加施設です。楽天トラベルへサービス利用料を支払うことにより、原則同条件の他の施設よりも上位に表示されています。（ヘルプページ参照）</span></span>
#             </h1>
# 		<p class="htlPrice">
#     		[最安料金]
# 			<span>2,591円〜</span><span class="incldTax">（消費税込2,850円〜）</span></p>
#     <p class="cstmrEvl">
#     <a id="182439_review" href="https://travel.rakuten.co.jp/HOTEL/182439/review.html?l-id=hotelList_ad_L000002979_2_182439">
# 			<span class="starfive"></span>
# 				<strong>4.65</strong>
#
# 			[お客さまの声（99件）]
# 		</a>
#     </p>
# 		<p class="htlSpecial">オシャレなホテルに多彩なお部屋をご用意しました。ファミリーやご夫婦、カップルやお1人様でのご利用にも最適なホテルです。</p>
# 		<div class="tagwrp_v2">
#             <p class="hometown_icon"><img src="https://trvimg.r10s.jp/share/common/images/label_hometown_tax.svg"></p>
#             <div class="othrIndIcons 182439_link_couponlisting event_182439">
#                 <ul>
#                     <input type="hidden" id="182439_link_coupon_hotelNolisting" value="182439" />
#                 </ul>
#             </div>
# 		</div>
#     <!--/.info--></div>
#     </div>
#     <p class="htlAccess">
#            〒900-0015　沖縄県那覇市久茂地2-22-5<a href="//travel.rakuten.co.jp/share/gmap/map.html?f_longitude=127.6822461&f_latitude=26.2195155&TB_iframe=true&height=450&width=600" class="thickbox" title="ネストホテル那覇久茂地" data-ratId="hotelList_ad_L000002979_2_182439_mapClick" data-ratEvent="click" data-ratParam="all">[地図を見る]</a>
#     </p>
#     <p class="htlInfo">アクセス　：ゆいレール美栄橋駅より徒歩５分／那覇空港よりお車にて約１０分<br>
#         駐車場　　：有り　40台　1500円/1日　予約不要</p>
# 	<ul class="btnUndtd">
# 		<li><a href="//hotel.travel.rakuten.co.jp/hotelinfo/plan/182439?f_teikei=&l-id=hotelList_ad_L000002979_2_182439"><span>宿泊プラン一覧</span></a></li>
# 			<li><a id="RM_DP_PLAN_182439" class="dplkn" hotel_no="182439" href="javascript:void(0)" data-ratId="hotelList_ad_L000002979_2_182439_dpPlanClick" data-ratEvent="click" data-ratParam="all"><span>航空券付プラン一覧</span></a></li>
# 		</ul>
#     </section>
#
#     <div class="photoPrnt">
#     	<div class="photoBox" id="182439-photo-contents" style="display: none; opacity: 0; z-index:">
#     		<p class="photoCls"><a class="closePhotoBox" href="javascript:void(0);"  photoBoxId="182439-photo-contents">閉じる</a></p>
#     		<ul>
#     		<li class="photoStck" id="photo-182439-0"></li>
#     		<li class="photoStck" id="photo-182439-1"></li>
#     		<li class="photoStck" id="photo-182439-2"></li>
#     		<li class="photoStck" id="photo-182439-3"></li>
#     		<li class="photoStck" id="photo-182439-4"></li>
#     		<li class="photoStck" id="photo-182439-5"></li>
#     		</ul>
# 			<p class="morePix"><a href="https://travel.rakuten.co.jp/HOTEL/182439/gallery.html">もっと見る</a></p>
#     <!--/.photoBox-->
#     	</div>
#     <!--/.photoPrnt-->
#     </div>
# </li>
#
# <li id="158644_list" class="listing" data-ratid="hotelList_ad_L000002979_3_158644" data-ratevent="appear" data-ratparam="all" >
# 	<section>
#
#         <div class="pr_icon">
#             PR
#         </div>
#         <div class="htlHead">
#         <div class="photo">
# 	  	<div class="htlImgWrp">
# 	    <a id="158644_gaikanlisting" href="javascript:void(0)" class="htlImg" data-ratId="hotelList_ad_L000002979_3_158644_photoClick" data-ratEvent="click" data-ratParam="all" >
# 	    	<span id="thumbnail_158644_listing" video-id="" class="thumbnail"><img src="https://trvimg.r10s.jp/share/image_up/158644/origin/2c14024f0c124051b2cc427e34ea985c70e7b881.47.9.26.3.jpg?fit=inside|900:507&interpolation=lanczos-none" alt=""></span>
# 				</a>
#         </div>
# 	    <a href="" class="thickbox btn360dgr 158644-pano" id="158644-panorama" style="display:none;" data-lid="dateSearchC_cassette_panorama_8_pg1"><span>360ビュー</span></a>
# 	    <!--/.photo-->
#     </div>
#
#     <div class="info">
#     <p class="area">
#     那覇</p>
# 	<h1 class=""><a href="https://travel.rakuten.co.jp/HOTEL/158644/158644.html?l-id=hotelList_ad_L000002979_3_158644" >アベストＣＵＢＥ那覇国際通りー全室鍵付きキャビン型ホテルー</a>
#                 <span class="preferred_sparkle_none"><img src="https://img.travel.rakuten.co.jp/share/themes/ds/images/Sparkle_final16x16.png"><span class="preferred_sparkletext">こちらの宿泊施設は、宿泊者からの総合評価点数が高い、もしくは多くの宿泊実績がある等の独自の条件を満たしたプリファードプログラム参加施設です。楽天トラベルへサービス利用料を支払うことにより、原則同条件の他の施設よりも上位に表示されています。（ヘルプページ参照）</span></span>
#             </h1>
# 		<p class="htlPrice">
#     		[最安料金]
# 			<span>2,728円〜</span><span class="incldTax">（消費税込3,000円〜）</span></p>
#     <p class="cstmrEvl">
#     <a id="158644_review" href="https://travel.rakuten.co.jp/HOTEL/158644/review.html?l-id=hotelList_ad_L000002979_3_158644">
# 			<span class="starfourHlf"></span>
# 				<strong>4.38</strong>
#
# 			[お客さまの声（211件）]
# 		</a>
#     </p>
# 		<p class="htlSpecial">【国際通り沿いのキャビン型ホテル】相部屋無しで全室施錠可能★ご宿泊者朝食無料★2名〜4名部屋もあり★</p>
# 		<div class="tagwrp_v2">
#             <p class="hometown_icon"><img src="https://trvimg.r10s.jp/share/common/images/label_hometown_tax.svg"></p>
#             <div class="othrIndIcons 158644_link_couponlisting event_158644">
#                 <ul>
#                     <input type="hidden" id="158644_link_coupon_hotelNolisting" value="158644" />
#                 </ul>
#             </div>
# 		</div>
#     <!--/.info--></div>
#     </div>
#     <p class="htlAccess">
#            〒900-0013　沖縄県那覇市牧志3-13-17<a href="//travel.rakuten.co.jp/share/gmap/map.html?f_longitude=127.69160280000006&f_latitude=26.2172288&TB_iframe=true&height=450&width=600" class="thickbox" title="アベストＣＵＢＥ那覇国際通りー全室鍵付きキャビン型ホテルー" data-ratId="hotelList_ad_L000002979_3_158644_mapClick" data-ratEvent="click" data-ratParam="all">[地図を見る]</a>
#     </p>
#     <p class="htlInfo">アクセス　：ゆいレール「牧志駅」より徒歩１分・国際通りまで徒歩0分♪那覇空港からホテルまでゆいレールで15分♪<br>
#         駐車場　　：無し</p>
# 	<ul class="btnUndtd">
# 		<li><a href="//hotel.travel.rakuten.co.jp/hotelinfo/plan/158644?f_teikei=&l-id=hotelList_ad_L000002979_3_158644"><span>宿泊プラン一覧</span></a></li>
# 			<li><a id="RM_DP_PLAN_158644" class="dplkn" hotel_no="158644" href="javascript:void(0)" data-ratId="hotelList_ad_L000002979_3_158644_dpPlanClick" data-ratEvent="click" data-ratParam="all"><span>航空券付プラン一覧</span></a></li>
# 		</ul>
#     </section>
#
#     <div class="photoPrnt">
#     	<div class="photoBox" id="158644-photo-contents" style="display: none; opacity: 0; z-index:">
#     		<p class="photoCls"><a class="closePhotoBox" href="javascript:void(0);"  photoBoxId="158644-photo-contents">閉じる</a></p>
#     		<ul>
#     		<li class="photoStck" id="photo-158644-0"></li>
#     		<li class="photoStck" id="photo-158644-1"></li>
#     		<li class="photoStck" id="photo-158644-2"></li>
#     		<li class="photoStck" id="photo-158644-3"></li>
#     		<li class="photoStck" id="photo-158644-4"></li>
#     		<li class="photoStck" id="photo-158644-5"></li>
#     		</ul>
# 			<p class="morePix"><a href="https://travel.rakuten.co.jp/HOTEL/158644/gallery.html">もっと見る</a></p>
#     <!--/.photoBox-->
#     	</div>
#     <!--/.photoPrnt-->
#     </div>
# </li>
#
# <li id="183095_list" class="listing" data-ratid="hotelList_ad_L000002979_4_183095" data-ratevent="appear" data-ratparam="all" >
# 	<section>
#
#         <div class="pr_icon">
#             PR
#         </div>
#         <div class="htlHead">
#         <div class="photo">
# 	  	<div class="htlImgWrp">
# 	    <a id="183095_gaikanlisting" href="javascript:void(0)" class="htlImg" data-ratId="hotelList_ad_L000002979_4_183095_photoClick" data-ratEvent="click" data-ratParam="all" >
# 	    	<span id="thumbnail_183095_listing" video-id="" class="thumbnail"><img src="https://trvimg.r10s.jp/share/image_up/183095/origin/9ab5482f672ee9c93113ee355d3f105e22fa3be4.47.9.26.3.jpg?fit=inside|900:507&interpolation=lanczos-none" alt=""></span>
# 				</a>
#         </div>
# 	    <a href="" class="thickbox btn360dgr 183095-pano" id="183095-panorama" style="display:none;" data-lid="dateSearchC_cassette_panorama_8_pg1"><span>360ビュー</span></a>
# 	    <!--/.photo-->
#     </div>
#
#     <div class="info">
#     <p class="area">
#     那覇</p>
# 	<h1 class=""><a href="https://travel.rakuten.co.jp/HOTEL/183095/183095.html?l-id=hotelList_ad_L000002979_4_183095" >ホテルグランコンソルト那覇</a>
#                 <span class="preferred_sparkle_none"><img src="https://img.travel.rakuten.co.jp/share/themes/ds/images/Sparkle_final16x16.png"><span class="preferred_sparkletext">こちらの宿泊施設は、宿泊者からの総合評価点数が高い、もしくは多くの宿泊実績がある等の独自の条件を満たしたプリファードプログラム参加施設です。楽天トラベルへサービス利用料を支払うことにより、原則同条件の他の施設よりも上位に表示されています。（ヘルプページ参照）</span></span>
#             </h1>
# 		<p class="htlPrice">
#     		[最安料金]
# 			<span>4,546円〜</span><span class="incldTax">（消費税込5,000円〜）</span></p>
#     <p class="cstmrEvl">
#     <a id="183095_review" href="https://travel.rakuten.co.jp/HOTEL/183095/review.html?l-id=hotelList_ad_L000002979_4_183095">
# 			<span class="starfourHlf"></span>
# 				<strong>4.44</strong>
#
# 			[お客さまの声（62件）]
# 		</a>
#     </p>
# 		<p class="htlSpecial">2022年9月新規OPEN！国際通り徒歩3分・ご宿泊の皆様ご利用可能なフリーラウンジございます</p>
# 		<div class="tagwrp_v2">
#             <p class="hometown_icon"><img src="https://trvimg.r10s.jp/share/common/images/label_hometown_tax.svg"></p>
#             <div class="othrIndIcons 183095_link_couponlisting event_183095">
#                 <ul>
#                     <input type="hidden" id="183095_link_coupon_hotelNolisting" value="183095" />
#                 </ul>
#             </div>
# 		</div>
#     <!--/.info--></div>
#     </div>
#     <p class="htlAccess">
#            〒900-0014　沖縄県那覇市松尾1-18-25<a href="//travel.rakuten.co.jp/share/gmap/map.html?f_longitude=127.6823056208321&f_latitude=26.21238991042739&TB_iframe=true&height=450&width=600" class="thickbox" title="ホテルグランコンソルト那覇" data-ratId="hotelList_ad_L000002979_4_183095_mapClick" data-ratEvent="click" data-ratParam="all">[地図を見る]</a>
#     </p>
#     <p class="htlInfo">アクセス　：那覇空港から車で約15分、ゆいレール「県庁前駅」より徒歩約５分<br>
#         駐車場　　：有り：28台　料金：1,650円/泊 (税込み）高さ制限がございます。</p>
# 	<ul class="btnUndtd">
# 		<li><a href="//hotel.travel.rakuten.co.jp/hotelinfo/plan/183095?f_teikei=&l-id=hotelList_ad_L000002979_4_183095"><span>宿泊プラン一覧</span></a></li>
# 			<li><a id="RM_DP_PLAN_183095" class="dplkn" hotel_no="183095" href="javascript:void(0)" data-ratId="hotelList_ad_L000002979_4_183095_dpPlanClick" data-ratEvent="click" data-ratParam="all"><span>航空券付プラン一覧</span></a></li>
# 		</ul>
#     </section>
#
#     <div class="photoPrnt">
#     	<div class="photoBox" id="183095-photo-contents" style="display: none; opacity: 0; z-index:">
#     		<p class="photoCls"><a class="closePhotoBox" href="javascript:void(0);"  photoBoxId="183095-photo-contents">閉じる</a></p>
#     		<ul>
#     		<li class="photoStck" id="photo-183095-0"></li>
#     		<li class="photoStck" id="photo-183095-1"></li>
#     		<li class="photoStck" id="photo-183095-2"></li>
#     		<li class="photoStck" id="photo-183095-3"></li>
#     		<li class="photoStck" id="photo-183095-4"></li>
#     		<li class="photoStck" id="photo-183095-5"></li>
#     		</ul>
# 			<p class="morePix"><a href="https://travel.rakuten.co.jp/HOTEL/183095/gallery.html">もっと見る</a></p>
#     <!--/.photoBox-->
#     	</div>
#     <!--/.photoPrnt-->
#     </div>
# </li>
#
# <li id="72693_list" class="listing" data-ratid="hotelList_ad_L000002979_5_72693" data-ratevent="appear" data-ratparam="all" >
# 	<section>
#
#         <div class="pr_icon">
#             PR
#         </div>
#         <div class="htlHead">
#         <div class="photo">
# 	  	<div class="htlImgWrp">
# 	    <a id="72693_gaikanlisting" href="javascript:void(0)" class="htlImg" data-ratId="hotelList_ad_L000002979_5_72693_photoClick" data-ratEvent="click" data-ratParam="all" >
# 	    	<span id="thumbnail_72693_listing" video-id="" class="thumbnail"><img src="https://trvimg.r10s.jp/share/image_up/72693/origin/e5aa44d94a8047b44f8ab75dd2e57cb18a0772ba.47.9.26.3.jpg?fit=inside|900:507&interpolation=lanczos-none" alt=""></span>
# 				</a>
#         </div>
# 	    <a href="" class="thickbox btn360dgr 72693-pano" id="72693-panorama" style="display:none;" data-lid="dateSearchC_cassette_panorama_8_pg1"><span>360ビュー</span></a>
# 	    <!--/.photo-->
#     </div>
#
#     <div class="info">
#     <p class="area">
#     那覇</p>
# 	<h1 class=""><a href="https://travel.rakuten.co.jp/HOTEL/72693/72693.html?l-id=hotelList_ad_L000002979_5_72693" >那覇ウエスト・イン</a>
#                 <span class="preferred_sparkle_none"><img src="https://img.travel.rakuten.co.jp/share/themes/ds/images/Sparkle_final16x16.png"><span class="preferred_sparkletext">こちらの宿泊施設は、宿泊者からの総合評価点数が高い、もしくは多くの宿泊実績がある等の独自の条件を満たしたプリファードプログラム参加施設です。楽天トラベルへサービス利用料を支払うことにより、原則同条件の他の施設よりも上位に表示されています。（ヘルプページ参照）</span></span>
#             </h1>
# 		<p class="htlPrice">
#     		[最安料金]
# 			<span>2,400円〜</span><span class="incldTax">（消費税込2,640円〜）</span></p>
#     <p class="cstmrEvl">
#     <a id="72693_review" href="https://travel.rakuten.co.jp/HOTEL/72693/review.html?l-id=hotelList_ad_L000002979_5_72693">
# 			<span class="starfourHlf"></span>
# 				<strong>4.16</strong>
#
# 			[お客さまの声（692件）]
# 		</a>
#     </p>
# 		<p class="htlSpecial">全室個別Wi-Fi＆バルコニー付　コンクリート打ちっぱなしがクールさと清潔感を演出　バストイレセパレード</p>
# 		<div class="tagwrp_v2">
#             <p class="hometown_icon"><img src="https://trvimg.r10s.jp/share/common/images/label_hometown_tax.svg"></p>
#             <div class="othrIndIcons 72693_link_couponlisting event_72693">
#                 <ul>
#                     <input type="hidden" id="72693_link_coupon_hotelNolisting" value="72693" />
#                 </ul>
#             </div>
# 		</div>
#     <!--/.info--></div>
#     </div>
#     <p class="htlAccess">
#            〒900-0036　沖縄県那覇市西1-16-7<a href="//travel.rakuten.co.jp/share/gmap/map.html?f_longitude=127.67097680000006&f_latitude=26.213301&TB_iframe=true&height=450&width=600" class="thickbox" title="那覇ウエスト・イン" data-ratId="hotelList_ad_L000002979_5_72693_mapClick" data-ratEvent="click" data-ratParam="all">[地図を見る]</a>
#     </p>
#     <p class="htlInfo">アクセス　：コンビニ目の前！新館＆本館〈全150室〉空港⇔ホテル車で約10分。旭橋駅⇔ホテル徒歩約８分。那覇港まで徒歩約2分。<br>
#         駐車場　　：有　収容台数50台（先着順/予約不可）1泊1,100円込</p>
# 	<ul class="btnUndtd">
# 		<li><a href="//hotel.travel.rakuten.co.jp/hotelinfo/plan/72693?f_teikei=&l-id=hotelList_ad_L000002979_5_72693"><span>宿泊プラン一覧</span></a></li>
# 			<li><a id="RM_DP_PLAN_72693" class="dplkn" hotel_no="72693" href="javascript:void(0)" data-ratId="hotelList_ad_L000002979_5_72693_dpPlanClick" data-ratEvent="click" data-ratParam="all"><span>航空券付プラン一覧</span></a></li>
# 		</ul>
#     </section>
#
#     <div class="photoPrnt">
#     	<div class="photoBox" id="72693-photo-contents" style="display: none; opacity: 0; z-index:">
#     		<p class="photoCls"><a class="closePhotoBox" href="javascript:void(0);"  photoBoxId="72693-photo-contents">閉じる</a></p>
#     		<ul>
#     		<li class="photoStck" id="photo-72693-0"></li>
#     		<li class="photoStck" id="photo-72693-1"></li>
#     		<li class="photoStck" id="photo-72693-2"></li>
#     		<li class="photoStck" id="photo-72693-3"></li>
#     		<li class="photoStck" id="photo-72693-4"></li>
#     		<li class="photoStck" id="photo-72693-5"></li>
#     		</ul>
# 			<p class="morePix"><a href="https://travel.rakuten.co.jp/HOTEL/72693/gallery.html">もっと見る</a></p>
#     <!--/.photoBox-->
#     	</div>
#     <!--/.photoPrnt-->
#     </div>
# </li>
#
# <li id="149360_list" class="listing" data-ratid="hotelList_ad_L000002979_6_149360" data-ratevent="appear" data-ratparam="all" >
# 	<section>
#
#         <div class="pr_icon">
#             PR
#         </div>
#         <div class="htlHead">
#         <div class="photo">
# 	  	<div class="htlImgWrp">
# 	    <a id="149360_gaikanlisting" href="javascript:void(0)" class="htlImg" data-ratId="hotelList_ad_L000002979_6_149360_photoClick" data-ratEvent="click" data-ratParam="all" >
# 	    	<span id="thumbnail_149360_listing" video-id="" class="thumbnail"><img src="https://trvimg.r10s.jp/share/image_up/149360/origin/dde597450c1c85385a6c0e13c4558616c95c8159.47.9.26.3.jpg?fit=inside|900:507&interpolation=lanczos-none" alt=""></span>
# 				</a>
#         </div>
# 	    <a href="" class="thickbox btn360dgr 149360-pano" id="149360-panorama" style="display:none;" data-lid="dateSearchC_cassette_panorama_8_pg1"><span>360ビュー</span></a>
# 	    <!--/.photo-->
#     </div>
#
#     <div class="info">
#     <p class="area">
#     那覇</p>
# 	<h1 class=""><a href="https://travel.rakuten.co.jp/HOTEL/149360/149360.html?l-id=hotelList_ad_L000002979_6_149360" >アルモントホテル那覇県庁前</a>
#                 <span class="preferred_sparkle_none"><img src="https://img.travel.rakuten.co.jp/share/themes/ds/images/Sparkle_final16x16.png"><span class="preferred_sparkletext">こちらの宿泊施設は、宿泊者からの総合評価点数が高い、もしくは多くの宿泊実績がある等の独自の条件を満たしたプリファードプログラム参加施設です。楽天トラベルへサービス利用料を支払うことにより、原則同条件の他の施設よりも上位に表示されています。（ヘルプページ参照）</span></span>
#             </h1>
# 		<p class="htlPrice">
#     		[最安料金]
# 			<span>4,091円〜</span><span class="incldTax">（消費税込4,500円〜）</span></p>
#     <p class="cstmrEvl">
#     <a id="149360_review" href="https://travel.rakuten.co.jp/HOTEL/149360/review.html?l-id=hotelList_ad_L000002979_6_149360">
# 			<span class="starfourHlf"></span>
# 				<strong>4.35</strong>
#
# 			[お客さまの声（340件）]
# 		</a>
#     </p>
# 		<p class="htlSpecial">◆人工温泉光明石温泉宿泊者無料◆全室禁煙&amp;Wi-Fi無料◆徒歩数秒にコンビニ３社！</p>
# 		<div class="tagwrp_v2">
#             <p class="hometown_icon"><img src="https://trvimg.r10s.jp/share/common/images/label_hometown_tax.svg"></p>
#             <div class="othrIndIcons 149360_link_couponlisting event_149360">
#                 <ul>
#                     <input type="hidden" id="149360_link_coupon_hotelNolisting" value="149360" />
#                 </ul>
#             </div>
# 		</div>
#     <!--/.info--></div>
#     </div>
#     <p class="htlAccess">
#            〒900-0015　沖縄県那覇市久茂地1-3-5<a href="//travel.rakuten.co.jp/share/gmap/map.html?f_longitude=127.67815862460633&f_latitude=26.21342490266712&TB_iframe=true&height=450&width=600" class="thickbox" title="アルモントホテル那覇県庁前" data-ratId="hotelList_ad_L000002979_6_149360_mapClick" data-ratEvent="click" data-ratParam="all">[地図を見る]</a>
#     </p>
#     <p class="htlInfo">アクセス　：「県庁前」 駅／那覇バスセンター／県庁／那覇市役所／国際通りまで徒歩約3分<br>
#         駐車場　　：有料先着順ご予約不可。立体駐車場完備。台数・車高制限有り。1,100円（税込）。※駐輪場なし</p>
# 	<ul class="btnUndtd">
# 		<li><a href="//hotel.travel.rakuten.co.jp/hotelinfo/plan/149360?f_teikei=&l-id=hotelList_ad_L000002979_6_149360"><span>宿泊プラン一覧</span></a></li>
# 			<li><a id="RM_DP_PLAN_149360" class="dplkn" hotel_no="149360" href="javascript:void(0)" data-ratId="hotelList_ad_L000002979_6_149360_dpPlanClick" data-ratEvent="click" data-ratParam="all"><span>航空券付プラン一覧</span></a></li>
# 		</ul>
#     </section>
#
#     <div class="photoPrnt">
#     	<div class="photoBox" id="149360-photo-contents" style="display: none; opacity: 0; z-index:">
#     		<p class="photoCls"><a class="closePhotoBox" href="javascript:void(0);"  photoBoxId="149360-photo-contents">閉じる</a></p>
#     		<ul>
#     		<li class="photoStck" id="photo-149360-0"></li>
#     		<li class="photoStck" id="photo-149360-1"></li>
#     		<li class="photoStck" id="photo-149360-2"></li>
#     		<li class="photoStck" id="photo-149360-3"></li>
#     		<li class="photoStck" id="photo-149360-4"></li>
#     		<li class="photoStck" id="photo-149360-5"></li>
#     		</ul>
# 			<p class="morePix"><a href="https://travel.rakuten.co.jp/HOTEL/149360/gallery.html">もっと見る</a></p>
#     <!--/.photoBox-->
#     	</div>
#     <!--/.photoPrnt-->
#     </div>
# </li>
#
# <li id="104526_list" class="" data-ratid="hotelList_7_104526" data-ratevent="appear" data-ratparam="all" >
# 	<section>
#
#         <div class="htlHead">
#         <div class="photo">
# 	  	<div class="htlImgWrp">
# ...
#                                                 <img src="https://img.travel.rakuten.co.jp/share/themes/header/images/icon_arrow01_hover.gif" id="sideImg" class="sideImg">
#                                                 <a class="showMoreCheckbox" onclick="showMore(this)">もっと見る</a>
#                                             </div>
#                                         </li>
#                                     </ul>
#                             </dd>
#                         <dt>部屋</dt>
#                             <dd>
#                                 <ul>
#                                     <li class="feature-parent-kinen">
#                                                 <input type="checkbox"  class="feature-kinen" onchange="autoSelectDuplication(this);autoSelectChildren(this)" id="kinen" value="kinen"/>
#                                                 <label for="kinen">禁煙ルーム</label>
#                                             </li>
#                                             <li class="feature-parent-kitsuen">
#                                                 <input type="checkbox"  class="feature-kitsuen" onchange="autoSelectDuplication(this);autoSelectChildren(this)" id="kitsuen" value="kitsuen"/>
#                                                 <label for="kitsuen">喫煙ルーム</label>
#                                             </li>
#                                             <li class="feature-parent-internet">
#                                                 <input type="checkbox" name="f_squeezes" class="feature-internet" onchange="autoSelectDuplication(this);autoSelectChildren(this)" id="internet" value="internet"/>
#                                                 <label for="internet">インターネット可</label>
#                                             </li>
#                                             <li class="feature-parent-roten">
#                                                 <input type="checkbox"  class="feature-roten" onchange="autoSelectDuplication(this);autoSelectChildren(this)" id="roten" value="roten"/>
#                                                 <label for="roten">露天風呂付き客室</label>
#                                             </li>
#                                             </ul>
#                             </dd>
#                         <dt>新型コロナウイルス対策</dt>
#                             <dd>
#                                 <ul>
#                                     <li class="feature-parent-via_staff">
#                                                 <input type="checkbox" name="f_squeezes" class="feature-via_staff" onchange="autoSelectDuplication(this);autoSelectChildren(this)" id="via_staff" value="via_staff"/>
#                                                 <label for="via_staff">スタッフのウイルス対策あり</label>
#                                             </li>
#                                             <li class="feature-parent-via_disinfect">
#                                                 <input type="checkbox" name="f_squeezes" class="feature-via_disinfect" onchange="autoSelectDuplication(this);autoSelectChildren(this)" id="via_disinfect" value="via_disinfect"/>
#                                                 <label for="via_disinfect">館内・客室などの消毒清掃あり</label>
#                                             </li>
#                                             <li class="feature-parent-via_vent">
#                                                 <input type="checkbox" name="f_squeezes" class="feature-via_vent" onchange="autoSelectDuplication(this);autoSelectChildren(this)" id="via_vent" value="via_vent"/>
#                                                 <label for="via_vent">館内・客室などの換気あり</label>
#                                             </li>
#                                             <li class="feature-parent-via_chkinout">
#                                                 <input type="checkbox" name="f_squeezes" class="feature-via_chkinout" onchange="autoSelectDuplication(this);autoSelectChildren(this)" id="via_chkinout" value="via_chkinout"/>
#                                                 <label for="via_chkinout">チェックイン・アウト時の接触回避策あり</label>
#                                             </li>
#                                             <li class="feature-parent-via_room">
#                                                 <input type="checkbox" name="f_squeezes" class="feature-via_room" onchange="autoSelectDuplication(this);autoSelectChildren(this)" id="via_room" value="via_room"/>
#                                                 <label for="via_room">客室に消毒液などあり</label>
#                                             </li>
#                                             <li class="feature-parent-via_meal more hidden">
#                                                 <input type="checkbox" name="f_squeezes" class="feature-via_meal" onchange="autoSelectDuplication(this);autoSelectChildren(this)" id="via_meal" value="via_meal"/>
#                                                 <label for="via_meal">食事時の接触回避策あり</label>
#                                             </li>
#                                             <li class="feature-parent-via_bath more hidden">
#                                                 <input type="checkbox" name="f_squeezes" class="feature-via_bath" onchange="autoSelectDuplication(this);autoSelectChildren(this)" id="via_bath" value="via_bath"/>
#                                                 <label for="via_bath">大浴場の消毒・接触回避策あり</label>
#                                             </li>
#                                             <li class="feature-parent-via_other_req more hidden">
#                                                 <input type="checkbox" name="f_squeezes" class="feature-via_other_req" onchange="autoSelectDuplication(this);autoSelectChildren(this)" id="via_other_req" value="via_other_req"/>
#                                                 <label for="via_other_req">宿泊者への消毒などお願いあり</label>
#                                             </li>
#                                             <li class="feature-parent-via_emergency more hidden">
#                                                 <input type="checkbox" name="f_squeezes" class="feature-via_emergency" onchange="autoSelectDuplication(this);autoSelectChildren(this)" id="via_emergency" value="via_emergency"/>
#                                                 <label for="via_emergency">緊急時のマニュアル・スタッフ教育あり</label>
#                                             </li>
#                                             <li>
#                                             <div class="positionDiv">
#                                                 <img src="https://img.travel.rakuten.co.jp/share/themes/header/images/icon_arrow01_hover.gif" id="sideImg" class="sideImg">
#                                                 <a class="showMoreCheckbox" onclick="showMore(this)">もっと見る</a>
#                                             </div>
#                                         </li>
#                                     </ul>
#                             </dd>
#                         <dt>バリアフリー</dt>
#                             <dd>
#                                 <ul>
#                                     <li class="feature-parent-uwhlchair">
#                                                 <input type="checkbox" name="f_squeezes" class="feature-uwhlchair" onchange="autoSelectDuplication(this);autoSelectChildren(this)" id="uwhlchair" value="uwhlchair"/>
#                                                 <label for="uwhlchair">車椅子可</label>
#                                             </li>
#                                             <li class="feature-parent-bfroom">
#                                                 <input type="checkbox" name="f_squeezes" class="feature-bfroom" onchange="autoSelectDuplication(this);autoSelectChildren(this)" id="bfroom" value="bfroom"/>
#                                                 <label for="bfroom">バリアフリールーム</label>
#                                             </li>
#                                             <li class="feature-parent-bftoilet">
#                                                 <input type="checkbox" name="f_squeezes" class="feature-bftoilet" onchange="autoSelectDuplication(this);autoSelectChildren(this)" id="bftoilet" value="bftoilet"/>
#                                                 <label for="bftoilet">バリアフリー用トイレ</label>
#                                             </li>
#                                             <li class="feature-parent-rwhlchair">
#                                                 <input type="checkbox" name="f_squeezes" class="feature-rwhlchair" onchange="autoSelectDuplication(this);autoSelectChildren(this)" id="rwhlchair" value="rwhlchair"/>
#                                                 <label for="rwhlchair">貸出用車椅子</label>
#                                             </li>
#                                             </ul>
#                             </dd>
#                         <dt>ふるさと納税</dt>
#                             <dd>
#                                 <ul>
#                                     <li class="feature-parent-hmtwntax">
#                                                 <input type="checkbox" name="f_squeezes" class="feature-hmtwntax" onchange="autoSelectDuplication(this);autoSelectChildren(this)" id="hmtwntax" value="hmtwntax"/>
#                                                 <label for="hmtwntax">ふるさと納税クーポン対象</label>
#                                             </li>
#                                             </ul>
#                             </dd>
#                         </dl>
#
#                 <p class="stdSrchBtn smlSz">
#                     <a id="dh-squeeze-submit" href="javascript:document.getElementById('dh-form-squeeze').submit();">絞り込む</a>
#                 </p>
#             </dd>
#         </dl>
#     </form>
# </div>
# <div class="mboxDefault"></div>
#
# <script type="text/javascript" src="https://trv.r10s.jp/share/themes/ds/js/lowerprice.js?p=20200722"></script>
# <!-- end of domestic squeeze form -->
# <dl id="aroundArea">
# <dt class="ttlBar">周辺エリアのホテル・旅館</dt>
# <dd class="outerBox">
# <ul>
# <li class="first"><a href="https://travel.rakuten.co.jp/yado/okinawa/">沖縄県 ホテル・旅館</a></li>
# 	<li id="t-01"><a href="https://travel.rakuten.co.jp/yado/okinawa/nahashi.html" class="rtcond">那覇 ホテル・旅館</a></li>
# 	<li id="t-02"><a href="https://travel.rakuten.co.jp/yado/okinawa/hokubu.html" class="rtcond">恩納・名護・本部・今帰仁 ホテル・旅館</a></li>
# 	<li id="t-03"><a href="https://travel.rakuten.co.jp/yado/okinawa/chubu.html" class="rtcond">宜野湾・北谷・読谷・沖縄市・うるま ホテル・旅館</a></li>
# 	<li id="t-04"><a href="https://travel.rakuten.co.jp/yado/okinawa/nanbu.html" class="rtcond">糸満・豊見城・南城 ホテル・旅館</a></li>
# 	<li id="t-05"><a href="https://travel.rakuten.co.jp/yado/okinawa/kerama.html" class="rtcond">慶良間・渡嘉敷・座間味・阿嘉 ホテル・旅館</a></li>
# 	<li id="t-06"><a href="https://travel.rakuten.co.jp/yado/okinawa/kumejima.html" class="rtcond">久米島 ホテル・旅館</a></li>
# 	<li id="t-07"><a href="https://travel.rakuten.co.jp/yado/okinawa/Miyako.html" class="rtcond">宮古島・伊良部島 ホテル・旅館</a></li>
# 	<li id="t-08"><a href="https://travel.rakuten.co.jp/yado/okinawa/ritou.html" class="rtcond">石垣・西表・小浜島 ホテル・旅館</a></li>
# 	<li id="t-09"><a href="https://travel.rakuten.co.jp/yado/okinawa/yonaguni.html" class="rtcond">与那国島 ホテル・旅館</a></li>
# 	<li id="t-10"><a href="https://travel.rakuten.co.jp/yado/okinawa/daito.html" class="rtcond">大東島 ホテル・旅館</a></li>
# 	</ul>
#   <dl class="rtprts__area_links-wrap">
#       <dt><a href=""><span>もっと細かい地域から探す</span></a></dt>
#       <dd>
#           <ul style="top:0; left:0;">
#           </ul>
#       </dd>
#   </dl>
# </dd>
# </dl>
# <div class="module-history-domsearch">
#     <section id="browsing-history-container">
#     </section>
#     <section id="browsing-history-correlatedItem-container">
#     </section>
# </div></div>
# 	<div id="srchSide-B">
# 	</div>
#     <script src="https://trv.r10s.jp/share/common/js/lib/jquery/jquery.js" type="text/javascript" ></script>
# <script charset="UTF-8" type="text/javascript" src="https://trv.r10s.jp/share/recipe/js/recipe.js" data-menu="ds.v4" async></script>
# <script src="https://trv.r10s.jp/share/themes/top/js/top_global_link.js" type="text/javascript" charset="Shift_jis"></script>
# <script src="https://trv.r10s.jp/share/themes/ds/js/actionviruslistcommon.js" type="text/javascript" ></script>
# <!--[if gte IE 9]>
#   <style type="text/css">
#     .gradient {
#        filter: none;
#     }
#   </style>
# <![endif]-->
# <script type="text/javascript" src="https://trv.r10s.jp/share/wat/list/undated_hotel.js"></script>
# 	<script type="text/javascript" src="https://trv.r10s.jp/share/themes/ds/js/rakutenTr_domesticAirPackageCarrier4UdSrch.js"></script>
# 	<!-- UserInsight start -->
# 	<script type="text/javascript" src="https://trv.r10s.jp/share/themes/top/js/userLocal.js"></script>
# 	<!-- UserInsight end -->
# 	<!-- SiteCatalyst code version: H.9.Copyright 1997-2007 Omniture, Inc. More info available at http://www.omniture.com -->
# <div id="dynamicElement"></div>
# <script language="JavaScript" src="https://trv.r10s.jp/share/wat/sc/s_code.js"></script>
# <script language="JavaScript" src="https://trv.r10s.jp/share/wat/sc/code_to_paste.js"></script>
# <!-- End SiteCatalyst code version: H.9. -->
#
# <!-- Mebius -->
# <script type="text/javascript">
# var mbHost = (("https:" == document.location.protocol) ? "https://" : "http://");
# document.write(unescape("%3Cscript src='" + mbHost + "rd.rakuten.co.jp/js/p_code.js' type='text/javascript'%3E%3C/script%3E"));
# </script>
# <script type="text/javascript"><!--
#     i="6.2994.0";
#     n="travel";
#     l="travel";
#     r=document.referrer;
#     document.write(p(i,n,l,r));
# //--></script>
# <noscript>
#     <img src="//rd.rakuten.co.jp/p/?i=6.2994.0&n=travel&l=travel&r=" />
# </noscript>
# <!-- /Mebius -->
#
# <script type="text/javascript" charset="Shift_JIS" src="https://trv.r10s.jp/share/themes/ds/js/undated_s_code_setting.js"></script>
#
# <script type="text/javascript">
# 	<!--
# 	function showCovid(){
#
# 		if ( typeof antivirushotellist !== 'undefined' && document.getElementById('hotelNos') != null){
# 			// var hnolist = $('#hotelNos').val().split(',');
# 			// for(var i = 0 ; i < hnolist.length; i++ ){
# 			// 	if(antivirushotellist[hnolist[i]] ){
# 			// 		if(document.getElementById('via_' + hnolist[i] + '_listing')){
# 			// 			document.getElementById('via_' + hnolist[i] + '_listing').style.display ="inline-block";
# 			// 		}
# 			// 		if(document.getElementById('via_' + hnolist[i])){
# 			// 			document.getElementById('via_' + hnolist[i]).style.display ="inline-block";
# 			// 		}
# 			// 	}
# 			// }
# 			return;
# 		}
#
# 	}
# 	//-->
# </script><script type="text/javascript" src="https://trv.r10s.jp/share/themes/ds/js/show_ads_randomly.js?p=20210522"></script>
#     </div>
# <!--START_FOORTER -->
# <!--@FOOTER_MENU-->
# <!--START_FOOTER-->
# <script charset="UTF-8" type="text/javascript" src="https://img.travel.rakuten.co.jp/share/rtl/js/navigation.js?_=20210719"> </script>
# <div class="rt-footer">
# <dl id="rt-switch-device" class="rt-switch-device">
# <dt>表示モード：</dt>
# <dd><ul>
# <li>モバイル</li>
# <li><a id="linkFtToPC" href="#">PC</a></li>
# </ul></dd>
# </dl>
# <ul class="rt-foot-nav">
# <li><a href="https://travel.rakuten.co.jp/corporate/" rel="nofollow">会社情報</a></li>
# <li><a href="https://privacy.rakuten.co.jp/" rel="nofollow">個人情報保護方針</a></li>
# <li class="rt-for-pc"><a href="https://corp.rakuten.co.jp/csr/">社会的責任[CSR]</a></li>
# <li class="rt-for-pc"><a href="https://travel.rakuten.co.jp/recruit/">採用情報</a></li>
# <li class="rt-for-pc"><a href="https://travel.rakuten.co.jp/info/" rel="nofollow">規約集</a></li>
# <li class="rt-for-pc"><a href="https://travel.rakuten.co.jp/info/hotel_msg.html">資料請求</a></li>
# </ul>
# <p class="rt-copyright">&copy; Rakuten Group, Inc.</p>
# <!--/.rt-footer--></div>
# <!--END_FOOTER-->
# <span id="footerBannerAppDL"></span>
# <script charset="UTF-8" type="text/javascript" src="//trv.r10s.jp/share/tags/js/tags.env.js"></script>
# <script charset="UTF-8" type="text/javascript" src="//trv.r10s.jp/share/tags/js/tags.track.js?_=20210522"></script><!--END_FOORTER--></body>
# </html>

# %% [markdown]
# >BeautifulSoupでhtml解析

# %% [markdown]
# htmlの内容を解析するためにbeautifulSoupにデータを格納しましょう！

# %%
# BeautifulSoup(解析したいデータ,解析する方法)を指定し、解析したデータをsoupに代入します。
soup = BeautifulSoup(res.text,"html.parser")
soup
# Out:
# <!DOCTYPE HTML>
#
# <html lang="ja" prefix="og: http://ogp.me/ns# fb: http://www.facebook.com/2008/fbml mixi: http://mixi-platform.com/ns# gr: http://gree.jp/ns">
# <head>
# <meta charset="utf-8"/>
# <title>那覇のホテル・旅館 宿泊予約 【楽天トラベル】</title>
# <meta content="那覇のホテル・旅館の予約は楽天トラベルで！人気ビジネス,シティホテルから旅館までお客様の声など宿情報満載" name="description"/>
# <meta content="宿泊,出張,予約,施設,ビジネス,ホテル,旅館,楽天トラベル,旅の窓口,那覇" name="keywords"/>
# <meta content="index,follow" name="robots"/>
# <meta content="那覇のホテル・旅館 宿泊予約 【楽天トラベル】" property="og:title"/>
# <meta content="那覇のホテル・旅館の予約は楽天トラベルで！人気ビジネス,シティホテルから旅館までお客様の声など宿情報満載" property="og:description"/>
# <meta content="article" property="og:type"/>
# <meta content="https://travel.rakuten.co.jp/yado/okinawa/nahashi.html" property="og:url"/>
# <meta content="https://trvimg.r10s.jp/share/common/images/bnr_ogp_logo.gif" property="og:image"/>
# <link href="https://travel.rakuten.co.jp/yado/okinawa/nahashi.html" rel="canonical"/>
# <meta content="楽天トラベル" property="og:site_name"/>
# <meta content="ja_JP" property="og:locale"/>
# <meta content="telephone=no" name="format-detection"/>
# <link href="https://img.travel.rakuten.co.jp/share/common/css/style-pc.css?_=20221213" rel="stylesheet"/>
# <link href="https://img.travel.rakuten.co.jp/share/themes/ds/css/trvl_srch_undtd_page.css?_=20230717" media="screen" rel="stylesheet" type="text/css"/>
# <link href="https://img.travel.rakuten.co.jp/share/themes/ds/css/trvl_srch_undtd_dp_pop.css" media="screen" rel="stylesheet" type="text/css"/>
# <link href="https://img.travel.rakuten.co.jp/share/rtl/css/util.calendar.css" media="screen" rel="stylesheet" type="text/css"/>
# <link href="https://img.travel.rakuten.co.jp/share/themes/ds/css/searchSide_B.css" media="screen" rel="stylesheet" type="text/css"/>
# <link href="https://img.travel.rakuten.co.jp/share/common/css/thickbox.css" media="screen" rel="stylesheet" type="text/css"/>
# <link href="https://img.travel.rakuten.co.jp/share/themes/ds/css/station_C.css" media="screen" rel="stylesheet" type="text/css"/>
# <link href="https://img.travel.rakuten.co.jp/share/themes/ds/css/preferred_sparkle.css?=_20210525" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://search.travel.rakuten.co.jp/ds/yado/okinawa/nahashi-p2" rel="next"/>
# <link href="https://img.travel.rakuten.co.jp/share/rtl/css/widget_history_correlated-pc.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://trv.r10s.jp/share/rtl/css/widget_history_correlated-pc_imgOpt.css" media="all" rel="stylesheet" type="text/css"/>
# <!--[if lt IE 9]><script src="https://img.travel.rakuten.co.jp/share/common/js/lib/html5shiv.js"></script><![endif]-->
# </head>
# <body class="" id="TOP">
# <script>
#  if(!tags) var tags = {};
#  if(!tags.data) tags.data = {};
#  tags.data = {"contents":{"type":"hotel"},"page":{"type":"search","step":"","pageNo":1,"abTestName":"E20210630","patternNumber":"0"},"query":{"items":[{"from":{"date":"","country":"japan","prefecture":"okinawa","city":"nahashi","district":"","spot":""},"to":{"date":"","country":"japan","prefecture":"okinawa","city":"nahashi","district":"","spot":""},"guest":{"adult":"","child":"","infant":""},"id":"","type":"","category":"","provider":{"id":"","type":"hotel","category":""}}],"price":"","currency":"JPY","abTestHotelIdList":["hotelList_ad_L000002979_1_146927","hotelList_ad_L000002979_2_182439","hotelList_ad_L000002979_3_158644","hotelList_ad_L000002979_4_183095","hotelList_ad_L000002979_5_72693","hotelList_ad_L000002979_6_149360","hotelList_7_104526","hotelList_8_134763","hotelList_9_128440","hotelList_10_163087","hotelList_11_178447","hotelList_12_171943","hotelList_13_177761","hotelList_14_181785","hotelList_15_40768","hotelList_16_160939","hotelList_17_176757","hotelList_18_130025","hotelList_19_182884","hotelList_20_167519","hotelList_21_71990","hotelList_22_38282","hotelList_23_149369","hotelList_24_136808","hotelList_25_178292","hotelList_26_148000","hotelList_27_70884","hotelList_28_67292","hotelList_29_153504","hotelList_30_76923","hotelList_31_183095","hotelList_32_16693","hotelList_33_16443","hotelList_34_181339","hotelList_35_172986","hotelList_36_18195"]},"browse":{"items":[{"id":"","type":"room","provider":{"id":"146927","type":"hotel"}},{"id":"","type":"room","provider":{"id":"182439","type":"hotel"}},{"id":"","type":"room","provider":{"id":"158644","type":"hotel"}},{"id":"","type":"room","provider":{"id":"183095","type":"hotel"}},{"id":"","type":"room","provider":{"id":"72693","type":"hotel"}},{"id":"","type":"room","provider":{"id":"149360","type":"hotel"}},{"id":"","type":"room","provider":{"id":"104526","type":"hotel"}},{"id":"","type":"room","provider":{"id":"134763","type":"hotel"}},{"id":"","type":"room","provider":{"id":"128440","type":"hotel"}},{"id":"","type":"room","provider":{"id":"163087","type":"hotel"}},{"id":"","type":"room","provider":{"id":"178447","type":"hotel"}},{"id":"","type":"room","provider":{"id":"171943","type":"hotel"}},{"id":"","type":"room","provider":{"id":"177761","type":"hotel"}},{"id":"","type":"room","provider":{"id":"181785","type":"hotel"}},{"id":"","type":"room","provider":{"id":"40768","type":"hotel"}},{"id":"","type":"room","provider":{"id":"160939","type":"hotel"}},{"id":"","type":"room","provider":{"id":"176757","type":"hotel"}},{"id":"","type":"room","provider":{"id":"130025","type":"hotel"}},{"id":"","type":"room","provider":{"id":"182884","type":"hotel"}},{"id":"","type":"room","provider":{"id":"167519","type":"hotel"}},{"id":"","type":"room","provider":{"id":"71990","type":"hotel"}},{"id":"","type":"room","provider":{"id":"38282","type":"hotel"}},{"id":"","type":"room","provider":{"id":"149369","type":"hotel"}},{"id":"","type":"room","provider":{"id":"136808","type":"hotel"}},{"id":"","type":"room","provider":{"id":"178292","type":"hotel"}},{"id":"","type":"room","provider":{"id":"148000","type":"hotel"}},{"id":"","type":"room","provider":{"id":"70884","type":"hotel"}},{"id":"","type":"room","provider":{"id":"67292","type":"hotel"}},{"id":"","type":"room","provider":{"id":"153504","type":"hotel"}},{"id":"","type":"room","provider":{"id":"76923","type":"hotel"}},{"id":"","type":"room","provider":{"id":"183095","type":"hotel"}},{"id":"","type":"room","provider":{"id":"16693","type":"hotel"}},{"id":"","type":"room","provider":{"id":"16443","type":"hotel"}},{"id":"","type":"room","provider":{"id":"181339","type":"hotel"}},{"id":"","type":"room","provider":{"id":"172986","type":"hotel"}},{"id":"","type":"room","provider":{"id":"18195","type":"hotel"}}]}};
# </script>
# <script type="text/javascript">
# if(!rtp) var rtp = {};
# rtp.service = "dh";
#
# var abtest = {};
#
#
# 	var ds = {"actionPath":"search","areaName":"那覇","conditions":{"f_sort":["hotel"],"f_campaign":[""],"f_point_min":["0"],"f_page":["1"],"seo_f_chu":["okinawa"],"seo_f_shou":["nahashi"],"f_gcode":[""],"f_cd":[""],"f_dai":["japan"],"f_chu":["okinawa"],"f_shou":["nahashi"],"f_sai":[""],"f_latitude":["0.0"],"f_longitude":["0.0"],"f_km":[""],"f_squeezes":[],"f_rm_bed":[],"f_rm_type":[],"f_tab":["hotel"],"f_service":null},"displayedHotels":[146927,182439,158644,183095,72693,149360,104526,134763,128440,163087,178447,171943,177761,181785,40768,160939,176757,130025,182884,167519,71990,38282,149369,136808,178292,148000,70884,67292,153504,76923,16693,16443,181339,172986,18195],"facilityName":"","hotels":{},"isCamby":false,"isDated":false,"isHotelFixed":false,"isNearbySearch":false,"isSecret":false,"isShowCrossSearch":true,"isSqueezingCambyFlag":false,"narrowingArea":[],"rtcond":{"f_sort":["hotel"],"f_campaign":[""],"f_point_min":["0"],"f_gcode":[""],"f_cd":[""],"f_dai":["japan"],"f_chu":["okinawa"],"f_shou":["nahashi"],"f_sai":[""],"f_latitude":["0.0"],"f_longitude":["0.0"],"f_km":[""],"f_squeezes":[]},"rtcondex":{"dated":false,"f_tab":"hotel"},"totalResults":[416]};
#
# var searchHotelNo = "";
#
# if (!tags) var tags = {};
# if (!tags.data) tags.data = {};
# </script>
# <!--START_HEADER-->
# <span id="headerBannerAppDL"></span>
# <div class="rt-header">
# <ul class="rt-group-link">
# <li><a href="https://travel-smp.faq.rakuten.net/detail/000013745" target="_blank">新型コロナウイルスの対応について</a></li>
# <li><a href="https://ad2.trafficgate.net/t/r/9091/1441/99636_99636/">カード</a></li>
# <li><a href="https://gora.golf.rakuten.co.jp/?scid=wi_grp_gmx_trv_hetopbu_gra">GORA</a></li>
# <li><a href="https://www.rakuten.co.jp/">楽天市場</a></li>
# <!--/.rt-group-link--></ul>
# <div class="rt-service-bar">
# <div class="rt-site-id">
# <p class="rt-site-name"><a href="https://travel.rakuten.co.jp/">楽天トラベル</a></p>
# <p class="rt-outline">宿・航空券・ツアー予約</p>
# <!--/.rt-site-id--></div>
# <div class="rt-promotion">
# <a href="#" id="rt-header-square-banner"><img alt="" border="0" height="53" src="https://img.travel.rakuten.co.jp/share/images/null.gif" width="170"/></a>
# <!--/.rt-promotion --></div>
# <div class="rt-utility">
# <ul class="rt-help-link">
# <li><a href="https://travel.rakuten.co.jp/howto/">楽天トラベルの使い方</a></li>
# <li><a href="https://travel.rakuten.co.jp/sitemap/">サイトマップ</a></li>
# <li><a href="https://travel.faq.rakuten.net/">ヘルプ</a></li>
# <li class="rt-lang-link"><a href="javascript:void(0);" id="rt-lang-link-a">Languages</a>
# <ul id="rt-lang-box" style="display: none;">
# <li><a href="https://travel.rakuten.com/" id="lnkEnglish"><span>English</span></a></li>
# <li><a href="https://travel.rakuten.co.kr/" id="lnkKorea"><span>대한민국(한국어)</span></a></li>
# <li><a href="https://travel.rakuten.com.tw/" id="lnkTaiwanese"><span>台灣(繁體中文)</span></a></li>
# <li><a href="https://travel.rakuten.com.hk/" id="lnkHonkKong"><span>香港(繁體中文)</span></a></li>
# <li><a href="https://travel.rakuten.cn/" id="lnkChinese"><span>中国(简体中文)</span></a></li>
# <li><a href="https://travel.rakuten.co.th/" id="lnkThai"><span>ประเทศไทย (ภาษาไทย)</span></a></li>
# </ul>
# </li>
# </ul>
# <div class="rt-mytrv">
# <a href="https://auth.travel.rakuten.co.jp/fwd/memberDispatcher/staticPageLogin?service_id=t01&amp;return_url=cgi-bin/rakuten_id_reference&amp;_guestLoginServiceKey=guestReservation&amp;f_next_url=https://mypage.travel.rakuten.co.jp/">予約の確認・キャンセル</a>
# <!--/.rt-mytrv--></div>
# <div class="rt-notification-btn-box" id="rt-notification-container" style="display:none;">
# <button class="rt-notification-btn" id="notificationButton">
#     お知らせ
#   <!--/.rt-notification--></button>
# <span class="rt-count-badge" id="notificationBadge" style="display:none;">0</span>
# </div>
# <div id="pbox-container">
# <script id="pbox-member" type="text/x-jquery-tmpl">
#   <div class="rt-member-notification">
#   <dl class="rt-member">
#   <dt class="rt-member-${body.userRank}"><span>ようこそ</span><a href="https://my.travel.rakuten.co.jp/mytravel/"><b>${body.name}</b>さん</a></dt>
#   <dd><b>${body.totalPoint}</b>ポイント</dd>
#   </dl>
#   </div>
#   <div id="rt-btn-info" class="rt-btn-info">
#   <a href="#">会員情報</a>
#   <!--/.rt-btn-info--></div>
#
#   <!-- member detail -->
#   <div id="memberDetail">
#
#   <!-- detailMenu -->
#   <div class="detailMenu">
#   <ul id="menuTab"><!--
#   --><li class="memberMenu open">会員情報</li><!--
#   --><li class="serviceMenu">関連サービス</li><!--
#   --></ul><!--
#   --><div class="close">閉じる</div>
#   </div>
#   <!-- /detailMenu -->
#
#   <!-- statusInfo -->
#   <div id="statusInfo">
#   <div id="loginForm" class="${body.userRank}">
#   <div class="loginStatus" id="loginStatus">
#   <p class="user-name">ようこそ、<a href="https://my.travel.rakuten.co.jp/mytravel/"><span>${body.name}</span>さん</a></p>
#   <p class="member-rank">あなたは<em>${body.kaiinRank}</em></p>
#
#   <div class="pointInfo">
#   {{if body.loadPrivateFile}}
#   <p class="invitation"><a href="${body.loadPrivateFile}"><img width="20" hspace="2" height="24" border="0" style="vertical-align:middle;" src="https://img.travel.rakuten.co.jp/share/themes/top/images/env_anime.gif" alt="特別ご招待">特別ご招待</a></p>
#   {{/if}}
#   <p class="point">現在の保有ポイント<em>${body.totalPoint}ポイント</em>
#   {{if body.limitedTermPoint != 0}}
#   <span class="limit">うち、期間限定ポイント: ${body.limitedTermPoint}ポイント</span>
#       {{if body.pointrCash != 0 }}
#           <span class="note">楽天キャッシュ ${rtl.widget.pbox.viewHelper.numSeparate3Format(body.pointrCash)} 円</span>
#       {{/if}}
#   {{else  body.pointrCash != 0 }}
#   <span class="cash">うち、楽天キャッシュ ${rtl.widget.pbox.viewHelper.numSeparate3Format(body.pointrCash)} 円</span>
#   {{/if}}
#   </p>
#   <!-- /pointInfo --></div>
#   <!-- /loginStatus --></div>
#
#   <div class="btn-point"><a href="https://travel.rakuten.co.jp/point/">楽天ポイントについて</a><!-- /.btn-point --></div>
#   <ul class="link">
#   <li><a href="https://coupon.rakuten.co.jp/myCoupon">獲得済みのクーポン</a><img src="https://img.travel.rakuten.co.jp/share/themes/top/images/icon_new.gif"></li>
#   </ul>
#
#   <div class="btn-confirm">
#   <a href="https://auth.travel.rakuten.co.jp/fwd/memberDispatcher/staticPageLogin?service_id=t01&return_url=cgi-bin/rakuten_id_reference&_guestLoginServiceKey=guestReservation&f_next_url=https://mypage.travel.rakuten.co.jp/">予約の確認・変更・取消</a>
#   <!-- /.btn-confirm --></div>
#   <div class="btn-change">
#   <a href="https://auth.travel.rakuten.co.jp/fwd/memberDispatcher/staticPageLogin?service_id=t01&return_url=cgi-bin/rakuten_id_reference&f_next_url=https://aps1.travel.rakuten.co.jp/portal/my/rakuten_kaiin_supplement.main?f_henkou_flg=HENKOU">登録内容変更</a>
#   <!-- /.btn-change --></div>
#
#   <!-- /loginForm --></div>
#
#   <div class="btn-logout"><a href="https://auth.travel.rakuten.co.jp/fwd/omniLogout">ログアウト</a><!-- /.btn-logout --></div>
#   </div><!-- /div#statusInfo -->
#
#   <div id="serviceInfo">
#   <p class="title">楽天グループのサービス</p>
#   <ul class="serviceList"><!--
#   --><li><a href="https://www.rakuten.co.jp/"><span>楽天市場</span></a></li><!--
#   --><li><a href="https://www.rakuten-card.co.jp/smart/"><span>楽天カード</span></a></li><!--
#   --><li><a href="https://books.rakuten.co.jp/"><span>楽天ブックス</span></a></li><!--
#   --><li><a href="https://auction.rakuten.co.jp/"><span>楽天オークション</span></a></li><!--
#   --><li><a href="https://sp.rakuten-edy.co.jp/"><span>楽天Edy</span></a></li><!--
#   --><li><a href="https://www.rakuten-bank.co.jp/smartphone/index.html"><span>楽天銀行</span></a></li><!--
#   --><li><a href="https://gora.golf.rakuten.co.jp/smart/iphone_top.html"><span>楽天GORA</span></a></li><!--
#   --><li><a href="https://www.rakuten-sec.co.jp/smartphone/"><span>楽天証券</span></a></li><!--
#   --><li><a href="https://www.rakuten.co.jp/sitemap/sp/"><span>楽天サービス一覧</span></a></li><!--
#   --><li><a href="https://www.rakuten.co.jp/sitemap/spapp/"><span>楽天アプリ一覧</span></a></li><!--
#   --></ul><!-- /.serviceLst -->
#   <!-- /div#serviceInfo --></div>
#   <!-- /member detail --></div>
#   </script>
# <script id="pbox-nologin" type="text/x-jquery-tmpl">
#   <dl class="rt-nologin">
#   <dt>ようこそ、楽天トラベルへ</dt>
#   <dd><ul>
#       <li class="rt-btn-register"><a href="https://travel.rakuten.co.jp/kaiin.html">会員登録</a></li>
#       <li class="rt-btn-login"><a href="${body.redirect}">ログイン</a></li>
#   </ul></dd>
#   </dl>
#   </script>
# </div>
# <!--/.rtUtility--></div>
# <!--/.rt-service-bar--></div>
# <dl class="rt-nav-link">
# <dt><a href="#" id="rt-nav-link-a">メニュー</a></dt>
# <dd><ul class="rt-hide" id="rt-nav-box">
# <li class="rt-nav-active"><a href="https://travel.rakuten.co.jp/?l-id=top_navi_dh">国内旅行</a></li>
# <li class="rt-nav-down"><a href="https://travel.rakuten.co.jp/package/?l-id=top_navi_dp">国内ツアー</a>
# <ul class="rt-nav-secondary">
# <li><a href="https://travel.rakuten.co.jp/package/ana/?l-id=top_navi_dp_ana">ANA楽パック（航空券＋宿）</a></li>
# <li><a href="https://travel.rakuten.co.jp/package/jal/?l-id=top_navi_dp_jal">JAL楽パック（航空券＋宿）</a></li>
# </ul>
# </li>
# <li class=""><a href="https://travel.rakuten.co.jp/cars/?scid=wi_trv_top_navi_car">レンタカー</a></li>
# <li class=""><a href="https://travel.rakuten.co.jp/bus/?scid=wi_trv_top_navi_bus">高速バス・バスツアー</a></li>
# <li class=""><a href="https://travel.rakuten.co.jp/kaigai/?scid=wi_trv_top_navi_kaigai">海外旅行</a></li>
# <li class=""><a href="https://experiences.travel.rakuten.co.jp/?scid=wi_txp_trv_pc-nav">遊び・体験</a></li>
# <li class=""><a href="https://camp.travel.rakuten.co.jp/?scid=wi_trv_top_navi_camp">キャンプ場</a></li>
# <li class=""><a href="https://travel.rakuten.co.jp/coupon/?l-id=top_navi_coupon">割引クーポン</a></li>
# <li class=""><a href="https://travel.rakuten.co.jp/special/furusato/?l-id=top_navi_furusato">ふるさと納税</a></li>
# <li class=""><a href="https://travel.rakuten.co.jp/mytrip/?scid=wi_trv_top_navi_guide">旅行ガイド</a></li>
# </ul></dd>
# <!--/.rt-nav-link--></dl>
# <!--ds-->
# <div id="widgetPointupBannerRef"></div>
# <!--/.rt-header--></div>
# <div data-ratevent="appear" data-ratid="Point_Banner" data-ratparam="all" id="widgetPointupModalRef"></div>
# <input id="rt-service-hidden" type="hidden" value="domestic-travel"/>
# <!--END_HEADER-->
# <div id="wideEventBanner" style="display:none;">
# </div>
# <div class="htlList" id="srchContents">
# <!-- ****パンくず開始**** -->
# <p id="srchBrdCrmbs">
# <a href="//travel.rakuten.co.jp/">楽天トラベルトップ</a> &gt;
# 				<span class="grpLocationLocus"><a href="//travel.rakuten.co.jp/yado/japan.html">全国</a></span> &gt;
# 							<span class="grpLocationLocus"><a href="//travel.rakuten.co.jp/yado/okinawa/map.html">沖縄県</a></span>
#
# 								 &gt;
# 								那覇</p>
# <!-- ****パンくず終了**** --><h1 id="seoTtl">
# <span>那覇 </span>ホテル・旅館
# 				</h1>
# <div id="contentInner">
# <div id="srchMainContent">
# <!-- New Tab  start -->
# <input id="abTestForDAPLink" type="hidden" value="471_Link_A">
# <script type="text/javascript">
# 	var abTestForDAPLink = getABPatternForDAPLink();
# 	tags.data.page.abTestName = "trvab_2";
# 	tags.data.page.patternNumber = abTestForDAPLink;
#
# 	document.getElementById("abTestForDAPLink").value = abTestForDAPLink;
#
# 	function getABPatternForDAPLink() {
# 		var Rpstr = "";
# 		var name = "Rp" + "=";
# 		var cookies = document.cookie.split(';');
# 		if(cookies == null || cookies.length == 0) {
# 			return "471_Link_A";
# 		}
# 		for(var i=0; i<cookies.length; i++) {
# 			var c = cookies[i].trim();
# 			if (c.indexOf(name)==0) {
# 				Rpstr = c.substring(name.length,c.length);
# 				var result;
# 				var reg = /[a-zA-Z]+/;
# 				while (result = Rpstr.match(reg)) {
# 					Rpstr = Rpstr.replace(result[0], '');
# 				}
# 			}
# 		}
# 		if (!(Rpstr == null || Rpstr.length < 2)) {
# 			var checkNumber = parseInt(Rpstr.substring(Rpstr.length-2));
# 			if (checkNumber < 30) {
# 				return "471_Link_B";
# 			} else {
# 				return "471_Link_A";
# 			}
# 		}
# 		return "471_Link_A";
# 	}
# </script>
# <div class="section bleeding" id="listTab">
# <div class="sectionContent">
# <div id="freqCap_pushdown" style="display: none;">
# <div class="pushdownContainer" id="pushdownContainer">
# <div class="ad">
# </div>
# </div>
# </div>
# <div class="linebreak"></div>
# <div class="sectionColumns">
# <div class="gridPanel grid12">
# <div class="tabs">
# <ul>
# <li class="current" id="tabHtl" tns="no"><a>施設ごとに表示</a></li>
# <li id="tabMap" tns="no">
# <a href="//search.travel.rakuten.co.jp/ds/undated/search?f_dai=japan&amp;f_chu=okinawa&amp;f_shou=nahashi&amp;f_latitude=0.0&amp;f_longitude=0.0&amp;f_sort=hotel&amp;f_page=1&amp;f_hyoji=30&amp;f_image=1&amp;f_tab=map&amp;f_point_min=0">
# 										地図上に表示
# 									</a></li>
# </ul>
# <p class="dpsearch__links" id="dapLink" style="display: none;">
# <span class="dpsearch__links-label">パッケージで検索</span>
# <a class="dpsearch__links-item" href="https://travel.rakuten.co.jp/package/ana/?l-id=471_ANA">
# <img alt="ANA" height="12" src="https://trvimg.r10s.jp/share/common/images/icon_ana.svg" width="44"/>航空券+宿泊</a>
# <a class="dpsearch__links-item" href="https://travel.rakuten.co.jp/package/jal/?l-id=471_JAL">
# <img alt="JAL" height="12" src="https://trvimg.r10s.jp/share/common/images/icon_jal.svg" width="44"/>航空券+宿泊</a>
# </p>
# <p class="attension">
# </p>
# </div>
# </div>
# </div>
# </div>
# </div>
# <!-- New Tab  end -->
# <input id="hotelNos" type="hidden" value="146927,182439,158644,183095,72693,149360,104526,134763,128440,163087,178447,171943,177761,181785,40768,160939,176757,130025,182884,167519,71990,38282,149369,136808,178292,148000,70884,67292,153504,76923,16693,16443,181339,172986,18195"/>
# <input id="hotelPlanList" type="hidden" value=""/>
# <input id="actionPath" type="hidden" value="search"/>
# <input id="servicePath" type="hidden" value="undated"/>
# <input id="fTab" type="hidden" value="hotel"/>
# <input id="pageType" type="hidden" value="dateSearch"/>
# <input id="squeezes" type="hidden" value=""/>
# <input id="teikei" type="hidden" value=""/>
# <input id="isOEM" type="hidden" value="0"/>
# <input id="isHojin" type="hidden" value="0"/>
# <input id="f_service" type="hidden" value=""/>
# <input data-onetag-array-num="" data-onetag-name="hotelid" type="hidden" value="146927,182439,158644"/>
# <input data-onetag-name="checkin" data-onetag-num="" type="hidden" value=""/>
# <input data-onetag-name="checkout" data-onetag-num="" type="hidden" value=""/><!--sort-->
# <dl id="srtSwtch">
# <dt>並びかえ ： </dt>
# <dd><span>おすすめ順</span></dd>
# <dd>
# <a href="https://search.travel.rakuten.co.jp/ds/yado/okinawa/nahashi-low">料金の安い順</a></dd>
# <dd>
# <a href="https://search.travel.rakuten.co.jp/ds/yado/okinawa/nahashi-high">料金の高い順</a></dd>
# <dd>
# <a href="https://search.travel.rakuten.co.jp/ds/yado/okinawa/nahashi-review">評価が高い順</a></dd>
# </dl>
# <!--/sort--><!--**************paging start**************-->
# <div class="paging">
# <p class="pagingTitle"><span><em>416</em>件中</span>1～30件表示</p><ul class="pagingNumber"><li class="pagingTo">[ <span class="pagingActive">1</span> | <a href="https://search.travel.rakuten.co.jp/ds/yado/okinawa/nahashi-p2">2</a> | <a href="https://search.travel.rakuten.co.jp/ds/yado/okinawa/nahashi-p3">3</a> | <a href="https://search.travel.rakuten.co.jp/ds/yado/okinawa/nahashi-p4">4</a> | <a href="https://search.travel.rakuten.co.jp/ds/yado/okinawa/nahashi-p5">5</a> ･･･ ]</li><li class="pagingBack"><a href="https://search.travel.rakuten.co.jp/ds/yado/okinawa/nahashi-p2">次の30件</a></li></ul><div class="paging" style="float:right; display:inline-block">
# <img class="preferredSparklePagingPc" src="https://img.travel.rakuten.co.jp/share/themes/ds/images/Sparkle_final.png"/>
# <a class="preferredExplanation" href="https://travel.faq.rakuten.net/detail/000015657" style="color: #1D52A5;">プリファードADとは</a>
# </div>
# </div>
# <!--**************paging end**************--><link href="https://trv.r10s.jp/share/themes/ds/css/trvl_srch_undtd_page_v2.css?_=20211029" media="screen" rel="stylesheet" type="text/css"/>
# <script type="text/javascript">
# <!--
# 	var cks = document.cookie.split(',');
# 	var ckname = "Rp";
# 	var rpv = "99";
# 	var pattern = "";
#
# 	// Confirm Rp value
# 	if (cks && cks.length > 0) {
# 		// find Rp value from Cookies
# 		for(var i = 0; i < cks.length; i++) {
# 			var c = cks[i];
# 			while (c.charAt(0) == ' ') {
# 				c = c.substring(1);
# 			}
# 			// Rp is set in Cookie
# 			if (c.indexOf(ckname) >= 0) {
# 				// Get value between "Rp=" and ";"
# 				var sep = c.indexOf(";", c.indexOf(ckname));
# 				if (sep >= 0) {
# 					rpv = c.substring(c.indexOf(ckname) + ckname.length + 1, sep);
# 				} else {
# 					rpv = c.substring(c.indexOf(ckname) + ckname.length + 1, c.length);
# 				}
# 				// Get last 2 digits
# 				rpv = rpv.replace(/[^0-9]/g, '');
# 				rpv = rpv.substring(rpv.length - 2);
# 				// set back to DEFAULT
# 				if (!rpv || rpv.length != 2) {
# 					rpv = "99";
# 				}
# 				break;
# 			}
# 		}
# 	}
#
# 	// Append RAT tag
# 	pattern = parseInt(rpv) < 10 ? "[PR]" : "[注目]";
# 	if (!tags) var tags = {};
# 	if (!tags.data) tags.data = {};
# 	tags.data.ratabtest = {
# 		"name": "lad",
# 		"pattern": pattern
# 	};
# -->
# </script>
# <!--hotel list-->
# <input id="cassetteCount" type="hidden" value="dateSearch_a-30:c-0:p-0:e-0"/>
# <ul class="htlList" id="htlBox" style="visibility: hidden">
# <li class="listing" data-ratevent="appear" data-ratid="hotelList_ad_L000002979_1_146927" data-ratparam="all" id="146927_list">
# <section>
# <div class="pr_icon">
#             PR
#         </div>
# <div class="htlHead">
# <div class="photo">
# <div class="htlImgWrp">
# <a class="htlImg" data-ratevent="click" data-ratid="hotelList_ad_L000002979_1_146927_photoClick" data-ratparam="all" href="javascript:void(0)" id="146927_gaikanlisting">
# <span class="thumbnail" id="thumbnail_146927_listing" video-id=""><img alt="" src="https://trvimg.r10s.jp/share/image_up/146927/origin/0b0fa54d113a402287846d1b4147ecb67cea1e4d.47.9.26.3.jpg?fit=inside|900:507&amp;interpolation=lanczos-none"/></span>
# </a>
# </div>
# <a class="thickbox btn360dgr 146927-pano" data-lid="dateSearchC_cassette_panorama_8_pg1" href="" id="146927-panorama" style="display:none;"><span>360ビュー</span></a>
# <!--/.photo-->
# </div>
# <div class="info">
# <p class="area">
#     那覇</p>
# <h1 class=""><a href="https://travel.rakuten.co.jp/HOTEL/146927/146927.html?l-id=hotelList_ad_L000002979_1_146927">ホテルアベスト那覇国際通り</a>
# <span class="preferred_sparkle_none"><img src="https://img.travel.rakuten.co.jp/share/themes/ds/images/Sparkle_final16x16.png"/><span class="preferred_sparkletext">こちらの宿泊施設は、宿泊者からの総合評価点数が高い、もしくは多くの宿泊実績がある等の独自の条件を満たしたプリファードプログラム参加施設です。楽天トラベルへサービス利用料を支払うことにより、原則同条件の他の施設よりも上位に表示されています。（ヘルプページ参照）</span></span>
# </h1>
# <p class="htlPrice">
#     		[最安料金]
# 			<span>3,055円〜</span><span class="incldTax">（消費税込3,360円〜）</span></p>
# <p class="cstmrEvl">
# <a href="https://travel.rakuten.co.jp/HOTEL/146927/review.html?l-id=hotelList_ad_L000002979_1_146927" id="146927_review">
# <span class="starfourHlf"></span>
# <strong>4.13</strong>
#
# 			[お客さまの声（526件）]
# 		</a>
# </p>
# <p class="htlSpecial">国際通り徒歩０分の最高立地★地域一番の接客サービスを目指します★朝は大好評あんま～（お母さん）手作りの沖縄料理をどうぞ♪</p>
# <div class="tagwrp_v2">
# <p class="hometown_icon"><img src="https://trvimg.r10s.jp/share/common/images/label_hometown_tax.svg"/></p>
# <div class="othrIndIcons 146927_link_couponlisting event_146927">
# <ul>
# <input id="146927_link_coupon_hotelNolisting" type="hidden" value="146927"/>
# </ul>
# </div>
# </div>
# <!--/.info--></div>
# </div>
# <p class="htlAccess">
#            〒900-0015　沖縄県那覇市久茂地3-1-10<a class="thickbox" data-ratevent="click" data-ratid="hotelList_ad_L000002979_1_146927_mapClick" data-ratparam="all" href="//travel.rakuten.co.jp/share/gmap/map.html?f_longitude=127.6807344&amp;f_latitude=26.2140234&amp;TB_iframe=true&amp;height=450&amp;width=600" title="ホテルアベスト那覇国際通り">[地図を見る]</a>
# </p>
# <p class="htlInfo">アクセス　：ゆいレール（モノレール）「県庁前」駅より徒歩２分、那覇空港より車で約15分<br/>
#         駐車場　　：提携駐車場　1,000円/泊　入出庫1泊1回限　24時〜6時入出庫不可　詳細お問い合わせ下さい。</p>
# <ul class="btnUndtd">
# <li><a href="//hotel.travel.rakuten.co.jp/hotelinfo/plan/146927?f_teikei=&amp;l-id=hotelList_ad_L000002979_1_146927"><span>宿泊プラン一覧</span></a></li>
# <li><a class="dplkn" data-ratevent="click" data-ratid="hotelList_ad_L000002979_1_146927_dpPlanClick" data-ratparam="all" hotel_no="146927" href="javascript:void(0)" id="RM_DP_PLAN_146927"><span>航空券付プラン一覧</span></a></li>
# </ul>
# </section>
# <div class="photoPrnt">
# <div class="photoBox" id="146927-photo-contents" style="display: none; opacity: 0; z-index:">
# <p class="photoCls"><a class="closePhotoBox" href="javascript:void(0);" photoboxid="146927-photo-contents">閉じる</a></p>
# <ul>
# <li class="photoStck" id="photo-146927-0"></li>
# <li class="photoStck" id="photo-146927-1"></li>
# <li class="photoStck" id="photo-146927-2"></li>
# <li class="photoStck" id="photo-146927-3"></li>
# <li class="photoStck" id="photo-146927-4"></li>
# <li class="photoStck" id="photo-146927-5"></li>
# </ul>
# <p class="morePix"><a href="https://travel.rakuten.co.jp/HOTEL/146927/gallery.html">もっと見る</a></p>
# <!--/.photoBox-->
# </div>
# <!--/.photoPrnt-->
# </div>
# </li>
# <li class="listing" data-ratevent="appear" data-ratid="hotelList_ad_L000002979_2_182439" data-ratparam="all" id="182439_list">
# <section>
# <div class="pr_icon">
#             PR
#         </div>
# <div class="htlHead">
# <div class="photo">
# <div class="htlImgWrp">
# <a class="htlImg" data-ratevent="click" data-ratid="hotelList_ad_L000002979_2_182439_photoClick" data-ratparam="all" href="javascript:void(0)" id="182439_gaikanlisting">
# <span class="thumbnail" id="thumbnail_182439_listing" video-id=""><img alt="" src="https://trvimg.r10s.jp/share/image_up/182439/origin/c2cbee2f34315ad59baeaa1d99492a21377860bc.47.9.26.3.jpg?fit=inside|900:507&amp;interpolation=lanczos-none"/></span>
# </a>
# </div>
# <a class="thickbox btn360dgr 182439-pano" data-lid="dateSearchC_cassette_panorama_8_pg1" href="" id="182439-panorama" style="display:none;"><span>360ビュー</span></a>
# <!--/.photo-->
# </div>
# <div class="info">
# <p class="area">
#     那覇</p>
# <h1 class=""><a href="https://travel.rakuten.co.jp/HOTEL/182439/182439.html?l-id=hotelList_ad_L000002979_2_182439">ネストホテル那覇久茂地</a>
# <span class="preferred_sparkle_none"><img src="https://img.travel.rakuten.co.jp/share/themes/ds/images/Sparkle_final16x16.png"/><span class="preferred_sparkletext">こちらの宿泊施設は、宿泊者からの総合評価点数が高い、もしくは多くの宿泊実績がある等の独自の条件を満たしたプリファードプログラム参加施設です。楽天トラベルへサービス利用料を支払うことにより、原則同条件の他の施設よりも上位に表示されています。（ヘルプページ参照）</span></span>
# </h1>
# <p class="htlPrice">
#     		[最安料金]
# 			<span>2,591円〜</span><span class="incldTax">（消費税込2,850円〜）</span></p>
# <p class="cstmrEvl">
# <a href="https://travel.rakuten.co.jp/HOTEL/182439/review.html?l-id=hotelList_ad_L000002979_2_182439" id="182439_review">
# <span class="starfive"></span>
# <strong>4.65</strong>
#
# 			[お客さまの声（99件）]
# 		</a>
# </p>
# <p class="htlSpecial">オシャレなホテルに多彩なお部屋をご用意しました。ファミリーやご夫婦、カップルやお1人様でのご利用にも最適なホテルです。</p>
# <div class="tagwrp_v2">
# <p class="hometown_icon"><img src="https://trvimg.r10s.jp/share/common/images/label_hometown_tax.svg"/></p>
# <div class="othrIndIcons 182439_link_couponlisting event_182439">
# <ul>
# <input id="182439_link_coupon_hotelNolisting" type="hidden" value="182439"/>
# </ul>
# </div>
# </div>
# <!--/.info--></div>
# </div>
# <p class="htlAccess">
#            〒900-0015　沖縄県那覇市久茂地2-22-5<a class="thickbox" data-ratevent="click" data-ratid="hotelList_ad_L000002979_2_182439_mapClick" data-ratparam="all" href="//travel.rakuten.co.jp/share/gmap/map.html?f_longitude=127.6822461&amp;f_latitude=26.2195155&amp;TB_iframe=true&amp;height=450&amp;width=600" title="ネストホテル那覇久茂地">[地図を見る]</a>
# </p>
# <p class="htlInfo">アクセス　：ゆいレール美栄橋駅より徒歩５分／那覇空港よりお車にて約１０分<br/>
#         駐車場　　：有り　40台　1500円/1日　予約不要</p>
# <ul class="btnUndtd">
# <li><a href="//hotel.travel.rakuten.co.jp/hotelinfo/plan/182439?f_teikei=&amp;l-id=hotelList_ad_L000002979_2_182439"><span>宿泊プラン一覧</span></a></li>
# <li><a class="dplkn" data-ratevent="click" data-ratid="hotelList_ad_L000002979_2_182439_dpPlanClick" data-ratparam="all" hotel_no="182439" href="javascript:void(0)" id="RM_DP_PLAN_182439"><span>航空券付プラン一覧</span></a></li>
# </ul>
# </section>
# <div class="photoPrnt">
# <div class="photoBox" id="182439-photo-contents" style="display: none; opacity: 0; z-index:">
# <p class="photoCls"><a class="closePhotoBox" href="javascript:void(0);" photoboxid="182439-photo-contents">閉じる</a></p>
# <ul>
# <li class="photoStck" id="photo-182439-0"></li>
# <li class="photoStck" id="photo-182439-1"></li>
# <li class="photoStck" id="photo-182439-2"></li>
# <li class="photoStck" id="photo-182439-3"></li>
# <li class="photoStck" id="photo-182439-4"></li>
# <li class="photoStck" id="photo-182439-5"></li>
# </ul>
# <p class="morePix"><a href="https://travel.rakuten.co.jp/HOTEL/182439/gallery.html">もっと見る</a></p>
# <!--/.photoBox-->
# </div>
# <!--/.photoPrnt-->
# </div>
# </li>
# <li class="listing" data-ratevent="appear" data-ratid="hotelList_ad_L000002979_3_158644" data-ratparam="all" id="158644_list">
# <section>
# <div class="pr_icon">
#             PR
#         </div>
# <div class="htlHead">
# <div class="photo">
# <div class="htlImgWrp">
# <a class="htlImg" data-ratevent="click" data-ratid="hotelList_ad_L000002979_3_158644_photoClick" data-ratparam="all" href="javascript:void(0)" id="158644_gaikanlisting">
# <span class="thumbnail" id="thumbnail_158644_listing" video-id=""><img alt="" src="https://trvimg.r10s.jp/share/image_up/158644/origin/2c14024f0c124051b2cc427e34ea985c70e7b881.47.9.26.3.jpg?fit=inside|900:507&amp;interpolation=lanczos-none"/></span>
# </a>
# </div>
# <a class="thickbox btn360dgr 158644-pano" data-lid="dateSearchC_cassette_panorama_8_pg1" href="" id="158644-panorama" style="display:none;"><span>360ビュー</span></a>
# <!--/.photo-->
# </div>
# <div class="info">
# <p class="area">
#     那覇</p>
# <h1 class=""><a href="https://travel.rakuten.co.jp/HOTEL/158644/158644.html?l-id=hotelList_ad_L000002979_3_158644">アベストＣＵＢＥ那覇国際通りー全室鍵付きキャビン型ホテルー</a>
# <span class="preferred_sparkle_none"><img src="https://img.travel.rakuten.co.jp/share/themes/ds/images/Sparkle_final16x16.png"/><span class="preferred_sparkletext">こちらの宿泊施設は、宿泊者からの総合評価点数が高い、もしくは多くの宿泊実績がある等の独自の条件を満たしたプリファードプログラム参加施設です。楽天トラベルへサービス利用料を支払うことにより、原則同条件の他の施設よりも上位に表示されています。（ヘルプページ参照）</span></span>
# </h1>
# <p class="htlPrice">
#     		[最安料金]
# 			<span>2,728円〜</span><span class="incldTax">（消費税込3,000円〜）</span></p>
# <p class="cstmrEvl">
# <a href="https://travel.rakuten.co.jp/HOTEL/158644/review.html?l-id=hotelList_ad_L000002979_3_158644" id="158644_review">
# <span class="starfourHlf"></span>
# <strong>4.38</strong>
#
# 			[お客さまの声（211件）]
# 		</a>
# </p>
# <p class="htlSpecial">【国際通り沿いのキャビン型ホテル】相部屋無しで全室施錠可能★ご宿泊者朝食無料★2名〜4名部屋もあり★</p>
# <div class="tagwrp_v2">
# <p class="hometown_icon"><img src="https://trvimg.r10s.jp/share/common/images/label_hometown_tax.svg"/></p>
# <div class="othrIndIcons 158644_link_couponlisting event_158644">
# <ul>
# <input id="158644_link_coupon_hotelNolisting" type="hidden" value="158644"/>
# </ul>
# </div>
# </div>
# <!--/.info--></div>
# </div>
# <p class="htlAccess">
#            〒900-0013　沖縄県那覇市牧志3-13-17<a class="thickbox" data-ratevent="click" data-ratid="hotelList_ad_L000002979_3_158644_mapClick" data-ratparam="all" href="//travel.rakuten.co.jp/share/gmap/map.html?f_longitude=127.69160280000006&amp;f_latitude=26.2172288&amp;TB_iframe=true&amp;height=450&amp;width=600" title="アベストＣＵＢＥ那覇国際通りー全室鍵付きキャビン型ホテルー">[地図を見る]</a>
# </p>
# <p class="htlInfo">アクセス　：ゆいレール「牧志駅」より徒歩１分・国際通りまで徒歩0分♪那覇空港からホテルまでゆいレールで15分♪<br/>
#         駐車場　　：無し</p>
# <ul class="btnUndtd">
# <li><a href="//hotel.travel.rakuten.co.jp/hotelinfo/plan/158644?f_teikei=&amp;l-id=hotelList_ad_L000002979_3_158644"><span>宿泊プラン一覧</span></a></li>
# <li><a class="dplkn" data-ratevent="click" data-ratid="hotelList_ad_L000002979_3_158644_dpPlanClick" data-ratparam="all" hotel_no="158644" href="javascript:void(0)" id="RM_DP_PLAN_158644"><span>航空券付プラン一覧</span></a></li>
# </ul>
# </section>
# <div class="photoPrnt">
# <div class="photoBox" id="158644-photo-contents" style="display: none; opacity: 0; z-index:">
# <p class="photoCls"><a class="closePhotoBox" href="javascript:void(0);" photoboxid="158644-photo-contents">閉じる</a></p>
# <ul>
# <li class="photoStck" id="photo-158644-0"></li>
# <li class="photoStck" id="photo-158644-1"></li>
# <li class="photoStck" id="photo-158644-2"></li>
# <li class="photoStck" id="photo-158644-3"></li>
# <li class="photoStck" id="photo-158644-4"></li>
# <li class="photoStck" id="photo-158644-5"></li>
# </ul>
# <p class="morePix"><a href="https://travel.rakuten.co.jp/HOTEL/158644/gallery.html">もっと見る</a></p>
# <!--/.photoBox-->
# </div>
# <!--/.photoPrnt-->
# </div>
# </li>
# <li class="listing" data-ratevent="appear" data-ratid="hotelList_ad_L000002979_4_183095" data-ratparam="all" id="183095_list">
# <section>
# <div class="pr_icon">
#             PR
#         </div>
# <div class="htlHead">
# <div class="photo">
# <div class="htlImgWrp">
# <a class="htlImg" data-ratevent="click" data-ratid="hotelList_ad_L000002979_4_183095_photoClick" data-ratparam="all" href="javascript:void(0)" id="183095_gaikanlisting">
# <span class="thumbnail" id="thumbnail_183095_listing" video-id=""><img alt="" src="https://trvimg.r10s.jp/share/image_up/183095/origin/9ab5482f672ee9c93113ee355d3f105e22fa3be4.47.9.26.3.jpg?fit=inside|900:507&amp;interpolation=lanczos-none"/></span>
# </a>
# </div>
# <a class="thickbox btn360dgr 183095-pano" data-lid="dateSearchC_cassette_panorama_8_pg1" href="" id="183095-panorama" style="display:none;"><span>360ビュー</span></a>
# <!--/.photo-->
# </div>
# <div class="info">
# <p class="area">
#     那覇</p>
# <h1 class=""><a href="https://travel.rakuten.co.jp/HOTEL/183095/183095.html?l-id=hotelList_ad_L000002979_4_183095">ホテルグランコンソルト那覇</a>
# <span class="preferred_sparkle_none"><img src="https://img.travel.rakuten.co.jp/share/themes/ds/images/Sparkle_final16x16.png"/><span class="preferred_sparkletext">こちらの宿泊施設は、宿泊者からの総合評価点数が高い、もしくは多くの宿泊実績がある等の独自の条件を満たしたプリファードプログラム参加施設です。楽天トラベルへサービス利用料を支払うことにより、原則同条件の他の施設よりも上位に表示されています。（ヘルプページ参照）</span></span>
# </h1>
# <p class="htlPrice">
#     		[最安料金]
# 			<span>4,546円〜</span><span class="incldTax">（消費税込5,000円〜）</span></p>
# <p class="cstmrEvl">
# <a href="https://travel.rakuten.co.jp/HOTEL/183095/review.html?l-id=hotelList_ad_L000002979_4_183095" id="183095_review">
# <span class="starfourHlf"></span>
# <strong>4.44</strong>
#
# 			[お客さまの声（62件）]
# 		</a>
# </p>
# <p class="htlSpecial">2022年9月新規OPEN！国際通り徒歩3分・ご宿泊の皆様ご利用可能なフリーラウンジございます</p>
# <div class="tagwrp_v2">
# <p class="hometown_icon"><img src="https://trvimg.r10s.jp/share/common/images/label_hometown_tax.svg"/></p>
# <div class="othrIndIcons 183095_link_couponlisting event_183095">
# <ul>
# <input id="183095_link_coupon_hotelNolisting" type="hidden" value="183095"/>
# </ul>
# </div>
# </div>
# <!--/.info--></div>
# </div>
# <p class="htlAccess">
#            〒900-0014　沖縄県那覇市松尾1-18-25<a class="thickbox" data-ratevent="click" data-ratid="hotelList_ad_L000002979_4_183095_mapClick" data-ratparam="all" href="//travel.rakuten.co.jp/share/gmap/map.html?f_longitude=127.6823056208321&amp;f_latitude=26.21238991042739&amp;TB_iframe=true&amp;height=450&amp;width=600" title="ホテルグランコンソルト那覇">[地図を見る]</a>
# </p>
# <p class="htlInfo">アクセス　：那覇空港から車で約15分、ゆいレール「県庁前駅」より徒歩約５分<br/>
#         駐車場　　：有り：28台　料金：1,650円/泊 (税込み）高さ制限がございます。</p>
# <ul class="btnUndtd">
# <li><a href="//hotel.travel.rakuten.co.jp/hotelinfo/plan/183095?f_teikei=&amp;l-id=hotelList_ad_L000002979_4_183095"><span>宿泊プラン一覧</span></a></li>
# <li><a class="dplkn" data-ratevent="click" data-ratid="hotelList_ad_L000002979_4_183095_dpPlanClick" data-ratparam="all" hotel_no="183095" href="javascript:void(0)" id="RM_DP_PLAN_183095"><span>航空券付プラン一覧</span></a></li>
# </ul>
# </section>
# <div class="photoPrnt">
# <div class="photoBox" id="183095-photo-contents" style="display: none; opacity: 0; z-index:">
# <p class="photoCls"><a class="closePhotoBox" href="javascript:void(0);" photoboxid="183095-photo-contents">閉じる</a></p>
# <ul>
# <li class="photoStck" id="photo-183095-0"></li>
# <li class="photoStck" id="photo-183095-1"></li>
# <li class="photoStck" id="photo-183095-2"></li>
# <li class="photoStck" id="photo-183095-3"></li>
# <li class="photoStck" id="photo-183095-4"></li>
# <li class="photoStck" id="photo-183095-5"></li>
# </ul>
# <p class="morePix"><a href="https://travel.rakuten.co.jp/HOTEL/183095/gallery.html">もっと見る</a></p>
# <!--/.photoBox-->
# </div>
# <!--/.photoPrnt-->
# </div>
# </li>
# <li class="listing" data-ratevent="appear" data-ratid="hotelList_ad_L000002979_5_72693" data-ratparam="all" id="72693_list">
# <section>
# <div class="pr_icon">
#             PR
#         </div>
# <div class="htlHead">
# <div class="photo">
# <div class="htlImgWrp">
# <a class="htlImg" data-ratevent="click" data-ratid="hotelList_ad_L000002979_5_72693_photoClick" data-ratparam="all" href="javascript:void(0)" id="72693_gaikanlisting">
# <span class="thumbnail" id="thumbnail_72693_listing" video-id=""><img alt="" src="https://trvimg.r10s.jp/share/image_up/72693/origin/e5aa44d94a8047b44f8ab75dd2e57cb18a0772ba.47.9.26.3.jpg?fit=inside|900:507&amp;interpolation=lanczos-none"/></span>
# </a>
# </div>
# <a class="thickbox btn360dgr 72693-pano" data-lid="dateSearchC_cassette_panorama_8_pg1" href="" id="72693-panorama" style="display:none;"><span>360ビュー</span></a>
# <!--/.photo-->
# </div>
# <div class="info">
# <p class="area">
#     那覇</p>
# <h1 class=""><a href="https://travel.rakuten.co.jp/HOTEL/72693/72693.html?l-id=hotelList_ad_L000002979_5_72693">那覇ウエスト・イン</a>
# <span class="preferred_sparkle_none"><img src="https://img.travel.rakuten.co.jp/share/themes/ds/images/Sparkle_final16x16.png"/><span class="preferred_sparkletext">こちらの宿泊施設は、宿泊者からの総合評価点数が高い、もしくは多くの宿泊実績がある等の独自の条件を満たしたプリファードプログラム参加施設です。楽天トラベルへサービス利用料を支払うことにより、原則同条件の他の施設よりも上位に表示されています。（ヘルプページ参照）</span></span>
# </h1>
# <p class="htlPrice">
#     		[最安料金]
# 			<span>2,400円〜</span><span class="incldTax">（消費税込2,640円〜）</span></p>
# <p class="cstmrEvl">
# <a href="https://travel.rakuten.co.jp/HOTEL/72693/review.html?l-id=hotelList_ad_L000002979_5_72693" id="72693_review">
# <span class="starfourHlf"></span>
# <strong>4.16</strong>
#
# 			[お客さまの声（692件）]
# 		</a>
# </p>
# <p class="htlSpecial">全室個別Wi-Fi＆バルコニー付　コンクリート打ちっぱなしがクールさと清潔感を演出　バストイレセパレード</p>
# <div class="tagwrp_v2">
# <p class="hometown_icon"><img src="https://trvimg.r10s.jp/share/common/images/label_hometown_tax.svg"/></p>
# <div class="othrIndIcons 72693_link_couponlisting event_72693">
# <ul>
# <input id="72693_link_coupon_hotelNolisting" type="hidden" value="72693"/>
# </ul>
# </div>
# </div>
# <!--/.info--></div>
# </div>
# <p class="htlAccess">
#            〒900-0036　沖縄県那覇市西1-16-7<a class="thickbox" data-ratevent="click" data-ratid="hotelList_ad_L000002979_5_72693_mapClick" data-ratparam="all" href="//travel.rakuten.co.jp/share/gmap/map.html?f_longitude=127.67097680000006&amp;f_latitude=26.213301&amp;TB_iframe=true&amp;height=450&amp;width=600" title="那覇ウエスト・イン">[地図を見る]</a>
# </p>
# <p class="htlInfo">アクセス　：コンビニ目の前！新館＆本館〈全150室〉空港⇔ホテル車で約10分。旭橋駅⇔ホテル徒歩約８分。那覇港まで徒歩約2分。<br/>
#         駐車場　　：有　収容台数50台（先着順/予約不可）1泊1,100円込</p>
# <ul class="btnUndtd">
# <li><a href="//hotel.travel.rakuten.co.jp/hotelinfo/plan/72693?f_teikei=&amp;l-id=hotelList_ad_L000002979_5_72693"><span>宿泊プラン一覧</span></a></li>
# <li><a class="dplkn" data-ratevent="click" data-ratid="hotelList_ad_L000002979_5_72693_dpPlanClick" data-ratparam="all" hotel_no="72693" href="javascript:void(0)" id="RM_DP_PLAN_72693"><span>航空券付プラン一覧</span></a></li>
# </ul>
# </section>
# <div class="photoPrnt">
# <div class="photoBox" id="72693-photo-contents" style="display: none; opacity: 0; z-index:">
# <p class="photoCls"><a class="closePhotoBox" href="javascript:void(0);" photoboxid="72693-photo-contents">閉じる</a></p>
# <ul>
# <li class="photoStck" id="photo-72693-0"></li>
# <li class="photoStck" id="photo-72693-1"></li>
# <li class="photoStck" id="photo-72693-2"></li>
# <li class="photoStck" id="photo-72693-3"></li>
# <li class="photoStck" id="photo-72693-4"></li>
# <li class="photoStck" id="photo-72693-5"></li>
# </ul>
# <p class="morePix"><a href="https://travel.rakuten.co.jp/HOTEL/72693/gallery.html">もっと見る</a></p>
# <!--/.photoBox-->
# </div>
# <!--/.photoPrnt-->
# </div>
# </li>
# <li class="listing" data-ratevent="appear" data-ratid="hotelList_ad_L000002979_6_149360" data-ratparam="all" id="149360_list">
# <section>
# <div class="pr_icon">
#             PR
#         </div>
# <div class="htlHead">
# <div class="photo">
# <div class="htlImgWrp">
# <a class="htlImg" data-ratevent="click" data-ratid="hotelList_ad_L000002979_6_149360_photoClick" data-ratparam="all" href="javascript:void(0)" id="149360_gaikanlisting">
# <span class="thumbnail" id="thumbnail_149360_listing" video-id=""><img alt="" src="https://trvimg.r10s.jp/share/image_up/149360/origin/dde597450c1c85385a6c0e13c4558616c95c8159.47.9.26.3.jpg?fit=inside|900:507&amp;interpolation=lanczos-none"/></span>
# </a>
# </div>
# <a class="thickbox btn360dgr 149360-pano" data-lid="dateSearchC_cassette_panorama_8_pg1" href="" id="149360-panorama" style="display:none;"><span>360ビュー</span></a>
# <!--/.photo-->
# </div>
# <div class="info">
# <p class="area">
#     那覇</p>
# <h1 class=""><a href="https://travel.rakuten.co.jp/HOTEL/149360/149360.html?l-id=hotelList_ad_L000002979_6_149360">アルモントホテル那覇県庁前</a>
# <span class="preferred_sparkle_none"><img src="https://img.travel.rakuten.co.jp/share/themes/ds/images/Sparkle_final16x16.png"/><span class="preferred_sparkletext">こちらの宿泊施設は、宿泊者からの総合評価点数が高い、もしくは多くの宿泊実績がある等の独自の条件を満たしたプリファードプログラム参加施設です。楽天トラベルへサービス利用料を支払うことにより、原則同条件の他の施設よりも上位に表示されています。（ヘルプページ参照）</span></span>
# </h1>
# <p class="htlPrice">
#     		[最安料金]
# 			<span>4,091円〜</span><span class="incldTax">（消費税込4,500円〜）</span></p>
# <p class="cstmrEvl">
# <a href="https://travel.rakuten.co.jp/HOTEL/149360/review.html?l-id=hotelList_ad_L000002979_6_149360" id="149360_review">
# <span class="starfourHlf"></span>
# <strong>4.35</strong>
#
# 			[お客さまの声（340件）]
# 		</a>
# </p>
# <p class="htlSpecial">◆人工温泉光明石温泉宿泊者無料◆全室禁煙&amp;Wi-Fi無料◆徒歩数秒にコンビニ３社！</p>
# <div class="tagwrp_v2">
# <p class="hometown_icon"><img src="https://trvimg.r10s.jp/share/common/images/label_hometown_tax.svg"/></p>
# <div class="othrIndIcons 149360_link_couponlisting event_149360">
# <ul>
# <input id="149360_link_coupon_hotelNolisting" type="hidden" value="149360"/>
# </ul>
# </div>
# </div>
# <!--/.info--></div>
# </div>
# <p class="htlAccess">
#            〒900-0015　沖縄県那覇市久茂地1-3-5<a class="thickbox" data-ratevent="click" data-ratid="hotelList_ad_L000002979_6_149360_mapClick" data-ratparam="all" href="//travel.rakuten.co.jp/share/gmap/map.html?f_longitude=127.67815862460633&amp;f_latitude=26.21342490266712&amp;TB_iframe=true&amp;height=450&amp;width=600" title="アルモントホテル那覇県庁前">[地図を見る]</a>
# </p>
# <p class="htlInfo">アクセス　：「県庁前」 駅／那覇バスセンター／県庁／那覇市役所／国際通りまで徒歩約3分<br/>
#         駐車場　　：有料先着順ご予約不可。立体駐車場完備。台数・車高制限有り。1,100円（税込）。※駐輪場なし</p>
# <ul class="btnUndtd">
# <li><a href="//hotel.travel.rakuten.co.jp/hotelinfo/plan/149360?f_teikei=&amp;l-id=hotelList_ad_L000002979_6_149360"><span>宿泊プラン一覧</span></a></li>
# <li><a class="dplkn" data-ratevent="click" data-ratid="hotelList_ad_L000002979_6_149360_dpPlanClick" data-ratparam="all" hotel_no="149360" href="javascript:void(0)" id="RM_DP_PLAN_149360"><span>航空券付プラン一覧</span></a></li>
# </ul>
# </section>
# <div class="photoPrnt">
# <div class="photoBox" id="149360-photo-contents" style="display: none; opacity: 0; z-index:">
# <p class="photoCls"><a class="closePhotoBox" href="javascript:void(0);" photoboxid="149360-photo-contents">閉じる</a></p>
# <ul>
# <li class="photoStck" id="photo-149360-0"></li>
# <li class="photoStck" id="photo-149360-1"></li>
# <li class="photoStck" id="photo-149360-2"></li>
# <li class="photoStck" id="photo-149360-3"></li>
# <li class="photoStck" id="photo-149360-4"></li>
# <li class="photoStck" id="photo-149360-5"></li>
# </ul>
# <p class="morePix"><a href="https://travel.rakuten.co.jp/HOTEL/149360/gallery.html">もっと見る</a></p>
# <!--/.photoBox-->
# </div>
# <!--/.photoPrnt-->
# </div>
# </li>
# <li class="" data-ratevent="appear" data-ratid="hotelList_7_104526" data-ratparam="all" id="104526_list">
# <section>
# <div class="htlHead">
# <div class="photo">
# <div class="htlImgWrp">
# <a class="htlImg" data-ratevent="click" data-ratid="hotelList_7_104526_photoClick" data-ratparam="all" href="javascript:void(0)" id="104526_gaikan">
# <span class="thumbnail" id="thumbnail_104526" video-id=""><img alt="" src="https://trvimg.r10s.jp/share/image_up/104526/origin/d2ac276969595c179960e2fd34d3ccfdf81800db.47.9.26.3.jpg?fit=inside|900:507&amp;interpolation=lanczos-none"/></span>
# </a>
# </div>
# <a class="thickbox btn360dgr 104526-pano" data-lid="dateSearchC_cassette_panorama_8_pg1" href="" id="104526-panorama" style="display:none;"><span>360ビュー</span></a>
# <!--/.photo-->
# </div>
# <div class="info">
# <p class="area">
#     那覇</p>
# <h1 class=""><a href="https://travel.rakuten.co.jp/HOTEL/104526/104526.html?l-id=hotelList_7_104526">ダイワロイネットホテル沖縄県庁前</a>
# <span class="preferred_sparkle"><img src="https://img.travel.rakuten.co.jp/share/themes/ds/images/Sparkle_final16x16.png"/><span class="preferred_sparkletext">こちらの宿泊施設は、宿泊者からの総合評価点数が高い、もしくは多くの宿泊実績がある等の独自の条件を満たしたプリファードプログラム参加施設です。楽天トラベルへサービス利用料を支払うことにより、原則同条件の他の施設よりも上位に表示されています。（ヘルプページ参照）</span></span>
# </h1>
# <p class="htlPrice">
#     		[最安料金]
# 			<span>3,955円〜</span><span class="incldTax">（消費税込4,350円〜）</span></p>
# <p class="cstmrEvl">
# <a href="https://travel.rakuten.co.jp/HOTEL/104526/review.html?l-id=hotelList_7_104526" id="104526_review">
# <span class="starfourHlf"></span>
# <strong>4.18</strong>
#
# 			[お客さまの声（1149件）]
# 		</a>
# </p>
# <p class="htlSpecial">アネックス棟ではYouTube視聴可能でございます♪急な買い物に便利な24時間対応「セブンイレブン」と連結</p>
# <div class="tagwrp_v2">
# <p class="hometown_icon"><img src="https://trvimg.r10s.jp/share/common/images/label_hometown_tax.svg"/></p>
# <div class="othrIndIcons 104526_link_coupon event_104526">
# <ul>
# <input id="104526_link_coupon_hotelNo" type="hidden" value="104526"/>
# </ul>
# </div>
# </div>
# <!--/.info--></div>
# </div>
# <p class="htlAccess">
#            〒900-0021　沖縄県那覇市泉崎1-11-2<a class="thickbox" data-ratevent="click" data-ratid="hotelList_7_104526_mapClick" data-ratparam="all" href="//travel.rakuten.co.jp/share/gmap/map.html?f_longitude=127.67668355767204&amp;f_latitude=26.21322734042152&amp;TB_iframe=true&amp;height=450&amp;width=600" title="ダイワロイネットホテル沖縄県庁前">[地図を見る]</a>
# </p>
# <p class="htlInfo">アクセス　：◆モノレール県庁前駅または旭橋駅 徒歩3分　◆那覇空港 モノレール13分、車で約10分　◆沖縄県庁、国際通り 徒歩3分<br/>
#         駐車場　　：有り　１台　１０５０円（税込み／泊）　先着順（予約不可）*満車の際は、近隣の有料駐車場へご案内。</p>
# <ul class="btnUndtd">
# ...
# <li class="feature-parent-daiyoku">
# <input class="feature-daiyoku" id="daiyoku" onchange="autoSelectDuplication(this);autoSelectChildren(this)" type="checkbox" value="daiyoku"/>
# <label for="daiyoku">大浴場</label>
# </li>
# <li class="feature-parent-pl">
# <input class="feature-pl" id="pl" name="f_squeezes" onchange="autoSelectDuplication(this);autoSelectChildren(this)" type="checkbox" value="pl"/>
# <label for="pl">駐車場あり</label>
# </li>
# <li class="feature-parent-card">
# <input class="feature-card" id="card" onchange="autoSelectDuplication(this);autoSelectChildren(this)" type="checkbox" value="card"/>
# <label for="card">クレジットカード決済</label>
# </li>
# <li class="feature-parent-df-LateCheckout">
# <input class="feature-df-LateCheckout" id="df-LateCheckout" name="f_squeezes" onchange="autoSelectDuplication(this);autoSelectChildren(this)" type="checkbox" value="df-LateCheckout"/>
# <label for="df-LateCheckout">レイトチェックアウト</label>
# </li>
# <li class="feature-parent-prm">
# <input class="feature-prm" id="prm" name="f_squeezes" onchange="autoSelectDuplication(this);autoSelectChildren(this)" type="checkbox" value="prm"/>
# <label for="prm">ペット同宿可の宿</label>
# </li>
# <li class="feature-parent-df-IndoorPool more hidden">
# <input class="feature-df-IndoorPool" id="df-IndoorPool" onchange="autoSelectDuplication(this);autoSelectChildren(this)" type="checkbox" value="df-IndoorPool"/>
# <label for="df-IndoorPool">屋内プール</label>
# </li>
# <li class="feature-parent-pubus more hidden">
# <input class="feature-pubus" id="pubus" name="f_squeezes" onchange="autoSelectDuplication(this);autoSelectChildren(this)" type="checkbox" value="pubus"/>
# <label for="pubus">送迎バス</label>
# </li>
# <li class="feature-parent-rot more hidden">
# <input class="feature-rot" id="rot" onchange="autoSelectDuplication(this);autoSelectChildren(this)" type="checkbox" value="rot"/>
# <label for="rot">露天風呂</label>
# </li>
# <li class="feature-parent-fam more hidden">
# <input class="feature-fam" id="fam" onchange="autoSelectDuplication(this);autoSelectChildren(this)" type="checkbox" value="fam"/>
# <label for="fam">貸切風呂</label>
# </li>
# <li class="feature-parent-gen more hidden">
# <input class="feature-gen" id="gen" onchange="autoSelectDuplication(this);autoSelectChildren(this)" type="checkbox" value="gen"/>
# <label for="gen">源泉かけ流しの宿</label>
# </li>
# <li class="feature-parent-df-ObservationBath more hidden">
# <input class="feature-df-ObservationBath" id="df-ObservationBath" onchange="autoSelectDuplication(this);autoSelectChildren(this)" type="checkbox" value="df-ObservationBath"/>
# <label for="df-ObservationBath">展望風呂</label>
# </li>
# <li class="feature-parent-credit more hidden">
# <input class="feature-credit" id="credit" name="f_squeezes" onchange="autoSelectDuplication(this);autoSelectChildren(this)" type="checkbox" value="credit"/>
# <label for="credit">現地でカード利用可</label>
# </li>
# <li class="feature-parent-babybed more hidden">
# <input class="feature-babybed" id="babybed" name="f_squeezes" onchange="autoSelectDuplication(this);autoSelectChildren(this)" type="checkbox" value="babybed"/>
# <label for="babybed">ベビーベッド</label>
# </li>
# <li class="feature-parent-mahjong more hidden">
# <input class="feature-mahjong" id="mahjong" name="f_squeezes" onchange="autoSelectDuplication(this);autoSelectChildren(this)" type="checkbox" value="mahjong"/>
# <label for="mahjong">麻雀設備あり</label>
# </li>
# <li class="feature-parent-rpc more hidden">
# <input class="feature-rpc" id="rpc" name="f_squeezes" onchange="autoSelectDuplication(this);autoSelectChildren(this)" type="checkbox" value="rpc"/>
# <label for="rpc">PC貸し出し</label>
# </li>
# <li class="feature-parent-ppress more hidden">
# <input class="feature-ppress" id="ppress" name="f_squeezes" onchange="autoSelectDuplication(this);autoSelectChildren(this)" type="checkbox" value="ppress"/>
# <label for="ppress">ズボンプレッサー(貸出)</label>
# </li>
# <li class="feature-parent-df-5minFromStation more hidden">
# <input class="feature-df-5minFromStation" id="df-5minFromStation" name="f_squeezes" onchange="autoSelectDuplication(this);autoSelectChildren(this)" type="checkbox" value="df-5minFromStation"/>
# <label for="df-5minFromStation">駅から徒歩5分以内</label>
# </li>
# <li class="feature-parent-df-ChargingVehicle more hidden">
# <input class="feature-df-ChargingVehicle" id="df-ChargingVehicle" name="f_squeezes" onchange="autoSelectDuplication(this);autoSelectChildren(this)" type="checkbox" value="df-ChargingVehicle"/>
# <label for="df-ChargingVehicle">電気自動車の充電スタンド</label>
# </li>
# <li>
# <div class="positionDiv">
# <img class="sideImg" id="sideImg" src="https://img.travel.rakuten.co.jp/share/themes/header/images/icon_arrow01_hover.gif"/>
# <a class="showMoreCheckbox" onclick="showMore(this)">もっと見る</a>
# </div>
# </li>
# </ul>
# </dd>
# <dt>部屋</dt>
# <dd>
# <ul>
# <li class="feature-parent-kinen">
# <input class="feature-kinen" id="kinen" onchange="autoSelectDuplication(this);autoSelectChildren(this)" type="checkbox" value="kinen"/>
# <label for="kinen">禁煙ルーム</label>
# </li>
# <li class="feature-parent-kitsuen">
# <input class="feature-kitsuen" id="kitsuen" onchange="autoSelectDuplication(this);autoSelectChildren(this)" type="checkbox" value="kitsuen"/>
# <label for="kitsuen">喫煙ルーム</label>
# </li>
# <li class="feature-parent-internet">
# <input class="feature-internet" id="internet" name="f_squeezes" onchange="autoSelectDuplication(this);autoSelectChildren(this)" type="checkbox" value="internet"/>
# <label for="internet">インターネット可</label>
# </li>
# <li class="feature-parent-roten">
# <input class="feature-roten" id="roten" onchange="autoSelectDuplication(this);autoSelectChildren(this)" type="checkbox" value="roten"/>
# <label for="roten">露天風呂付き客室</label>
# </li>
# </ul>
# </dd>
# <dt>新型コロナウイルス対策</dt>
# <dd>
# <ul>
# <li class="feature-parent-via_staff">
# <input class="feature-via_staff" id="via_staff" name="f_squeezes" onchange="autoSelectDuplication(this);autoSelectChildren(this)" type="checkbox" value="via_staff"/>
# <label for="via_staff">スタッフのウイルス対策あり</label>
# </li>
# <li class="feature-parent-via_disinfect">
# <input class="feature-via_disinfect" id="via_disinfect" name="f_squeezes" onchange="autoSelectDuplication(this);autoSelectChildren(this)" type="checkbox" value="via_disinfect"/>
# <label for="via_disinfect">館内・客室などの消毒清掃あり</label>
# </li>
# <li class="feature-parent-via_vent">
# <input class="feature-via_vent" id="via_vent" name="f_squeezes" onchange="autoSelectDuplication(this);autoSelectChildren(this)" type="checkbox" value="via_vent"/>
# <label for="via_vent">館内・客室などの換気あり</label>
# </li>
# <li class="feature-parent-via_chkinout">
# <input class="feature-via_chkinout" id="via_chkinout" name="f_squeezes" onchange="autoSelectDuplication(this);autoSelectChildren(this)" type="checkbox" value="via_chkinout"/>
# <label for="via_chkinout">チェックイン・アウト時の接触回避策あり</label>
# </li>
# <li class="feature-parent-via_room">
# <input class="feature-via_room" id="via_room" name="f_squeezes" onchange="autoSelectDuplication(this);autoSelectChildren(this)" type="checkbox" value="via_room"/>
# <label for="via_room">客室に消毒液などあり</label>
# </li>
# <li class="feature-parent-via_meal more hidden">
# <input class="feature-via_meal" id="via_meal" name="f_squeezes" onchange="autoSelectDuplication(this);autoSelectChildren(this)" type="checkbox" value="via_meal"/>
# <label for="via_meal">食事時の接触回避策あり</label>
# </li>
# <li class="feature-parent-via_bath more hidden">
# <input class="feature-via_bath" id="via_bath" name="f_squeezes" onchange="autoSelectDuplication(this);autoSelectChildren(this)" type="checkbox" value="via_bath"/>
# <label for="via_bath">大浴場の消毒・接触回避策あり</label>
# </li>
# <li class="feature-parent-via_other_req more hidden">
# <input class="feature-via_other_req" id="via_other_req" name="f_squeezes" onchange="autoSelectDuplication(this);autoSelectChildren(this)" type="checkbox" value="via_other_req"/>
# <label for="via_other_req">宿泊者への消毒などお願いあり</label>
# </li>
# <li class="feature-parent-via_emergency more hidden">
# <input class="feature-via_emergency" id="via_emergency" name="f_squeezes" onchange="autoSelectDuplication(this);autoSelectChildren(this)" type="checkbox" value="via_emergency"/>
# <label for="via_emergency">緊急時のマニュアル・スタッフ教育あり</label>
# </li>
# <li>
# <div class="positionDiv">
# <img class="sideImg" id="sideImg" src="https://img.travel.rakuten.co.jp/share/themes/header/images/icon_arrow01_hover.gif"/>
# <a class="showMoreCheckbox" onclick="showMore(this)">もっと見る</a>
# </div>
# </li>
# </ul>
# </dd>
# <dt>バリアフリー</dt>
# <dd>
# <ul>
# <li class="feature-parent-uwhlchair">
# <input class="feature-uwhlchair" id="uwhlchair" name="f_squeezes" onchange="autoSelectDuplication(this);autoSelectChildren(this)" type="checkbox" value="uwhlchair"/>
# <label for="uwhlchair">車椅子可</label>
# </li>
# <li class="feature-parent-bfroom">
# <input class="feature-bfroom" id="bfroom" name="f_squeezes" onchange="autoSelectDuplication(this);autoSelectChildren(this)" type="checkbox" value="bfroom"/>
# <label for="bfroom">バリアフリールーム</label>
# </li>
# <li class="feature-parent-bftoilet">
# <input class="feature-bftoilet" id="bftoilet" name="f_squeezes" onchange="autoSelectDuplication(this);autoSelectChildren(this)" type="checkbox" value="bftoilet"/>
# <label for="bftoilet">バリアフリー用トイレ</label>
# </li>
# <li class="feature-parent-rwhlchair">
# <input class="feature-rwhlchair" id="rwhlchair" name="f_squeezes" onchange="autoSelectDuplication(this);autoSelectChildren(this)" type="checkbox" value="rwhlchair"/>
# <label for="rwhlchair">貸出用車椅子</label>
# </li>
# </ul>
# </dd>
# <dt>ふるさと納税</dt>
# <dd>
# <ul>
# <li class="feature-parent-hmtwntax">
# <input class="feature-hmtwntax" id="hmtwntax" name="f_squeezes" onchange="autoSelectDuplication(this);autoSelectChildren(this)" type="checkbox" value="hmtwntax"/>
# <label for="hmtwntax">ふるさと納税クーポン対象</label>
# </li>
# </ul>
# </dd>
# </dl>
# <p class="stdSrchBtn smlSz">
# <a href="javascript:document.getElementById('dh-form-squeeze').submit();" id="dh-squeeze-submit">絞り込む</a>
# </p>
# </dd>
# </dl>
# </input></input></input></input></input></input></input></input></input></input></input></input></input></input></input></input></input></input></input></input></input></input></input></input></input></input></input></form>
# </div>
# <div class="mboxDefault"></div>
# <script src="https://trv.r10s.jp/share/themes/ds/js/lowerprice.js?p=20200722" type="text/javascript"></script>
# <!-- end of domestic squeeze form -->
# <dl id="aroundArea">
# <dt class="ttlBar">周辺エリアのホテル・旅館</dt>
# <dd class="outerBox">
# <ul>
# <li class="first"><a href="https://travel.rakuten.co.jp/yado/okinawa/">沖縄県 ホテル・旅館</a></li>
# <li id="t-01"><a class="rtcond" href="https://travel.rakuten.co.jp/yado/okinawa/nahashi.html">那覇 ホテル・旅館</a></li>
# <li id="t-02"><a class="rtcond" href="https://travel.rakuten.co.jp/yado/okinawa/hokubu.html">恩納・名護・本部・今帰仁 ホテル・旅館</a></li>
# <li id="t-03"><a class="rtcond" href="https://travel.rakuten.co.jp/yado/okinawa/chubu.html">宜野湾・北谷・読谷・沖縄市・うるま ホテル・旅館</a></li>
# <li id="t-04"><a class="rtcond" href="https://travel.rakuten.co.jp/yado/okinawa/nanbu.html">糸満・豊見城・南城 ホテル・旅館</a></li>
# <li id="t-05"><a class="rtcond" href="https://travel.rakuten.co.jp/yado/okinawa/kerama.html">慶良間・渡嘉敷・座間味・阿嘉 ホテル・旅館</a></li>
# <li id="t-06"><a class="rtcond" href="https://travel.rakuten.co.jp/yado/okinawa/kumejima.html">久米島 ホテル・旅館</a></li>
# <li id="t-07"><a class="rtcond" href="https://travel.rakuten.co.jp/yado/okinawa/Miyako.html">宮古島・伊良部島 ホテル・旅館</a></li>
# <li id="t-08"><a class="rtcond" href="https://travel.rakuten.co.jp/yado/okinawa/ritou.html">石垣・西表・小浜島 ホテル・旅館</a></li>
# <li id="t-09"><a class="rtcond" href="https://travel.rakuten.co.jp/yado/okinawa/yonaguni.html">与那国島 ホテル・旅館</a></li>
# <li id="t-10"><a class="rtcond" href="https://travel.rakuten.co.jp/yado/okinawa/daito.html">大東島 ホテル・旅館</a></li>
# </ul>
# <dl class="rtprts__area_links-wrap">
# <dt><a href=""><span>もっと細かい地域から探す</span></a></dt>
# <dd>
# <ul style="top:0; left:0;">
# </ul>
# </dd>
# </dl>
# </dd>
# </dl>
# <div class="module-history-domsearch">
# <section id="browsing-history-container">
# </section>
# <section id="browsing-history-correlatedItem-container">
# </section>
# </div></div>
# <div id="srchSide-B">
# </div>
# <script src="https://trv.r10s.jp/share/common/js/lib/jquery/jquery.js" type="text/javascript"></script>
# <script async="" charset="UTF-8" data-menu="ds.v4" src="https://trv.r10s.jp/share/recipe/js/recipe.js" type="text/javascript"></script>
# <script charset="Shift_jis" src="https://trv.r10s.jp/share/themes/top/js/top_global_link.js" type="text/javascript"></script>
# <script src="https://trv.r10s.jp/share/themes/ds/js/actionviruslistcommon.js" type="text/javascript"></script>
# <!--[if gte IE 9]>
#   <style type="text/css">
#     .gradient {
#        filter: none;
#     }
#   </style>
# <![endif]-->
# <script src="https://trv.r10s.jp/share/wat/list/undated_hotel.js" type="text/javascript"></script>
# <script src="https://trv.r10s.jp/share/themes/ds/js/rakutenTr_domesticAirPackageCarrier4UdSrch.js" type="text/javascript"></script>
# <!-- UserInsight start -->
# <script src="https://trv.r10s.jp/share/themes/top/js/userLocal.js" type="text/javascript"></script>
# <!-- UserInsight end -->
# <!-- SiteCatalyst code version: H.9.Copyright 1997-2007 Omniture, Inc. More info available at http://www.omniture.com -->
# <div id="dynamicElement"></div>
# <script language="JavaScript" src="https://trv.r10s.jp/share/wat/sc/s_code.js"></script>
# <script language="JavaScript" src="https://trv.r10s.jp/share/wat/sc/code_to_paste.js"></script>
# <!-- End SiteCatalyst code version: H.9. -->
# <!-- Mebius -->
# <script type="text/javascript">
# var mbHost = (("https:" == document.location.protocol) ? "https://" : "http://");
# document.write(unescape("%3Cscript src='" + mbHost + "rd.rakuten.co.jp/js/p_code.js' type='text/javascript'%3E%3C/script%3E"));
# </script>
# <script type="text/javascript"><!--
#     i="6.2994.0";
#     n="travel";
#     l="travel";
#     r=document.referrer;
#     document.write(p(i,n,l,r));
# //--></script>
# <noscript>
# <img src="//rd.rakuten.co.jp/p/?i=6.2994.0&amp;n=travel&amp;l=travel&amp;r=">
# </img></noscript>
# <!-- /Mebius -->
# <script charset="Shift_JIS" src="https://trv.r10s.jp/share/themes/ds/js/undated_s_code_setting.js" type="text/javascript"></script>
# <script type="text/javascript">
# 	<!--
# 	function showCovid(){
#
# 		if ( typeof antivirushotellist !== 'undefined' && document.getElementById('hotelNos') != null){
# 			// var hnolist = $('#hotelNos').val().split(',');
# 			// for(var i = 0 ; i < hnolist.length; i++ ){
# 			// 	if(antivirushotellist[hnolist[i]] ){
# 			// 		if(document.getElementById('via_' + hnolist[i] + '_listing')){
# 			// 			document.getElementById('via_' + hnolist[i] + '_listing').style.display ="inline-block";
# 			// 		}
# 			// 		if(document.getElementById('via_' + hnolist[i])){
# 			// 			document.getElementById('via_' + hnolist[i]).style.display ="inline-block";
# 			// 		}
# 			// 	}
# 			// }
# 			return;
# 		}
#
# 	}
# 	//-->
# </script><script src="https://trv.r10s.jp/share/themes/ds/js/show_ads_randomly.js?p=20210522" type="text/javascript"></script>
# </div>
# <!--START_FOORTER -->
# <!--@FOOTER_MENU-->
# <!--START_FOOTER-->
# <script charset="UTF-8" src="https://img.travel.rakuten.co.jp/share/rtl/js/navigation.js?_=20210719" type="text/javascript"> </script>
# <div class="rt-footer">
# <dl class="rt-switch-device" id="rt-switch-device">
# <dt>表示モード：</dt>
# <dd><ul>
# <li>モバイル</li>
# <li><a href="#" id="linkFtToPC">PC</a></li>
# </ul></dd>
# </dl>
# <ul class="rt-foot-nav">
# <li><a href="https://travel.rakuten.co.jp/corporate/" rel="nofollow">会社情報</a></li>
# <li><a href="https://privacy.rakuten.co.jp/" rel="nofollow">個人情報保護方針</a></li>
# <li class="rt-for-pc"><a href="https://corp.rakuten.co.jp/csr/">社会的責任[CSR]</a></li>
# <li class="rt-for-pc"><a href="https://travel.rakuten.co.jp/recruit/">採用情報</a></li>
# <li class="rt-for-pc"><a href="https://travel.rakuten.co.jp/info/" rel="nofollow">規約集</a></li>
# <li class="rt-for-pc"><a href="https://travel.rakuten.co.jp/info/hotel_msg.html">資料請求</a></li>
# </ul>
# <p class="rt-copyright">© Rakuten Group, Inc.</p>
# <!--/.rt-footer--></div>
# <!--END_FOOTER-->
# <span id="footerBannerAppDL"></span>
# <script charset="UTF-8" src="//trv.r10s.jp/share/tags/js/tags.env.js" type="text/javascript"></script>
# <script charset="UTF-8" src="//trv.r10s.jp/share/tags/js/tags.track.js?_=20210522" type="text/javascript"></script><!--END_FOORTER--></body>
# </html>

# %% [markdown]
# #### 2.4.3.試行錯誤その１

# %% [markdown]
# h1.premium_normalのcssセレクタで情報をすべてのホテル名を取得できるか確認してみましょう。
# ブラウザで確認できるホテルの情報は32件あります。

# %% [markdown]
# <img src="img/img029.png">

# %%
# h1.premium_normal aにホテルの名前があるので、このcssセレクタを利用してみましょう。
soup.select_one("h1.premium_normal")
# .select_one('ここにcssセレクタ')で抽出できます
# Out:
# <h1 class="premium_normal"><a href="https://travel.rakuten.co.jp/HOTEL/171943/171943.html?l-id=hotelList_12_171943">沖縄かりゆしリゾートエグゼス那覇＜県庁前＞</a>
# <span class="preferred_sparkle_none"><img src="https://img.travel.rakuten.co.jp/share/themes/ds/images/Sparkle_final16x16.png"/><span class="preferred_sparkletext">こちらの宿泊施設は、宿泊者からの総合評価点数が高い、もしくは多くの宿泊実績がある等の独自の条件を満たしたプリファードプログラム参加施設です。楽天トラベルへサービス利用料を支払うことにより、原則同条件の他の施設よりも上位に表示されています。（ヘルプページ参照）</span></span>
# </h1>

# %% [markdown]
# 確認が取れたので、先ほどのセレクタで取得したすべてのホテル名をhotel_nameという変数に代入します。

# %%
#hotel_nameに代入
hotel_name = soup.select_one("h1.premium_normal")

# %% [markdown]
# 取得したデータを確認してみましょう！

# %%
#len(ここに要素を数えたい配列)で数を表示
len(hotel_name)
# Out:
# 4

# %% [markdown]
# ブラウザで確認できる32件に対して全く足りていないので、取得した内容を確認してみましょう！

# %%
# 取得したデータをすべて格納した変数 hotel_nameをfor文を使って、１つずつｔに代入して、表示します。
for t in hotel_name:
    print(t.text)
# Out:
# 沖縄かりゆしリゾートエグゼス那覇＜県庁前＞
#
#
# こちらの宿泊施設は、宿泊者からの総合評価点数が高い、もしくは多くの宿泊実績がある等の独自の条件を満たしたプリファードプログラム参加施設です。楽天トラベルへサービス利用料を支払うことにより、原則同条件の他の施設よりも上位に表示されています。（ヘルプページ参照）

# %% [markdown]
# 9つの情報しか取れない原因をブラウザで確認すると、
#     スクレイピング対策でホテル名のh1タグにclassありと無しがあるでの、対策しましょう！

# %% [markdown]
# #### 2.4.4.試行錯誤その２

# %% [markdown]
# sectionで絞って、h1で絞って、最後にaタグで絞ってあげるとすべてのホテル名を取得できるのでこのcssセレクタで取得します。

# %% [markdown]
# <img src="img/img027.png">

# %%
# section h1 aのcssセレクタで取得したデータをhotel_nameに代入
hotel_name = soup.select('section h1 a')
# 取得したデータを確認
hotel_name
# Out:
# [<a href="https://travel.rakuten.co.jp/HOTEL/146927/146927.html?l-id=hotelList_ad_L000002979_1_146927">ホテルアベスト那覇国際通り</a>,
#  <a href="https://travel.rakuten.co.jp/HOTEL/182439/182439.html?l-id=hotelList_ad_L000002979_2_182439">ネストホテル那覇久茂地</a>,
#  <a href="https://travel.rakuten.co.jp/HOTEL/158644/158644.html?l-id=hotelList_ad_L000002979_3_158644">アベストＣＵＢＥ那覇国際通りー全室鍵付きキャビン型ホテルー</a>,
#  <a href="https://travel.rakuten.co.jp/HOTEL/183095/183095.html?l-id=hotelList_ad_L000002979_4_183095">ホテルグランコンソルト那覇</a>,
#  <a href="https://travel.rakuten.co.jp/HOTEL/72693/72693.html?l-id=hotelList_ad_L000002979_5_72693">那覇ウエスト・イン</a>,
#  <a href="https://travel.rakuten.co.jp/HOTEL/149360/149360.html?l-id=hotelList_ad_L000002979_6_149360">アルモントホテル那覇県庁前</a>,
#  <a href="https://travel.rakuten.co.jp/HOTEL/104526/104526.html?l-id=hotelList_7_104526">ダイワロイネットホテル沖縄県庁前</a>,
#  <a href="https://travel.rakuten.co.jp/HOTEL/134763/134763.html?l-id=hotelList_8_134763">ダイワロイネットホテル那覇おもろまち</a>,
#  <a href="https://travel.rakuten.co.jp/HOTEL/128440/128440.html?l-id=hotelList_9_128440">ダイワロイネットホテル那覇国際通り</a>,
#  <a href="https://travel.rakuten.co.jp/HOTEL/163087/163087.html?l-id=hotelList_10_163087">ホテルアクアチッタナハ</a>,
#  <a href="https://travel.rakuten.co.jp/HOTEL/178447/178447.html?l-id=hotelList_11_178447">ＨＯＴＥＬ　ＳＡＮＳＵＩ　ＮＡＨＡ　琉球温泉　波之上の湯</a>,
#  <a href="https://travel.rakuten.co.jp/HOTEL/171943/171943.html?l-id=hotelList_12_171943">沖縄かりゆしリゾートエグゼス那覇＜県庁前＞</a>,
#  <a href="https://travel.rakuten.co.jp/HOTEL/177761/177761.html?l-id=hotelList_13_177761">東急ステイ沖縄那覇</a>,
#  <a href="https://travel.rakuten.co.jp/HOTEL/181785/181785.html?l-id=hotelList_14_181785">ヒューイットリゾート那覇</a>,
#  <a href="https://travel.rakuten.co.jp/HOTEL/40768/40768.html?l-id=hotelList_15_40768">アルモントホテル那覇おもろまち(旧ホテル法華クラブ那覇新都心)</a>,
#  <a href="https://travel.rakuten.co.jp/HOTEL/160939/160939.html?l-id=hotelList_16_160939">ＪＲ九州ホテル　ブラッサム那覇</a>,
#  <a href="https://travel.rakuten.co.jp/HOTEL/176757/176757.html?l-id=hotelList_17_176757">沖縄ハーバービューホテル</a>,
#  <a href="https://travel.rakuten.co.jp/HOTEL/130025/130025.html?l-id=hotelList_18_130025">西鉄リゾートイン那覇</a>,
#  <a href="https://travel.rakuten.co.jp/HOTEL/182884/182884.html?l-id=hotelList_19_182884">ホテルリソルトリニティ那覇</a>,
#  <a href="https://travel.rakuten.co.jp/HOTEL/167519/167519.html?l-id=hotelList_20_167519">ノボテル沖縄那覇</a>,
#  <a href="https://travel.rakuten.co.jp/HOTEL/71990/71990.html?l-id=hotelList_21_71990">ホテル　ロコア　ナハ</a>,
#  <a href="https://travel.rakuten.co.jp/HOTEL/38282/38282.html?l-id=hotelList_22_38282">ホテルパームロイヤルNAHA国際通り</a>,
#  <a href="https://travel.rakuten.co.jp/HOTEL/149369/149369.html?l-id=hotelList_23_149369">ホテルグレイスリー那覇</a>,
#  <a href="https://travel.rakuten.co.jp/HOTEL/136808/136808.html?l-id=hotelList_24_136808">リーガロイヤルグラン沖縄</a>,
#  <a href="https://travel.rakuten.co.jp/HOTEL/178292/178292.html?l-id=hotelList_25_178292">ホテル　ストレータ那覇</a>,
#  <a href="https://travel.rakuten.co.jp/HOTEL/148000/148000.html?l-id=hotelList_26_148000">ハイアットリージェンシー那覇沖縄</a>,
#  <a href="https://travel.rakuten.co.jp/HOTEL/70884/70884.html?l-id=hotelList_27_70884">スーパーホテル那覇・新都心</a>,
#  <a href="https://travel.rakuten.co.jp/HOTEL/67292/67292.html?l-id=hotelList_28_67292">アパホテル〈那覇〉</a>,
#  <a href="https://travel.rakuten.co.jp/HOTEL/153504/153504.html?l-id=hotelList_29_153504">コンドミニアムリゾート那覇　リビングイン旭橋駅前プレミア＆アネックス</a>,
#  <a href="https://travel.rakuten.co.jp/HOTEL/76923/76923.html?l-id=hotelList_30_76923">那覇東急ＲＥＩホテル</a>,
#  <a href="https://travel.rakuten.co.jp/HOTEL/183095/183095.html?l-id=hotelList_31_183095">ホテルグランコンソルト那覇</a>,
#  <a href="https://travel.rakuten.co.jp/HOTEL/16693/16693.html?l-id=hotelList_32_16693">ＧＲＧホテル那覇</a>,
#  <a href="https://travel.rakuten.co.jp/HOTEL/16443/16443.html?l-id=hotelList_33_16443">ロワジールホテル那覇</a>,
#  <a href="https://travel.rakuten.co.jp/HOTEL/181339/181339.html?l-id=hotelList_34_181339">かりゆしコンドミニアムリゾート那覇　龍神ホテル浮島</a>,
#  <a href="https://travel.rakuten.co.jp/HOTEL/172986/172986.html?l-id=hotelList_35_172986">ホテルコレクティブ</a>,
#  <a href="https://travel.rakuten.co.jp/HOTEL/18195/18195.html?l-id=hotelList_36_18195">サンプラザホテル＜沖縄県＞</a>]

# %% [markdown]
# 取得したデータ数を確認してみましょう。

# %%
#lenを使ってhotel_nameの長さを取得
len(hotel_name)
# Out:
# 36

# %% [markdown]
# ブラウザで確認できる32件に対して数が多いので、
# htmlの中にホテルの情報が何件あるのか、どのcssセレクタですべての情報が取得できるか探っていきます。

# %% [markdown]
# #### 2.4.5.試行錯誤その３

# %% [markdown]
# >欲しい情報にすべて書かれている[最安料金]という文字に着目してスクレイピングの構造を考える

# %% [markdown]
# ブラウザで確認すると、欲しい情報である値段に[最安料金]がすべて共通で書かれていますので、これを活用します。

# %% [markdown]
# どうかソースページでいくつあるか確認します。

# %% [markdown]
# <img src="img/img028.png">

# %% [markdown]
# このサイトのhtmlには３２件ではなく、表示されていない３６件のデータが含まれている事がわかりました。

# %% [markdown]
# >36件のデータを取得するための条件を考える

# %% [markdown]
# ３６件のデータを取得する前提でスクレイピングに使えるcssセレクタを考えます。

# %% [markdown]
# 欲しい情報にclassありや、classなしが混在している中、
# ＜section＞の中に＜p class="area"＞を含むhtmlなら、欲しい情報の４つを必ず1つずつあります。
#
# また、そのhtmlの部分から以下のcssセレクタでそれぞれの欲しい情報を取得できます。
#
# - h1 a
# - p.htlPrice span
# - p.cstmrEvl strong
# - p.htlAccess
#
# 欲しい情報の４つを必ず1つずつしか持たないhtmlを抽出するメリットは、
# 4つのデータが必ず1セットになるので、どこでスクレイピングを間違えたかなどのデバックをしやすいです。
#
# 例として、取得した結果だけを見ても原因がわからないからです。
# - ホテル名　35件
# - 値段　32件
# - 評価　3件
# - 住所　35件
#
# なので、必ず1セットにして取得できていない箇所を特定できるコードにする必要があります。

# %% [markdown]
# <img src="img/img030.png">

# %% [markdown]
# >sectionを条件にhtmlを分割

# %% [markdown]
# sectionタグを活用してこれで各ホテルごとのデータを取得してみましょう！
#
# 全体のhtmlから
# 欲しい情報を含まないsectionを含むhtmlをhotel_section_from_htmlに格納して、
# そこから欲しい情報を含むsectionを含むhtmlをhotel_sectionに代入してみましょう！
#
# 欲しい情報を含むsectionはhtmlの中に＜p class="area"＞のhtmlをもつので、それを分離条件にします。

# %%
# すべてのsectionタグを取得します。
hotel_section_from_html = soup.select('section')
# 取得したセクションすべての数を確認します。
len(hotel_section_from_html)
# Out:
# 38

# %%
# sectionのp.areaに欲しいデータがちゃんと含まれているかを確認します
# hotel_section_from_htmlの中の１つであるhotel_section_from_html[0]から取得してみます。
hotel_section_from_html[0].select_one('p.area').text
# Out:
# '\n    那覇'

# %%
#すべてのsctionのデータを持つhotel_section_from_htmlから欲しい情報を取得出来る事条件を作ります。
# 条件でselect_one('p.area')にデータを含まない場合、不要なsectionなので条件文で排除できるように準備します。

# すべてのsctionのデータを持つhotel_section_from_htmlをhsに1つずつsectionデータを代入して実行します。
for hs in hotel_section_from_html:
    a = hs.select_one('p.area')
# hotel_section_from_htmlから順番に取り出したsctionデータをaに代入します。
    if(a == None):
       print("空です")
#　この条件が実行された場合、不要なsectionを検知できたことになります。またこれが2つ出力されていればOKです。
# Out:
# 空です
# 空です

# %%
# 必要な情報を含むsectionを抽出する条件を作成できたので、hotel_sectionに必要な情報を含むsectionを追加していきます。

# hotel_section_from_htmlからsctionを抽出して残しておく、hotel_sectionとして空の配列を用意しておきます。
hotel_section = []
for hs in hotel_section_from_html:
    a = hs.select_one('p.area')
    if (a != None):
        hotel_section.append(hs)
# aに情報がある時に実行したいので、条件はNoneではないというa != Noneになります。

# %%
#取得したhotel_sectionが不要である2つを除いた３６になっている事を確認します。
len(hotel_section)
# Out:
# 36

# %% [markdown]
# >分割したhtmlから欲しい情報を含むhtmlを1つずつ抽出

# %% [markdown]
# 余分なsectionデータを取り除いたので、sectionから名前、値段、評価、住所のそれぞれのデータを抽出してみましょう！

# %%
# for文を使ってすべてのデータを抜き出す前に、１つのsectionからそれぞれの項目のデータを取得できる土台を作ります。
#hotel_sectionの１つ目のsectionデータhotel_section[0]をhsに代入します。
hs = hotel_section[0]
print(hs.select_one('h1 a').text) # h1 aのcssセレクタにホテル名があるのでselect_one('h1 a').textで取得します。
print(hs.select_one('p.htlPrice span').text)# p.htlPrice spanのcssセレクタにホテル名があるのでselect_one('p.htlPrice span').textで取得します。
print(hs.select_one('p.cstmrEvl strong').text)# p.cstmrEvl strongのcssセレクタにホテル名があるのでselect_one('p.cstmrEvl strong').textで取得します。
# p.htlAccessのcssセレクタにホテル名があるのでselect_one('p.htlAccess').textで取得します。
print(hs.select_one('p.htlAccess').text)
# Out:
# ホテルアベスト那覇国際通り
# 3,055円〜
# 4.13
#
#            〒900-0015　沖縄県那覇市久茂地3-1-10[地図を見る]

# %% [markdown]
# >htmlから欲しい情報だけを抽出

# %% [markdown]
# 金額と住所だけデータの整理が必要なので、整理してみましょう！

# %%
# もう一度取得できた住所のデータを確認してみましょう
hs.select_one('p.htlAccess').text

# 改行である￥nと空欄と[地図を見る]と　が不要なのが確認できます
# これらをreplace(入れ替える文字列を指定,代入した文字列を指定)で削除していきます。
# 代入した文字列を指定の部分""にすることで何も挿入されませんので、削除のような処理になります。
# Out:
# '\n           〒900-0015\u3000沖縄県那覇市久茂地3-1-10[地図を見る]\n'

# %%
# ￥nを置き換える場合は.replace("\n","")になります。
# どのような挙動になるか確認してみましょう
hs.select_one('p.htlAccess').text.replace("\n","")
# Out:
# '           〒900-0015\u3000沖縄県那覇市久茂地3-1-10[地図を見る]'

# %%
# すべて置換して住所だけ抽出します。
# replace()で改行である￥nと空欄と[地図を見る]と　を1つずつ削除していきます。
hs.select_one('p.htlAccess').text.replace("\n","").replace(" ","").replace("　","").replace("[地図を見る]","")
# Out:
# '〒900-0015沖縄県那覇市久茂地3-1-10'

# %% [markdown]
# 同様に金額も数字にしてみましょう！！
# 数字だけにしておけば、後々あらゆる変換が可能になります。
#
# 一例として、金額のカンマ区切り表現にすると

# %%
# 4273を{:,}を指定することで、フォーマットを変更できます。
test = 4273
'{:,}'.format(test)
# Out:
# '4,273'

# %%
# 住所と同様、replace()で円～と,を削除処理します。
hs.select_one('p.htlPrice span').text.replace(",","").replace("円〜","")
# Out:
# '1819'

# %% [markdown]
# sectionからそれぞれの項目のデータを抽出し、それぞれ整理するコードをまとめてみましょう。

# %%
hs = hotel_section[0] #hotel_sectionの１つめのsectionであるhotel_section[0]をhsに代入
print(hs.select_one('h1 a').text)# ホテル名を取得
print(hs.select_one('p.htlPrice span').text.replace(",","").replace("円〜",""))# 値段を取得
print(hs.select_one('p.cstmrEvl strong').text)# ホテルの評価を取得
print(hs.select_one('p.htlAccess').text.replace("\n","").replace(" ","").replace("　","").replace("[地図を見る]",""))# ホテルの住所を取得
# Out:
# ホテルアベスト那覇国際通り
# 3055
# 4.13
# 〒900-0015沖縄県那覇市久茂地3-1-10

# %% [markdown]
# １つのsectionからそれぞれのデータを抽出できたので、すべてsectionからホテルデータを取得しましょう。

# %% [markdown]
# for文を使ってすべてのsectionを処理する前に、それぞれのsectionからそれぞれのホテルデータを格納するコードを作ります。
#
# すべてのsection要素をもつhtmlを格納する変数hotel_sectionからsectionを1つ選んで変数hsに代入します。
# そのhsから欲しい情報を抽出し、一時的に代入するための変数を４つ用意します。
#
# - hs1 （ホテル名）
# - hs2 （ホテルの料金）
# - hs3 （ホテル評価）
# - hs4 （ホテル住所）
#
# さらにそれらのすべてのホテルデータを格納する配列を４つ用意します。
#
# - hotelName （ホテル名）
# - hotelMinCharge （ホテルの料金）
# - reviewAverage （ホテル評価）
# - hotel_locate （ホテル住所）

# %%
# ホテル情報格納のための空配列を用意します。

hotelName = []# ホテル名を格納する空配列を用意します。
hotelMinCharge = []# ホテルの料金を格納する空配列を用意します。
reviewAverage = [] # ホテル評価を格納する空配列を用意します。
hotel_locate = []# ホテル住所を格納する空配列を用意します。

# hotel_sectionから任意のsectionを1つ選んでhsに代入して実行します。
hs = hotel_section[0]
# hsに格納されたhtmlであるsectionから欲しい情報を抽出
#ホテル名をhs1に代入
hs1 = hs.select_one('h1 a').text
# 値段が含まれていないホテル情報があるので、if文で条件分岐
if (hs.select_one('p.htlPrice span')!= None):
    hs2 = hs.select_one('p.htlPrice span').text.replace(",","").replace("円〜","") # 値段をhs2に代入
else:
    hs2 = -1   # 値段が記入されていない場合があるので、わかりやすく-1にしておきましょう。

hs3 = hs.select_one('p.cstmrEvl strong').text # 評価をhs3に代入

hs4 = hs.select_one('p.htlAccess').text.replace("\n","").replace(" ","").replace("　","").replace("[地図を見る]","") # 住所をhs4に代入

# それぞれ抽出した情報hs1~hs4までのデータを配列に追加

hotelName.append(hs1)#抽出したホテル名をhotelNameに追加
hotelMinCharge.append(hs2)#抽出したホテルの料金をhotelMinChargeに追加
reviewAverage.append(hs3)#抽出したホテルの評価をreviewAverageに追加
hotel_locate.append(hs4)#抽出したホテル住所をhotel_locateに追加

# %% [markdown]
# 追加した配列の中身を確認してみましょう！

# %%
#hotelName, hotelMinCharge, reviewAverage, hotel_locateの中身を確認
print(hotelName)
print(hotelMinCharge)
print(reviewAverage)
print(hotel_locate)
print(hs1)
# Out:
# ['ホテルアベスト那覇国際通り']
# ['3055']
# ['4.13']
# ['〒900-0015沖縄県那覇市久茂地3-1-10']
# ホテルアベスト那覇国際通り

# %% [markdown]
# hs = hotel_section[5]のように手動で選択していましたが、
# 自動ですべてのsectionから情報を取得できるようにfor文を活用してみましょう。

# %%
hotelName = [] # ホテル名を格納する空配列を用意します。
hotelMinCharge = [] # ホテルの料金を格納する空配列を用意します。
reviewAverage = [] # ホテル評価を格納する空配列を用意します。
hotel_locate = []# ホテル住所を格納する空配列を用意します。

# hotel_sectionからsectionを1つずつ取り出してhsに代入して実行します。
for hs in hotel_section:
    hs1 = hs.select_one('h1 a').text #ホテル名をhs1に代入
    if (hs.select_one('p.htlPrice span')!= None):
        hs2 = hs.select_one('p.htlPrice span').text.replace(",","").replace("円〜","") # 値段をhs2に代入
    else:
        hs2 = -1   # 値段が記入されていない場合があるので、わかりやすく-1にしておきましょう。
    hs3 = hs.select_one('p.cstmrEvl strong').text # 評価をhs3に代入
    hs4 = hs.select_one('p.htlAccess').text.replace("\n","").replace(" ","").replace("　","").replace("[地図を見る]","") # 住所をhs4に代入
    hotelName.append(hs1)#抽出したホテル名をhotelNameに追加
    hotelMinCharge.append(hs2)#抽出したホテルの料金をhotelMinChargeに追加
    reviewAverage.append(hs3)#抽出したホテルの評価をreviewAverageに追加
    hotel_locate.append(hs4)#抽出したホテル住所をhotel_locateに追加

# %% [markdown]
# #### 2.4.6.pandasを活用してデータにまとめる

# %% [markdown]
# >抽出した配列をDataFrameへ

# %% [markdown]
# pandasのデータ化して、確認してみましょう！！

# %%
# pandasのデータフレームに使うデータを定義します。
data_list = {
    "hotelName" : hotelName,
    "hotelMinCharge" : hotelMinCharge,
    "reviewAverage" : reviewAverage,
    "hotel_locate" : hotel_locate,
}

# %%
# 定義したデータをpandasに読み込ませます
# pd.DataFrame(ここにデータ)でデータフレームに変換できます。
import pandas as pd
df = pd.DataFrame(data_list)
df
# Out:
#                              hotelName hotelMinCharge reviewAverage  \
# 0                        ホテルアベスト那覇国際通り           3055          4.13
# 1                          ネストホテル那覇久茂地           2591          4.65
# 2        アベストＣＵＢＥ那覇国際通りー全室鍵付きキャビン型ホテルー           2728          4.38
# 3                        ホテルグランコンソルト那覇           4546          4.44
# 4                            那覇ウエスト・イン           2400          4.16
# 5                        アルモントホテル那覇県庁前           4091          4.35
# 6                     ダイワロイネットホテル沖縄県庁前           3955          4.18
# 7                   ダイワロイネットホテル那覇おもろまち           3341          4.46
# 8                    ダイワロイネットホテル那覇国際通り           3182          4.38
# 9                          ホテルアクアチッタナハ           4167          4.36
# 10        ＨＯＴＥＬ　ＳＡＮＳＵＩ　ＮＡＨＡ　琉球温泉　波之上の湯           3988          4.09
# 11               沖縄かりゆしリゾートエグゼス那覇＜県庁前＞           7728          4.68
# 12                           東急ステイ沖縄那覇           4864          4.52
# 13                        ヒューイットリゾート那覇           4519          4.27
# 14     アルモントホテル那覇おもろまち(旧ホテル法華クラブ那覇新都心)           3364          4.53
# 15                     ＪＲ九州ホテル　ブラッサム那覇           6546          4.41
# 16                        沖縄ハーバービューホテル           3069          4.24
# 17                          西鉄リゾートイン那覇           3637          4.20
# 18                       ホテルリソルトリニティ那覇           4091          4.41
# 19                            ノボテル沖縄那覇           3491          4.33
# 20                          ホテル　ロコア　ナハ           3228          4.36
# 21                  ホテルパームロイヤルNAHA国際通り           3728          4.30
# 22                         ホテルグレイスリー那覇           4273          4.51
# 23                        リーガロイヤルグラン沖縄           5576          4.62
# 24                         ホテル　ストレータ那覇           4000          4.49
# 25                    ハイアットリージェンシー那覇沖縄           7703          4.66
# 26                       スーパーホテル那覇・新都心           2900          4.22
# 27                           アパホテル〈那覇〉           3028          3.98
# 28  コンドミニアムリゾート那覇　リビングイン旭橋駅前プレミア＆アネックス           2728          4.45
# 29                          那覇東急ＲＥＩホテル           3473          4.34
# 30                       ホテルグランコンソルト那覇           4546          4.44
# 31                            ＧＲＧホテル那覇           3055          4.26
# 32                          ロワジールホテル那覇           4675          3.89
# 33           かりゆしコンドミニアムリゾート那覇　龍神ホテル浮島           3182          4.55
# 34                           ホテルコレクティブ          10920          4.80
# 35                       サンプラザホテル＜沖縄県＞           1819          4.12
#
#                                         hotel_locate
# 0                           〒900-0015沖縄県那覇市久茂地3-1-10
# 1                           〒900-0015沖縄県那覇市久茂地2-22-5
# 2                           〒900-0013沖縄県那覇市牧志3-13-17
# 3                           〒900-0014沖縄県那覇市松尾1-18-25
# 4                             〒900-0036沖縄県那覇市西1-16-7
# 5                            〒900-0015沖縄県那覇市久茂地1-3-5
# 6                            〒900-0021沖縄県那覇市泉崎1-11-2
# 7                         〒900-0006沖縄県那覇市おもろまち1-1-12
# 8                             〒902-0067沖縄県那覇市安里2-1-1
# 9                            〒900-0016沖縄県那覇市前島3-2-20
# 10                            〒900-0037沖縄県那覇市辻2-25-1
# 11                           〒900-0021沖縄県那覇市泉崎1-11-5
# 12                            〒900-0025沖縄県那覇市壷川3-2-1
# 13                         〒902-0067沖縄県那覇市安里2丁目5番16号
# 14                         〒900-0006沖縄県那覇市おもろまち4-3-8
# 15                         〒900-0013沖縄県那覇市牧志2丁目16番１号
# 16                             〒900-0021沖縄県那覇市泉崎2-46
# 17                     〒900-0033沖縄県那覇市久米2-3-13国際通り近く
# 18                                〒900-0029沖縄県那覇市旭町7
# 19                             〒902-0062沖縄県那覇市松川40番地
# 20                            〒900-0014沖縄県那覇市松尾1-1-2
# 21                           〒900-0013沖縄県那覇市牧志3-9-10
# 22                            〒900-0014沖縄県那覇市松尾1-3-6
# 23                              〒900-0029沖縄県那覇市旭町1-9
# 24                         〒900-0013沖縄県那覇市牧志1丁目19番8号
# 25                           〒900-0013沖縄県那覇市牧志3-6-20
# 26                       〒900-0006沖縄県那覇市おもろまち4-16-27
# 27                           〒900-0032沖縄県那覇市松山1-4-16
# 28  〒900-0034沖縄県那覇市東町11-17（プレミア館）・那覇市東町5番17号（アネックス館）
# 29          〒900-0029沖縄県那覇市旭町116-37（「カフーナ旭橋」内、自治会館隣）
# 30                          〒900-0014沖縄県那覇市松尾1-18-25
# 31                          〒900-0032沖縄県那覇市松山2-16-10
# 32                             〒900-0036沖縄県那覇市西3-2-1
# 33                           〒900-0014沖縄県那覇市松尾2-5-36
# 34                            〒900-0014沖縄県那覇市松尾2-5-7
# 35                              〒902-0067沖縄県那覇市安里138

# %% [markdown]
# >重複をチェック

# %% [markdown]
# スクレイピング対策で重複したデータが存在するので、
# 重複を確認して、削除してみましょう！

# %%
# duplicated()で重複がしているかをTrueかFalseで返してくれます。
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30     True
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# dtype: bool

# %% [markdown]
# >データ整理

# %%
# drop_duplicates()で重複したデータを削除してくれます。
# drop_duplicates(inplace=True)とすることで、処理したデータを出力だけでなく、出力したデータを元のdfに代入して変更してくれます。
df.drop_duplicates(inplace=True)
df
# Out:
#                              hotelName hotelMinCharge reviewAverage  \
# 0                        ホテルアベスト那覇国際通り           3055          4.13
# 1                          ネストホテル那覇久茂地           2591          4.65
# 2        アベストＣＵＢＥ那覇国際通りー全室鍵付きキャビン型ホテルー           2728          4.38
# 3                        ホテルグランコンソルト那覇           4546          4.44
# 4                            那覇ウエスト・イン           2400          4.16
# 5                        アルモントホテル那覇県庁前           4091          4.35
# 6                     ダイワロイネットホテル沖縄県庁前           3955          4.18
# 7                   ダイワロイネットホテル那覇おもろまち           3341          4.46
# 8                    ダイワロイネットホテル那覇国際通り           3182          4.38
# 9                          ホテルアクアチッタナハ           4167          4.36
# 10        ＨＯＴＥＬ　ＳＡＮＳＵＩ　ＮＡＨＡ　琉球温泉　波之上の湯           3988          4.09
# 11               沖縄かりゆしリゾートエグゼス那覇＜県庁前＞           7728          4.68
# 12                           東急ステイ沖縄那覇           4864          4.52
# 13                        ヒューイットリゾート那覇           4519          4.27
# 14     アルモントホテル那覇おもろまち(旧ホテル法華クラブ那覇新都心)           3364          4.53
# 15                     ＪＲ九州ホテル　ブラッサム那覇           6546          4.41
# 16                        沖縄ハーバービューホテル           3069          4.24
# 17                          西鉄リゾートイン那覇           3637          4.20
# 18                       ホテルリソルトリニティ那覇           4091          4.41
# 19                            ノボテル沖縄那覇           3491          4.33
# 20                          ホテル　ロコア　ナハ           3228          4.36
# 21                  ホテルパームロイヤルNAHA国際通り           3728          4.30
# 22                         ホテルグレイスリー那覇           4273          4.51
# 23                        リーガロイヤルグラン沖縄           5576          4.62
# 24                         ホテル　ストレータ那覇           4000          4.49
# 25                    ハイアットリージェンシー那覇沖縄           7703          4.66
# 26                       スーパーホテル那覇・新都心           2900          4.22
# 27                           アパホテル〈那覇〉           3028          3.98
# 28  コンドミニアムリゾート那覇　リビングイン旭橋駅前プレミア＆アネックス           2728          4.45
# 29                          那覇東急ＲＥＩホテル           3473          4.34
# 31                            ＧＲＧホテル那覇           3055          4.26
# 32                          ロワジールホテル那覇           4675          3.89
# 33           かりゆしコンドミニアムリゾート那覇　龍神ホテル浮島           3182          4.55
# 34                           ホテルコレクティブ          10920          4.80
# 35                       サンプラザホテル＜沖縄県＞           1819          4.12
#
#                                         hotel_locate
# 0                           〒900-0015沖縄県那覇市久茂地3-1-10
# 1                           〒900-0015沖縄県那覇市久茂地2-22-5
# 2                           〒900-0013沖縄県那覇市牧志3-13-17
# 3                           〒900-0014沖縄県那覇市松尾1-18-25
# 4                             〒900-0036沖縄県那覇市西1-16-7
# 5                            〒900-0015沖縄県那覇市久茂地1-3-5
# 6                            〒900-0021沖縄県那覇市泉崎1-11-2
# 7                         〒900-0006沖縄県那覇市おもろまち1-1-12
# 8                             〒902-0067沖縄県那覇市安里2-1-1
# 9                            〒900-0016沖縄県那覇市前島3-2-20
# 10                            〒900-0037沖縄県那覇市辻2-25-1
# 11                           〒900-0021沖縄県那覇市泉崎1-11-5
# 12                            〒900-0025沖縄県那覇市壷川3-2-1
# 13                         〒902-0067沖縄県那覇市安里2丁目5番16号
# 14                         〒900-0006沖縄県那覇市おもろまち4-3-8
# 15                         〒900-0013沖縄県那覇市牧志2丁目16番１号
# 16                             〒900-0021沖縄県那覇市泉崎2-46
# 17                     〒900-0033沖縄県那覇市久米2-3-13国際通り近く
# 18                                〒900-0029沖縄県那覇市旭町7
# 19                             〒902-0062沖縄県那覇市松川40番地
# 20                            〒900-0014沖縄県那覇市松尾1-1-2
# 21                           〒900-0013沖縄県那覇市牧志3-9-10
# 22                            〒900-0014沖縄県那覇市松尾1-3-6
# 23                              〒900-0029沖縄県那覇市旭町1-9
# 24                         〒900-0013沖縄県那覇市牧志1丁目19番8号
# 25                           〒900-0013沖縄県那覇市牧志3-6-20
# 26                       〒900-0006沖縄県那覇市おもろまち4-16-27
# 27                           〒900-0032沖縄県那覇市松山1-4-16
# 28  〒900-0034沖縄県那覇市東町11-17（プレミア館）・那覇市東町5番17号（アネックス館）
# 29          〒900-0029沖縄県那覇市旭町116-37（「カフーナ旭橋」内、自治会館隣）
# 31                          〒900-0032沖縄県那覇市松山2-16-10
# 32                             〒900-0036沖縄県那覇市西3-2-1
# 33                           〒900-0014沖縄県那覇市松尾2-5-36
# 34                            〒900-0014沖縄県那覇市松尾2-5-7
# 35                              〒902-0067沖縄県那覇市安里138

# %%
# 列の認識番号であるindexが列の順番と一致していないので、reset_indexで番号を振り直します。
# reset_index(drop=True,inplace=True)とすることで、元のindexを削除して新たに生成したindexを作成し、元のデータを更新してくれます。
df.reset_index(drop=True,inplace=True)
df
# Out:
#                              hotelName hotelMinCharge reviewAverage  \
# 0                        ホテルアベスト那覇国際通り           3055          4.13
# 1                          ネストホテル那覇久茂地           2591          4.65
# 2        アベストＣＵＢＥ那覇国際通りー全室鍵付きキャビン型ホテルー           2728          4.38
# 3                        ホテルグランコンソルト那覇           4546          4.44
# 4                            那覇ウエスト・イン           2400          4.16
# 5                        アルモントホテル那覇県庁前           4091          4.35
# 6                     ダイワロイネットホテル沖縄県庁前           3955          4.18
# 7                   ダイワロイネットホテル那覇おもろまち           3341          4.46
# 8                    ダイワロイネットホテル那覇国際通り           3182          4.38
# 9                          ホテルアクアチッタナハ           4167          4.36
# 10        ＨＯＴＥＬ　ＳＡＮＳＵＩ　ＮＡＨＡ　琉球温泉　波之上の湯           3988          4.09
# 11               沖縄かりゆしリゾートエグゼス那覇＜県庁前＞           7728          4.68
# 12                           東急ステイ沖縄那覇           4864          4.52
# 13                        ヒューイットリゾート那覇           4519          4.27
# 14     アルモントホテル那覇おもろまち(旧ホテル法華クラブ那覇新都心)           3364          4.53
# 15                     ＪＲ九州ホテル　ブラッサム那覇           6546          4.41
# 16                        沖縄ハーバービューホテル           3069          4.24
# 17                          西鉄リゾートイン那覇           3637          4.20
# 18                       ホテルリソルトリニティ那覇           4091          4.41
# 19                            ノボテル沖縄那覇           3491          4.33
# 20                          ホテル　ロコア　ナハ           3228          4.36
# 21                  ホテルパームロイヤルNAHA国際通り           3728          4.30
# 22                         ホテルグレイスリー那覇           4273          4.51
# 23                        リーガロイヤルグラン沖縄           5576          4.62
# 24                         ホテル　ストレータ那覇           4000          4.49
# 25                    ハイアットリージェンシー那覇沖縄           7703          4.66
# 26                       スーパーホテル那覇・新都心           2900          4.22
# 27                           アパホテル〈那覇〉           3028          3.98
# 28  コンドミニアムリゾート那覇　リビングイン旭橋駅前プレミア＆アネックス           2728          4.45
# 29                          那覇東急ＲＥＩホテル           3473          4.34
# 30                            ＧＲＧホテル那覇           3055          4.26
# 31                          ロワジールホテル那覇           4675          3.89
# 32           かりゆしコンドミニアムリゾート那覇　龍神ホテル浮島           3182          4.55
# 33                           ホテルコレクティブ          10920          4.80
# 34                       サンプラザホテル＜沖縄県＞           1819          4.12
#
#                                         hotel_locate
# 0                           〒900-0015沖縄県那覇市久茂地3-1-10
# 1                           〒900-0015沖縄県那覇市久茂地2-22-5
# 2                           〒900-0013沖縄県那覇市牧志3-13-17
# 3                           〒900-0014沖縄県那覇市松尾1-18-25
# 4                             〒900-0036沖縄県那覇市西1-16-7
# 5                            〒900-0015沖縄県那覇市久茂地1-3-5
# 6                            〒900-0021沖縄県那覇市泉崎1-11-2
# 7                         〒900-0006沖縄県那覇市おもろまち1-1-12
# 8                             〒902-0067沖縄県那覇市安里2-1-1
# 9                            〒900-0016沖縄県那覇市前島3-2-20
# 10                            〒900-0037沖縄県那覇市辻2-25-1
# 11                           〒900-0021沖縄県那覇市泉崎1-11-5
# 12                            〒900-0025沖縄県那覇市壷川3-2-1
# 13                         〒902-0067沖縄県那覇市安里2丁目5番16号
# 14                         〒900-0006沖縄県那覇市おもろまち4-3-8
# 15                         〒900-0013沖縄県那覇市牧志2丁目16番１号
# 16                             〒900-0021沖縄県那覇市泉崎2-46
# 17                     〒900-0033沖縄県那覇市久米2-3-13国際通り近く
# 18                                〒900-0029沖縄県那覇市旭町7
# 19                             〒902-0062沖縄県那覇市松川40番地
# 20                            〒900-0014沖縄県那覇市松尾1-1-2
# 21                           〒900-0013沖縄県那覇市牧志3-9-10
# 22                            〒900-0014沖縄県那覇市松尾1-3-6
# 23                              〒900-0029沖縄県那覇市旭町1-9
# 24                         〒900-0013沖縄県那覇市牧志1丁目19番8号
# 25                           〒900-0013沖縄県那覇市牧志3-6-20
# 26                       〒900-0006沖縄県那覇市おもろまち4-16-27
# 27                           〒900-0032沖縄県那覇市松山1-4-16
# 28  〒900-0034沖縄県那覇市東町11-17（プレミア館）・那覇市東町5番17号（アネックス館）
# 29          〒900-0029沖縄県那覇市旭町116-37（「カフーナ旭橋」内、自治会館隣）
# 30                          〒900-0032沖縄県那覇市松山2-16-10
# 31                             〒900-0036沖縄県那覇市西3-2-1
# 32                           〒900-0014沖縄県那覇市松尾2-5-36
# 33                            〒900-0014沖縄県那覇市松尾2-5-7
# 34                              〒902-0067沖縄県那覇市安里138

# %% [markdown]
# ### 2.5課題

# %% [markdown]
# 2ページ目の物件を取得してみましょう！

# %% [markdown]
# ### +αとして、取得したホテル名と住所を地図上に表示してみましょう！

# %% [markdown]
# ここまでは楽天トラベルのデータをAPIで取得し、構造化データとして取り扱うことをやってきました。
#
# 次にその他のAPIや外部データを組み合わせて、より価値の高いデータにしていきながら、アプリケーションを作っていく考え方を学びます。
#
# アイデアから実装までの思考プロセス
#
# - 楽天トラベルAPIでデータを取得したがもっと自分独自のデータにしたい
# - 外部データと組み合わせることはできないだろうか？
# - 住所がわかるなら、緯度経度をとることでマップに表示できないだろうか？
# - 実際にやってみよう！

# %% [markdown]
# 全体像
# - データから住所を取得
# - 国土交通省の国土地理院APIで緯度経度を取得
# - 取得した緯度経度とライブラリfoliumを使ってマップに出力

# %% [markdown]
# 地図上に表示してみましょう！
# 地図上にピンを立てられるライブラリ、foliumを活用してみましょう

# %% [markdown]
# foliumのインストールとして、ターミナルでpip install foliumをします。

# %%
# foliumでどんな機能かを具体例として東京スカイツリーを地図上に補油時してみます
import folium # foliumの機能を金ポートします

# 東京スカイツリーがある緯度経度をlatitudeとlongtudeに代入します。
# ピンの名前として、変数nameに東京スカイツリーを代入します。

latitude = 35.710063
longtude = 139.8107
name = "東京スカイツリー"

# folium.Map(location=[ここ緯度, ここ経度], zoom_start=ここ半径の数字) でマップを生成して、変数mapに代入します。
map = folium.Map(location=[latitude, longtude], zoom_start=18)
folium.Marker(location=[latitude, longtude], popup=name).add_to(map) # 変数mapに格納された地図情報にマーカーを加えます
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3cfbb8efa0c99b99f4897f292bc8584b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3cfbb8efa0c99b99f4897f292bc8584b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3cfbb8efa0c99b99f4897f292bc8584b = L.map(
#                 &quot;map_3cfbb8efa0c99b99f4897f292bc8584b&quot;,
#                 {
#                     center: [35.710063, 139.8107],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 18,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ee2b6960fd570357815a9afa7e02d98e = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_3cfbb8efa0c99b99f4897f292bc8584b);
#
#
#             var marker_ce00d712d4b074c8e111dfcd38997686 = L.marker(
#                 [35.710063, 139.8107],
#                 {}
#             ).addTo(map_3cfbb8efa0c99b99f4897f292bc8584b);
#
#
#         var popup_76fbfb34e0a3e0267d6eb19b4ec9c7d8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_dd347bd251f256364b6b6e430f8d1ce6 = $(`&lt;div id=&quot;html_dd347bd251f256364b6b6e430f8d1ce6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;東京スカイツリー&lt;/div&gt;`)[0];
#                 popup_76fbfb34e0a3e0267d6eb19b4ec9c7d8.setContent(html_dd347bd251f256364b6b6e430f8d1ce6);
#
#
#
#         marker_ce00d712d4b074c8e111dfcd38997686.bindPopup(popup_76fbfb34e0a3e0267d6eb19b4ec9c7d8)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# 楽天トラベルから得られた住所を地図上に表示する場合、緯度経度が必要なので、住所を緯度経度に変換してくれるAPIを活用してみましょう！！

# %%
# 一例として千葉県南房総市富浦町青木123-1の緯度経度を取得してみましょう。
import requests # APIにアクセスするためのrequestsの機能をimportします

url = "https://msearch.gsi.go.jp/address-search/AddressSearch?q="#アクセス先のURLとパラメータの一部をurlに代入
q = '千葉県南房総市富浦町青木123-1' # パラメータの一部をqに代入
res = requests.get(url + q) # url + q でパラメーター付のURLを完成させてリクエスト
print(res.json()[0]["geometry"]["coordinates"])# 緯度経度はres.json()[0]["geometry"]["coordinates"]に返ってくる
# Out:
# [139.887955, 35.070312]

# %% [markdown]
# マップに表示する方法と住所から緯度経度を取得する方法を確認したので、
# DataFrameに格納してる住所データの状況を１つ取って確認してみましょう！

# %%
# 住所のデータはhotel_locateのカラムにあるので、df["hotel_locate"]で住所のデータ群を呼び出せます。
# １つのデータで良いので、１行目のdf["hotel_locate"][0]を選びましょう。
df["hotel_locate"][0]
# Out:
# '〒900-0015沖縄県那覇市久茂地3-1-10'

# %%
# df["hotel_locate"][0]で確認した文字列は郵便番号がいらないので
# 〒900-0014沖縄県那覇市松尾1-3-6を参考に、住所だけを抽出します。
# pythonでは[9:]とすることで、10番目から最後まで抽出することができます。

test = '〒900-0015沖縄県那覇市久茂地3-1-10' # testに〒900-0014沖縄県那覇市松尾1-3-6の文字列を代入します。
test[9:]# 〒900-0014沖縄県那覇市松尾1-3-6を代入されたtestの10番目から最後まで必要なので、test[9:]とします。
# Out:
# '沖縄県那覇市久茂地3-1-10'

# %%
# データフレームのdf["hotel_locate"][0]でも10番目から最後まで抽出するのは[9:]でできます。
df["hotel_locate"][0][9:]
# Out:
# '沖縄県那覇市久茂地3-1-10'

# %% [markdown]
# DataFrameに格納してる住所データと住所から緯度経度を取得する方法とマップに表示する方法が確認出来たので、
# 楽天トラベルで取得したデータすべてを地図上に表示してみましょう。

# %%
# マッピングする回数を決めるために、データ数がいくつあるかを確かめる
len(df)
# Out:
# 35

# %%
#３５回繰り返すfor文の為に0-34が格納された配列を作る
# range(0,5)なら[0, 1, 2, 3, 4]と同じ配列を生成してくれます。
# range()を確認する場合は配列に変換してくれるlist()を使ってlist(range(0,5))としましょう！
range(0,len(df))
# Out:
# range(0, 35)

# %% [markdown]
# すべての住所データをマップに表示するために、緯度経度に変換してみましょう！

# %%
latitude_list = []# dfの住所から変換した経度を追加するための空配列
longtude_list = []# dfの住所から変換した経度を追加するための空配列

# 地図上に表示するマーカーを名前の一覧配列をdfから取得します。
# df["hotelName"].values.tolist() でdf["hotelName"]値を配列としてname_listに代入します。
name_list = df["hotelName"].values.tolist()

import requests# リクエスト機能をインポート

url = "https://msearch.gsi.go.jp/address-search/AddressSearch?q=" # パラメータ付URLをアクセス先としてurlに代入

# dfの住所0-34番目を取り出すためのindexをiに代入
for i in range(0,len(df)):
    q = df["hotel_locate"][i][9:] # i番目ホテル住所を指定し、[9:]で住所のみ抽出し、qに代入
    res = requests.get(url + q) # パラメータに住所を足し算して、パラメータ付URLを完成させて、リクエストし、結果をresに代入
    latitude_list.append(res.json()[0]["geometry"]["coordinates"][1]) # APIから取得した緯度をlatitude_listに追加
    longtude_list.append(res.json()[0]["geometry"]["coordinates"][0]) # APIから取得した経度をlongtude_listに追加

# %% [markdown]
# 得られた緯度経度とホテル名のデータを使って、地図上に表示します。

# %%
import folium # 地図機能をインポートします
# APIの住所から緯度経度変換で得られた配列の１つ目を基準にマップを生成
map = folium.Map(location=[latitude_list[0], longtude_list[0]], zoom_start=15)

# 地図しか生成しておらず、マーカーが１つもないので、
# APIの住所から緯度経度変換で得られた配列の１つ目を基準に生成したマップにマーカを追加する
# マーカー名にホテル名のname_listを指定する
for i in range(0,len(df)):
    folium.Marker(location=[latitude_list[i], longtude_list[i]], popup=name_list[i]).add_to(map)

# %%
#マーカを追加したマップを表示
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0e38c2aba953adb17b63d6120f0f4625 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0e38c2aba953adb17b63d6120f0f4625&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0e38c2aba953adb17b63d6120f0f4625 = L.map(
#                 &quot;map_0e38c2aba953adb17b63d6120f0f4625&quot;,
#                 {
#                     center: [26.214062, 127.680824],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ecb4b9ae0441597983f25dd41b4daef7 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_0e38c2aba953adb17b63d6120f0f4625);
#
#
#             var marker_c38c86e7f001dd8f6d5576477d41ea61 = L.marker(
#                 [26.214062, 127.680824],
#                 {}
#             ).addTo(map_0e38c2aba953adb17b63d6120f0f4625);
#
#
#         var popup_826b0681539ffcfebbfc30081996f716 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_feaa810547eb8b41df23ead5ea16afdf = $(`&lt;div id=&quot;html_feaa810547eb8b41df23ead5ea16afdf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ホテルアベスト那覇国際通り&lt;/div&gt;`)[0];
#                 popup_826b0681539ffcfebbfc30081996f716.setContent(html_feaa810547eb8b41df23ead5ea16afdf);
#
#
#
#         marker_c38c86e7f001dd8f6d5576477d41ea61.bindPopup(popup_826b0681539ffcfebbfc30081996f716)
#         ;
#
#
#
#
#             var marker_f0cafa2caf448899b0eeb365a0938b64 = L.marker(
#                 [26.219534, 127.682159],
#                 {}
#             ).addTo(map_0e38c2aba953adb17b63d6120f0f4625);
#
#
#         var popup_466f3fa56c47f816d2d3c4997ddb2536 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1a507b90f63452173ec8802201954116 = $(`&lt;div id=&quot;html_1a507b90f63452173ec8802201954116&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ネストホテル那覇久茂地&lt;/div&gt;`)[0];
#                 popup_466f3fa56c47f816d2d3c4997ddb2536.setContent(html_1a507b90f63452173ec8802201954116);
#
#
#
#         marker_f0cafa2caf448899b0eeb365a0938b64.bindPopup(popup_466f3fa56c47f816d2d3c4997ddb2536)
#         ;
#
#
#
#
#             var marker_0412f3cf0f47b58b04d82470704e4093 = L.marker(
#                 [26.2173, 127.691505],
#                 {}
#             ).addTo(map_0e38c2aba953adb17b63d6120f0f4625);
#
#
#         var popup_07ce322196cef9267bf106bfdc462163 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_897b9f5d8e80b2bd0961461813f3a8db = $(`&lt;div id=&quot;html_897b9f5d8e80b2bd0961461813f3a8db&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;アベストＣＵＢＥ那覇国際通りー全室鍵付きキャビン型ホテルー&lt;/div&gt;`)[0];
#                 popup_07ce322196cef9267bf106bfdc462163.setContent(html_897b9f5d8e80b2bd0961461813f3a8db);
#
#
#
#         marker_0412f3cf0f47b58b04d82470704e4093.bindPopup(popup_07ce322196cef9267bf106bfdc462163)
#         ;
#
#
#
#
#             var marker_0ae5b8b553e22ccd0f2af00a6427ab58 = L.marker(
#                 [26.21233, 127.682175],
#                 {}
#             ).addTo(map_0e38c2aba953adb17b63d6120f0f4625);
#
#
#         var popup_9e14f082079face85ff0466e77b03ce8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_fbc8a3648653355e5e1c650580dc3e1a = $(`&lt;div id=&quot;html_fbc8a3648653355e5e1c650580dc3e1a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ホテルグランコンソルト那覇&lt;/div&gt;`)[0];
#                 popup_9e14f082079face85ff0466e77b03ce8.setContent(html_fbc8a3648653355e5e1c650580dc3e1a);
#
#
#
#         marker_0ae5b8b553e22ccd0f2af00a6427ab58.bindPopup(popup_9e14f082079face85ff0466e77b03ce8)
#         ;
#
#
#
#
#             var marker_a90bcd811266120d2686aca16952922a = L.marker(
#                 [26.213297, 127.670898],
#                 {}
#             ).addTo(map_0e38c2aba953adb17b63d6120f0f4625);
#
#
#         var popup_cb6baf8a35d1407003a9f1171c255855 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e205b073acd07b77dc1ac84ad7e057d0 = $(`&lt;div id=&quot;html_e205b073acd07b77dc1ac84ad7e057d0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;那覇ウエスト・イン&lt;/div&gt;`)[0];
#                 popup_cb6baf8a35d1407003a9f1171c255855.setContent(html_e205b073acd07b77dc1ac84ad7e057d0);
#
#
#
#         marker_a90bcd811266120d2686aca16952922a.bindPopup(popup_cb6baf8a35d1407003a9f1171c255855)
#         ;
#
#
#
#
#             var marker_40813de415a6b88c46d45c372a2f6d08 = L.marker(
#                 [26.213243, 127.678139],

# %% [markdown]
# ### 2.6最後に取得した価格と評価の散布図を表示してみましょう！

# %% [markdown]
# 構造化されたデータを整備したときにもっとも大事なことはデータを「見える化」「可視化」することです。そのTipsを学びます。
#
# 人間は数字の羅列をみるだけでは、直感的に繋がりを把握することはできません。
#
# しかし、グラフ化などのデータの「可視化」を行うことで、
#
# - データのトレンド
# - データの特徴
# - 外れ値や特異点
#
# などを知ることができます

# %% [markdown]
# 全体像
# -  matplotlibのpyplotを活用して散布図を作る
# - xの値をホテル料金、yの値を評価の散布図を作成

# %% [markdown]
# ライブラリのnumpyとmatplotlibをインストールしましょう！

# %% [markdown]
# サンプルとして、xの値、yの値それぞれ100個の乱数配列を作ります。

# %%
import numpy as np # 数列を得意とするライブラリnumpyをインポートする
x = np.random.rand(100) # x軸の値になる0-1までの乱数100個を配列として用意し、xに代入
y = np.random.rand(100) # y軸の値になる0-1までの乱数100個を配列として用意し、yに代入

# %% [markdown]
# 可視化ライブラリmatplotlibで散布図にしてみましょう！

# %%
import matplotlib.pyplot as plt # グラフにプロットする機能をインポートし、pltの省略形として呼べるようにする
plt.scatter(x, y) # 乱数で作ったxとyの配列をplt.scatter(x軸の値, y軸の値)として代入

# %% [markdown]
# 取得したデータの型がプロットできる数字の状態であるかを確認しましょう

# %%
type(df["hotelMinCharge"][0])# type(ここに判別したい変数)とするとその変数のデータ型がわかります。
# Out:
# str

# %%
# 文字列であるstrは数字として扱われなく、文字としてある買われるので、変数 + 変数とした時に数字の足し算のような処理になりません。
df["hotelMinCharge"][0] + df["hotelMinCharge"][1]
# Out:
# '30552591'

# %%
# 文字列を数字のデータ型に変換する時はint(変換したい変数)とすると数字のデータ型に変換できます。
int(df["hotelMinCharge"][0])
# Out:
# 3055

# %%
# 足し算して数字として扱われているかを確認しましょう。
int(df["hotelMinCharge"][0]) + int(df["hotelMinCharge"][1])
# Out:
# 5646

# %% [markdown]
# グラフにするためにxの値をホテル料金、yの値を評価して、X軸y軸のデータを作りましょう。

# %%
x = [] # 数字に変換したホテル料金を追加するための空配列
y = [] # 数字に変換したホテル評価を追加するための空配列

for i in range(0 ,len(df)): 
    a1 = int(df["hotelMinCharge"][i]) # ホテル料金を数字の型に変換
    a2 = float(df["reviewAverage"][i]) # ホテル評価を数字の型に変換

# -1として入力した欠損したホテル料金データを条件で追加処理しない事で、排除します。
    if (a1 > 0):
        x.append(a1) # xに数字に変換したホテル料金を追加
        y.append(a2) # yに数字に変換したホテル評価を追加

# %%
# 用意したxとyの配列をplt.scatter(x軸の値, y軸の値)として代入
plt.scatter(x, y)

# %% [markdown]
# 可視化することで値段とホテルの評価の相関関係がだいたい分かったと思います！

# %% [markdown]
# ## 3最後に

# %% [markdown]
# お疲れさまでした。
# スクレイピングは対策されている上に、仕様変更されるとすぐに動かなくなります。
#
# その点APIは労力も対策されるリスクもないので、APIとスクレイピングは大きく違うとわかって頂けたかと思います。

# %% [markdown]
# 次は、スクレイピングを自動で定期的に取得できるpythonの実行ファイルを学びましょう。
